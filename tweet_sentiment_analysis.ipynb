# %%
import numpy as np
import pandas as pd
from nltk.corpus import twitter_samples
import nltk
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')
train_pos=all_positive_tweets[:4000]
train_neg=all_negative_tweets[:4000]
test_pos=all_positive_tweets[4000:]
test_neg=all_negative_tweets[4000:]

# %%
train_x=train_pos+train_neg
test_x=test_pos+test_neg
train_y = np.append(np.ones((len(train_pos), 1)), np.zeros((len(train_neg), 1)), axis=0)
test_y=np.append(np.ones((len(test_pos),1)),np.zeros((len(test_neg),1)),axis=0)

# %%
import re 
import string 
import numpy as np
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer

# %%
def clean_tweets(tweets):
    ct=[]
    for t in tweets:
        t=re.sub(r'@\w*','',t)
        t=re.sub(r'#','',t)
        t=re.sub(r'http\S+','',t)
        t=re.sub(r'[$&\n]\w*','',t)
        t=re.sub(r'[.*]','',t)
#         t=re.sub(r'u','',t)
#         t=re.sub(r'ur','',t)
#         t=re.sub(r'[`^()-]','',t)
        ct.append(t)
    return ct

# %%
def tok_stem_tweets(clean_tweets):
    st=[]
    tokenizer=TweetTokenizer(preserve_case=False,strip_handles=True,reduce_len=True)
    stemmer=PorterStemmer()
    sw=stopwords.words('english')
    for t in clean_tweets:
        tokens=tokenizer.tokenize(t)
        stem_tweet=[]
        for word in tokens:
            if(word not in sw and word not in string.punctuation):
                stem_word=stemmer.stem(word)
                stem_tweet.append(stem_word)
        st.append(stem_tweet)
    return st

# %%
def gen_freq_table(stem_tweets,target):
    freq={}
    target=np.squeeze(target).tolist()
    for y,tweet in zip(target,stem_tweets):
        for word in tweet:
            pair=(word,y)
            if pair in freq:
                freq[pair]+=1
            else:
                freq[pair]=1
    return freq

# %%
def gen_features(stem_tweets,freq):
    feature_matrix=[]
    for t in stem_tweets:
        t_features=[1]
        pos=0
        neg=0
        for word in t:
            try:
                pos=pos+freq[(word,1)]
            except:
                None
            try:
                neg=neg+freq[(word,0)]
            except:
                None
        t_features.append(pos)
        t_features.append(neg)
        feature_matrix.append(t_features)
    return feature_matrix

# %%
cleanx1=clean_tweets(train_x)

# %%
stemx1=tok_stem_tweets(cleanx1)

# %%
freq=gen_freq_table(stemx1,train_y)
freq
# Out:
# {('followfriday', 1.0): 23,
#  ('top', 1.0): 29,
#  ('engag', 1.0): 7,
#  ('member', 1.0): 14,
#  ('commun', 1.0): 27,
#  ('week', 1.0): 72,
#  (':)', 1.0): 2960,
#  ('hey', 1.0): 58,
#  ('jame', 1.0): 7,
#  ('odd', 1.0): 2,
#  (':/', 1.0): 5,
#  ('pleas', 1.0): 80,
#  ('call', 1.0): 27,
#  ('contact', 1.0): 4,
#  ('centr', 1.0): 1,
#  ('02392441234', 1.0): 1,
#  ('abl', 1.0): 6,
#  ('assist', 1.0): 1,
#  ('mani', 1.0): 28,
#  ('thank', 1.0): 510,
#  ('listen', 1.0): 15,
#  ('last', 1.0): 39,
#  ('night', 1.0): 55,
#  ('bleed', 1.0): 2,
#  ('amaz', 1.0): 41,
#  ('track', 1.0): 5,
#  ('scotland', 1.0): 2,
#  ('congrat', 1.0): 15,
#  ('yeaaah', 1.0): 1,
#  ('yipppi', 1.0): 1,
#  ('accnt', 1.0): 2,
#  ('verifi', 1.0): 2,
#  ('rqst', 1.0): 1,
#  ('succeed', 1.0): 1,
#  ('got', 1.0): 56,
#  ('blue', 1.0): 8,
#  ('tick', 1.0): 1,
#  ('mark', 1.0): 1,
#  ('fb', 1.0): 4,
#  ('profil', 1.0): 2,
#  ('15', 1.0): 4,
#  ('day', 1.0): 185,
#  ('one', 1.0): 91,
#  ('irresist', 1.0): 2,
#  ('like', 1.0): 186,
#  ('keep', 1.0): 54,
#  ('love', 1.0): 291,
#  ('custom', 1.0): 3,
#  ('wait', 1.0): 54,
#  ('long', 1.0): 27,
#  ('hope', 1.0): 110,
#  ('enjoy', 1.0): 56,
#  ('happi', 1.0): 159,
#  ('friday', 1.0): 91,
#  ('lwwf', 1.0): 1,
#  ('second', 1.0): 8,
#  ('thought', 1.0): 21,
#  ('’', 1.0): 17,
#  ('enough', 1.0): 16,
#  ('time', 1.0): 101,
#  ('dd', 1.0): 1,
#  ('new', 1.0): 112,
#  ('short', 1.0): 6,
#  ('enter', 1.0): 9,
#  ('system', 1.0): 2,
#  ('sheep', 1.0): 1,
#  ('must', 1.0): 13,
#  ('buy', 1.0): 10,
#  ('jgh', 1.0): 4,
#  ('go', 1.0): 123,
#  ('bayan', 1.0): 1,
#  (':D', 1.0): 523,
#  ('bye', 1.0): 4,
#  ('act', 1.0): 6,
#  ('mischiev', 1.0): 1,
#  ('etl', 1.0): 1,
#  ('layer', 1.0): 1,
#  ('in-hous', 1.0): 1,
#  ('wareh', 1.0): 1,
#  ('app', 1.0): 12,
#  ('katamari', 1.0): 1,
#  ('…', 1.0): 31,
#  ('name', 1.0): 12,
#  ('impli', 1.0): 1,
#  (':p', 1.0): 104,
#  ('influenc', 1.0): 16,
#  ('bigjuicyselfi', 1.0): 3,
#  ('follow', 1.0): 383,
#  ('u', 1.0): 200,
#  ('back', 1.0): 139,
#  ('perfect', 1.0): 17,
#  ('alreadi', 1.0): 19,
#  ('know', 1.0): 128,
#  ("what'", 1.0): 14,
#  ('great', 1.0): 134,
#  ('opportun', 1.0): 17,
#  ('junior', 1.0): 2,
#  ('triathlet', 1.0): 1,
#  ('age', 1.0): 2,
#  ('12', 1.0): 5,
#  ('13', 1.0): 5,
#  ('gatorad', 1.0): 1,
#  ('seri', 1.0): 4,
#  ('get', 1.0): 166,
#  ('entri', 1.0): 3,
#  ('lay', 1.0): 3,
#  ('greet', 1.0): 4,
#  ('card', 1.0): 6,
#  ('rang', 1.0): 2,
#  ('print', 1.0): 4,
#  ('today', 1.0): 91,
#  ('job', 1.0): 34,
#  (':-)', 1.0): 552,
#  ("friend'", 1.0): 3,
#  ('lunch', 1.0): 3,
#  ('yummm', 1.0): 1,
#  ('tb', 1.0): 1,
#  ('ku', 1.0): 1,
#  ('id', 1.0): 8,
#  ('conflict', 1.0): 1,
#  ('help', 1.0): 39,
#  ("here'", 1.0): 20,
#  ('screenshot', 1.0): 2,
#  ('work', 1.0): 89,
#  ('hi', 1.0): 154,
#  ('liv', 1.0): 2,
#  ('hello', 1.0): 48,
#  ('need', 1.0): 62,
#  ('someth', 1.0): 25,
#  ('fm', 1.0): 2,
#  ('twitter', 1.0): 25,
#  ('—', 1.0): 22,
#  ('sure', 1.0): 37,
#  ('thing', 1.0): 48,
#  ('dm', 1.0): 34,
#  ('x', 1.0): 50,
#  ("i'v", 1.0): 24,
#  ('heard', 1.0): 9,
#  ('four', 1.0): 5,
#  ('season', 1.0): 5,
#  ('pretti', 1.0): 17,
#  ('dope', 1.0): 2,
#  ('penthous', 1.0): 1,
#  ('obv', 1.0): 1,
#  ('gobigorgohom', 1.0): 1,
#  ('fun', 1.0): 45,
#  ("y'all", 1.0): 4,
#  ('yeah', 1.0): 30,
#  ('suppos', 1.0): 6,
#  ('lol', 1.0): 46,
#  ('chat', 1.0): 9,
#  ('bit', 1.0): 16,
#  ('youth', 1.0): 14,
#  ('💅', 1.0): 1,
#  ('🏽', 1.0): 1,
#  ('💋', 1.0): 2,
#  ('seen', 1.0): 6,
#  ('year', 1.0): 33,
#  ('rest', 1.0): 8,
#  ('goe', 1.0): 4,
#  ('quickli', 1.0): 3,
#  ('bed', 1.0): 8,
#  ('music', 1.0): 14,
#  ('fix', 1.0): 6,
#  ('dream', 1.0): 17,
#  ('spiritu', 1.0): 1,
#  ('ritual', 1.0): 1,
#  ('festiv', 1.0): 7,
#  ('népal', 1.0): 1,
#  ('line-up', 1.0): 4,
#  ('left', 1.0): 10,
#  ('sarah', 1.0): 4,
#  ('send', 1.0): 17,
#  ('us', 1.0): 96,
#  ('email', 1.0): 22,
#  ('bitsycom', 1.0): 1,
#  ("we'll", 1.0): 12,
#  ('asap', 1.0): 5,
#  ('kik', 1.0): 16,
#  ('hatessuc', 1.0): 1,
#  ('32429', 1.0): 1,
#  ('kikm', 1.0): 1,
#  ('lgbt', 1.0): 2,
#  ('tinder', 1.0): 1,
#  ('nsfw', 1.0): 1,
#  ('akua', 1.0): 1,
#  ('cumshot', 1.0): 1,
#  ('come', 1.0): 63,
#  ('hous', 1.0): 5,
#  ('nsn_supplement', 1.0): 1,
#  ('effect', 1.0): 2,
#  ('press', 1.0): 1,
#  ('releas', 1.0): 11,
#  ('distribut', 1.0): 1,
#  ('result', 1.0): 2,
#  ('link', 1.0): 14,
#  ('remov', 1.0): 3,
#  ('pressreleas', 1.0): 1,
#  ('newsdistribut', 1.0): 1,
#  ('bam', 1.0): 44,
#  ('bestfriend', 1.0): 50,
#  ('lot', 1.0): 80,
#  ('warsaw', 1.0): 44,
#  ('3', 1.0): 145,
#  ('x46', 1.0): 1,
#  ('everyon', 1.0): 45,
#  ('watch', 1.0): 32,
#  ('documentari', 1.0): 1,
#  ('earthl', 1.0): 1,
#  ('youtub', 1.0): 8,
#  ('support', 1.0): 25,
#  ('buuut', 1.0): 1,
#  ('oh', 1.0): 44,
#  ('well', 1.0): 64,
#  ('look', 1.0): 110,
#  ('forward', 1.0): 20,
#  ('visit', 1.0): 24,
#  ('next', 1.0): 37,
#  ('letsgetmessi', 1.0): 1,
#  ('jo', 1.0): 1,
#  ('make', 1.0): 69,
#  ('feel', 1.0): 32,
#  ('better', 1.0): 40,
#  ('never', 1.0): 31,
#  ('see', 1.0): 111,
#  ('anyon', 1.0): 7,
#  ('kpop', 1.0): 1,
#  ('flesh', 1.0): 1,
#  ('good', 1.0): 188,
#  ('girl', 1.0): 34,
#  ('best', 1.0): 48,
#  ('wish', 1.0): 29,
#  ('reason', 1.0): 10,
#  ('epic', 1.0): 1,
#  ('soundtrack', 1.0): 1,
#  ('shout', 1.0): 11,
#  ('ad', 1.0): 10,
#  ('video', 1.0): 30,
#  ('playlist', 1.0): 5,
#  ('im', 1.0): 41,
#  ('twitch', 1.0): 7,
#  ('leagu', 1.0): 6,
#  ('1', 1.0): 61,
#  ('4', 1.0): 23,
#  ('would', 1.0): 70,
#  ('dear', 1.0): 15,
#  ('jordan', 1.0): 1,
#  ('okay', 1.0): 31,
#  ('fake', 1.0): 1,
#  ('gameplay', 1.0): 1,
#  (';)', 1.0): 22,
#  ('haha', 1.0): 44,
#  ('kid', 1.0): 13,
#  ('stuff', 1.0): 11,
#  ('exactli', 1.0): 5,
#  ('product', 1.0): 11,
#  ('line', 1.0): 6,
#  ('etsi', 1.0): 1,
#  ('shop', 1.0): 12,
#  ('check', 1.0): 38,
#  ('boxroomcraft', 1.0): 1,
#  ('vacat', 1.0): 5,
#  ('recharg', 1.0): 1,
#  ('normal', 1.0): 5,
#  ('charger', 1.0): 2,
#  ('asleep', 1.0): 7,
#  ('talk', 1.0): 37,
#  ('sooo', 1.0): 6,
#  ('someon', 1.0): 29,
#  ('text', 1.0): 12,
#  ('ye', 1.0): 56,
#  ('bet', 1.0): 6,
#  ("he'll", 1.0): 2,
#  ('fit', 1.0): 2,
#  ('hear', 1.0): 24,
#  ('speech', 1.0): 1,
#  ('piti', 1.0): 2,
#  ('green', 1.0): 2,
#  ('garden', 1.0): 5,
#  ('midnight', 1.0): 1,
#  ('sun', 1.0): 6,
#  ('beauti', 1.0): 45,
#  ('canal', 1.0): 1,
#  ('dasvidaniya', 1.0): 1,
#  ('till', 1.0): 16,
#  ('scout', 1.0): 1,
#  ('sg', 1.0): 1,
#  ('futur', 1.0): 9,
#  ('wlan', 1.0): 1,
#  ('pro', 1.0): 4,
#  ('confer', 1.0): 1,
#  ('asia', 1.0): 1,
#  ('chang', 1.0): 20,
#  ('lollipop', 1.0): 1,
#  ('🍭', 1.0): 1,
#  ('nez', 1.0): 1,
#  ('agnezmo', 1.0): 1,
#  ('big', 1.0): 25,
#  ('oley', 1.0): 1,
#  ('mama', 1.0): 1,
#  ('stand', 1.0): 6,
#  ('stronger', 1.0): 1,
#  ('god', 1.0): 14,
#  ('misti', 1.0): 1,
#  ('babi', 1.0): 17,
#  ('cute', 1.0): 21,
#  ('woohoo', 1.0): 3,
#  ("can't", 1.0): 31,
#  ('sign', 1.0): 9,
#  ('yet', 1.0): 12,
#  ('still', 1.0): 37,
#  ('think', 1.0): 54,
#  ('mka', 1.0): 5,
#  ('liam', 1.0): 5,
#  ('access', 1.0): 3,
#  ('welcom', 1.0): 54,
#  ('stat', 1.0): 51,
#  ('arriv', 1.0): 57,
#  ('unfollow', 1.0): 53,
#  ('via', 1.0): 73,
#  ('surprisedy', 1.0): 1,
#  ('figur', 1.0): 5,
#  ('happybirthdayemilybett', 1.0): 1,
#  ('sweet', 1.0): 16,
#  ('talent', 1.0): 4,
#  ('2', 1.0): 40,
#  ('plan', 1.0): 21,
#  ('drain', 1.0): 1,
#  ('gotta', 1.0): 4,
#  ('timezon', 1.0): 1,
#  ('parent', 1.0): 4,
#  ('proud', 1.0): 10,
#  ('least', 1.0): 14,
#  ('mayb', 1.0): 17,
#  ('sometim', 1.0): 11,
#  ('grade', 1.0): 4,
#  ('al', 1.0): 3,
#  ('grand', 1.0): 4,
#  ('manila_bro', 1.0): 1,
#  ('chosen', 1.0): 1,
#  ('let', 1.0): 70,
#  ('aroundat', 1.0): 1,
#  ('side', 1.0): 13,
#  ('world', 1.0): 23,
#  ('eh', 1.0): 2,
#  ('take', 1.0): 29,
#  ('care', 1.0): 12,
#  ('final', 1.0): 24,
#  ('fuck', 1.0): 20,
#  ('weekend', 1.0): 61,
#  ('real', 1.0): 18,
#  ('x45', 1.0): 1,
#  ('join', 1.0): 21,
#  ('hushedcallwithfraydo', 1.0): 1,
#  ('gift', 1.0): 7,
#  ('yeahhh', 1.0): 1,
#  ('hushedpinwithsammi', 1.0): 2,
#  ('event', 1.0): 8,
#  ('might', 1.0): 21,
#  ('luv', 1.0): 4,
#  ('realli', 1.0): 66,
#  ('appreci', 1.0): 28,
#  ('share', 1.0): 41,
#  ('around', 1.0): 13,
#  ('wow', 1.0): 13,
#  ('tom', 1.0): 6,
#  ('gym', 1.0): 3,
#  ('monday', 1.0): 7,
#  ('invit', 1.0): 15,
#  ('scope', 1.0): 5,
#  ('friend', 1.0): 42,
#  ('nude', 1.0): 1,
#  ('sleep', 1.0): 35,
#  ('birthday', 1.0): 53,
#  ('want', 1.0): 71,
#  ('t-shirt', 1.0): 2,
#  ('cool', 1.0): 29,
#  ('haw', 1.0): 1,
#  ('phela', 1.0): 1,
#  ('mom', 1.0): 7,
#  ('obvious', 1.0): 1,
#  ('princ', 1.0): 1,
#  ('charm', 1.0): 1,
#  ('stage', 1.0): 2,
#  ('luck', 1.0): 26,
#  ('tyler', 1.0): 1,
#  ('hipster', 1.0): 1,
#  ('glass', 1.0): 3,
#  ('marti', 1.0): 2,
#  ('glad', 1.0): 41,
#  ('done', 1.0): 40,
#  ('afternoon', 1.0): 7,
#  ('read', 1.0): 28,
#  ('kahfi', 1.0): 1,
#  ('finish', 1.0): 15,
#  ('ohmyg', 1.0): 1,
#  ('yaya', 1.0): 3,
#  ('dub', 1.0): 1,
#  ('stalk', 1.0): 2,
#  ('ig', 1.0): 3,
#  ('gondooo', 1.0): 1,
#  ('moo', 1.0): 2,
#  ('tologooo', 1.0): 1,
#  ('becom', 1.0): 8,
#  ('detail', 1.0): 8,
#  ('zzz', 1.0): 1,
#  ('xx', 1.0): 33,
#  ('physiotherapi', 1.0): 1,
#  ('hashtag', 1.0): 3,
#  ('💪', 1.0): 1,
#  ('monica', 1.0): 1,
#  ('miss', 1.0): 17,
#  ('sound', 1.0): 20,
#  ('morn', 1.0): 65,
#  ("that'", 1.0): 48,
#  ('x43', 1.0): 1,
#  ('definit', 1.0): 20,
#  ('tri', 1.0): 34,
#  ('tonight', 1.0): 15,
#  ('took', 1.0): 7,
#  ('advic', 1.0): 6,
#  ('treviso', 1.0): 1,
#  ('concert', 1.0): 22,
#  ('citi', 1.0): 26,
#  ('countri', 1.0): 22,
#  ("i'll", 1.0): 74,
#  ('start', 1.0): 56,
#  ('fine', 1.0): 7,
#  ('gorgeou', 1.0): 9,
#  ('xo', 1.0): 2,
#  ('oven', 1.0): 2,
#  ('roast', 1.0): 1,
#  ('garlic', 1.0): 1,
#  ('oliv', 1.0): 1,
#  ('oil', 1.0): 4,
#  ('dri', 1.0): 4,
#  ('tomato', 1.0): 1,
#  ('basil', 1.0): 1,
#  ('centuri', 1.0): 1,
#  ('tuna', 1.0): 1,
#  ('right', 1.0): 38,
#  ('atchya', 1.0): 1,
#  ('even', 1.0): 26,
#  ('almost', 1.0): 8,
#  ('chanc', 1.0): 3,
#  ('cheer', 1.0): 17,
#  ('po', 1.0): 3,
#  ('ice', 1.0): 6,
#  ('cream', 1.0): 6,
#  ('agre', 1.0): 13,
#  ('100', 1.0): 6,
#  ('heheheh', 1.0): 2,
#  ('that', 1.0): 10,
#  ('point', 1.0): 11,
#  ('stay', 1.0): 19,
#  ('home', 1.0): 20,
#  ('soon', 1.0): 38,
#  ('promis', 1.0): 4,
#  ('web', 1.0): 4,
#  ('whatsapp', 1.0): 2,
#  ('volta', 1.0): 1,
#  ('funcionar', 1.0): 1,
#  ('com', 1.0): 2,
#  ('iphon', 1.0): 7,
#  ('jailbroken', 1.0): 1,
#  ('later', 1.0): 12,
#  ('34', 1.0): 3,
#  ('min', 1.0): 7,
#  ('leia', 1.0): 1,
#  ('appear', 1.0): 3,
#  ('hologram', 1.0): 1,
#  ('r2d2', 1.0): 1,
#  ('w', 1.0): 12,
#  ('messag', 1.0): 9,
#  ('obi', 1.0): 1,
#  ('wan', 1.0): 1,
#  ('sit', 1.0): 7,
#  ('luke', 1.0): 4,
#  ('inter', 1.0): 1,
#  ('ucl', 1.0): 1,
#  ('arsen', 1.0): 2,
#  ('small', 1.0): 2,
#  ('team', 1.0): 24,
#  ('pass', 1.0): 10,
#  ('🚂', 1.0): 1,
#  ('dewsburi', 1.0): 2,
#  ('railway', 1.0): 1,
#  ('station', 1.0): 4,
#  ('dew', 1.0): 1,
#  ('west', 1.0): 1,
#  ('yorkshir', 1.0): 2,
#  ('430', 1.0): 1,
#  ('smh', 1.0): 2,
#  ('9:25', 1.0): 1,
#  ('live', 1.0): 23,
#  ('strang', 1.0): 4,
#  ('imagin', 1.0): 5,
#  ('megan', 1.0): 1,
#  ('shweta', 1.0): 1,
#  ('tripathi', 1.0): 1,
#  ('5', 1.0): 15,
#  ('20', 1.0): 7,
#  ('kurta', 1.0): 3,
#  ('half', 1.0): 6,
#  ('number', 1.0): 11,
#  ('wsalelov', 1.0): 9,
#  ('ah', 1.0): 11,
#  ('larri', 1.0): 3,
#  ('anyway', 1.0): 14,
#  ('kinda', 1.0): 12,
#  ('goood', 1.0): 1,
#  ('life', 1.0): 36,
#  ('enn', 1.0): 1,
#  ('could', 1.0): 25,
#  ('warmup', 1.0): 1,
#  ('15th', 1.0): 2,
#  ('bath', 1.0): 6,
#  ('dum', 1.0): 2,
#  ('andar', 1.0): 1,
#  ('ram', 1.0): 1,
#  ('sampath', 1.0): 1,
#  ('sona', 1.0): 1,
#  ('mohapatra', 1.0): 1,
#  ('samantha', 1.0): 1,
#  ('edward', 1.0): 1,
#  ('mein', 1.0): 1,
#  ('tulan', 1.0): 1,
#  ('razi', 1.0): 2,
#  ('wah', 1.0): 2,
#  ('josh', 1.0): 1,
#  ('alway', 1.0): 48,
#  ('smile', 1.0): 47,
#  ('pictur', 1.0): 7,
#  ('1620', 1.0): 1,
#  ('giveitup', 1.0): 1,
#  ('given', 1.0): 3,
#  ('ga', 1.0): 3,
#  ('subsidi', 1.0): 1,
#  ('initi', 1.0): 2,
#  ('propos', 1.0): 3,
#  ('delight', 1.0): 4,
#  ('yesterday', 1.0): 4,
#  ('x42', 1.0): 1,
#  ('lmaoo', 1.0): 2,
#  ('song', 1.0): 16,
#  ('ever', 1.0): 19,
#  ('shall', 1.0): 5,
#  ('littl', 1.0): 29,
#  ('throwback', 1.0): 3,
#  ('outli', 1.0): 1,
#  ('island', 1.0): 2,
#  ('cheung', 1.0): 1,
#  ('chau', 1.0): 1,
#  ('mui', 1.0): 1,
#  ('wotot', 1.0): 1,
#  ('differ', 1.0): 10,
#  ('kfckitchentour', 1.0): 2,
#  ('kitchen', 1.0): 3,
#  ('clean', 1.0): 1,
#  ("i'm", 1.0): 139,
#  ('total', 1.0): 5,
#  ('cusp', 1.0): 1,
#  ('test', 1.0): 7,
#  ('water', 1.0): 7,
#  ('reward', 1.0): 1,
#  ('arummzz', 1.0): 2,
#  ("let'", 1.0): 20,
#  ('drive', 1.0): 9,
#  ('travel', 1.0): 16,
#  ('yogyakarta', 1.0): 3,
#  ('jeep', 1.0): 3,
#  ('indonesia', 1.0): 3,
#  ('instamood', 1.0): 3,
#  ('wanna', 1.0): 21,
#  ('skype', 1.0): 3,
#  ('may', 1.0): 15,
#  ('nice', 1.0): 71,
#  ('friendli', 1.0): 1,
#  ('pretend', 1.0): 2,
#  ('film', 1.0): 8,
#  ('congratul', 1.0): 8,
#  ('winner', 1.0): 3,
#  ('cheesydelight', 1.0): 1,
#  ('contest', 1.0): 5,
#  ('address', 1.0): 8,
#  ('guy', 1.0): 48,
#  ('market', 1.0): 5,
#  ('24/7', 1.0): 1,
#  ('regret', 1.0): 4,
#  ('14', 1.0): 1,
#  ('hour', 1.0): 24,
#  ('leav', 1.0): 12,
#  ('without', 1.0): 9,
#  ('delay', 1.0): 1,
#  ('actual', 1.0): 13,
#  ('easi', 1.0): 7,
#  ('guess', 1.0): 8,
#  ('train', 1.0): 7,
#  ('wd', 1.0): 1,
#  ('shift', 1.0): 4,
#  ('engin', 1.0): 1,
#  ('etc', 1.0): 2,
#  ('sunburn', 1.0): 1,
#  ('peel', 1.0): 2,
#  ('blog', 1.0): 27,
#  ('huge', 1.0): 9,
#  ('warm', 1.0): 4,
#  ('☆', 1.0): 3,
#  ('complet', 1.0): 10,
#  ('triangl', 1.0): 2,
#  ('northern', 1.0): 1,
#  ('ireland', 1.0): 2,
#  ('sight', 1.0): 1,
#  ('smthng', 1.0): 2,
#  ('fr', 1.0): 3,
#  ('ulolwanna', 1.0): 1,
#  ('hug', 1.0): 11,
#  ('uxoxolov', 1.0): 1,
#  ('uu', 1.0): 1,
#  ('jaann', 1.0): 1,
#  ('topnewfollow', 1.0): 2,
#  ('connect', 1.0): 13,
#  ('wonder', 1.0): 26,
#  ('made', 1.0): 38,
#  ('fluffi', 1.0): 1,
#  ('insid', 1.0): 7,
#  ('pirouett', 1.0): 1,
#  ('moos', 1.0): 1,
#  ('trip', 1.0): 11,
#  ('philli', 1.0): 1,
#  ('decemb', 1.0): 2,
#  ("i'd", 1.0): 13,
#  ('dude', 1.0): 6,
#  ('x41', 1.0): 1,
#  ('question', 1.0): 15,
#  ('flaw', 1.0): 1,
#  ('pain', 1.0): 8,
#  ('negat', 1.0): 1,
#  ('strength', 1.0): 2,
#  ('went', 1.0): 9,
#  ('solo', 1.0): 4,
#  ('move', 1.0): 9,
#  ('fav', 1.0): 11,
#  ('nirvana', 1.0): 1,
#  ('smell', 1.0): 2,
#  ('teen', 1.0): 3,
#  ('spirit', 1.0): 1,
#  ('rip', 1.0): 3,
#  ('ami', 1.0): 4,
#  ('winehous', 1.0): 1,
#  ('coupl', 1.0): 5,
#  ('tomhiddleston', 1.0): 1,
#  ('elizabetholsen', 1.0): 1,
#  ('yaytheylookgreat', 1.0): 1,
#  ('goodnight', 1.0): 18,
#  ('vid', 1.0): 8,
#  ('wake', 1.0): 10,
#  ('gonna', 1.0): 16,
#  ('shoot', 1.0): 5,
#  ('itti', 1.0): 2,
#  ('bitti', 1.0): 2,
#  ('teeni', 1.0): 2,
#  ('bikini', 1.0): 3,
#  ('much', 1.0): 72,
#  ('4th', 1.0): 4,
#  ('togeth', 1.0): 6,
#  ('xfile', 1.0): 1,
#  ('surpris', 1.0): 9,
#  ('rain', 1.0): 18,
#  ('fabul', 1.0): 4,
#  ('fantast', 1.0): 9,
#  ('♡', 1.0): 12,
#  ('jb', 1.0): 1,
#  ('forev', 1.0): 5,
#  ('belieb', 1.0): 3,
#  ('nighti', 1.0): 1,
#  ('bug', 1.0): 2,
#  ('bite', 1.0): 1,
#  ('bracelet', 1.0): 2,
#  ('idea', 1.0): 24,
#  ('foundri', 1.0): 1,
#  ('game', 1.0): 23,
#  ('sens', 1.0): 6,
#  ('pic', 1.0): 21,
#  ('ef', 1.0): 1,
#  ('phone', 1.0): 16,
#  ('woot', 1.0): 2,
#  ('derek', 1.0): 1,
#  ('use', 1.0): 32,
#  ('parkshar', 1.0): 1,
#  ('gloucestershir', 1.0): 1,
#  ('aaaahhh', 1.0): 1,
#  ('man', 1.0): 16,
#  ('traffic', 1.0): 2,
#  ('stress', 1.0): 4,
#  ('reliev', 1.0): 1,
#  ("how'r", 1.0): 1,
#  ('arbeloa', 1.0): 1,
#  ('turn', 1.0): 14,
#  ('17', 1.0): 2,
#  ('daysomg', 1.0): 1,
#  ('say', 1.0): 43,
#  ('europ', 1.0): 1,
#  ('rise', 1.0): 2,
#  ('find', 1.0): 22,
#  ('hard', 1.0): 9,
#  ('believ', 1.0): 7,
#  ('uncount', 1.0): 1,
#  ('coz', 1.0): 2,
#  ('unlimit', 1.0): 1,
#  ('cours', 1.0): 10,
#  ('teamposit', 1.0): 1,
#  ('aldub', 1.0): 2,
#  ('☕', 1.0): 3,
#  ('rita', 1.0): 2,
#  ('info', 1.0): 11,
#  ("we'd", 1.0): 4,
#  ('way', 1.0): 33,
#  ('boy', 1.0): 13,
#  ('x40', 1.0): 1,
#  ('true', 1.0): 19,
#  ('sethi', 1.0): 2,
#  ('high', 1.0): 6,
#  ('exe', 1.0): 1,
#  ('skeem', 1.0): 1,
#  ('saam', 1.0): 1,
#  ('peopl', 1.0): 42,
#  ('polit', 1.0): 2,
#  ('izzat', 1.0): 1,
#  ('trust', 1.0): 7,
#  ('khawateen', 1.0): 1,
#  ('k', 1.0): 6,
#  ('sath', 1.0): 2,
#  ('selfi', 1.0): 8,
#  ('mana', 1.0): 1,
#  ('kar', 1.0): 1,
#  ('deya', 1.0): 1,
#  ('sort', 1.0): 7,
#  ('smart', 1.0): 5,
#  ('hair', 1.0): 7,
#  ('tbh', 1.0): 5,
#  ('jacob', 1.0): 2,
#  ('g', 1.0): 8,
#  ('upgrad', 1.0): 2,
#  ('tee', 1.0): 3,
#  ('famili', 1.0): 14,
#  ('person', 1.0): 14,
#  ('two', 1.0): 15,
#  ('convers', 1.0): 6,
#  ('onlin', 1.0): 4,
#  ('mclaren', 1.0): 1,
#  ('fridayfeel', 1.0): 5,
#  ('tgif', 1.0): 7,
#  ('squar', 1.0): 1,
#  ('enix', 1.0): 1,
#  ('bissmillah', 1.0): 1,
#  ('ya', 1.0): 19,
#  ('allah', 1.0): 3,
#  ("we'r", 1.0): 25,
#  ('socent', 1.0): 1,
#  ('startup', 1.0): 2,
#  ('drop', 1.0): 8,
#  ('your', 1.0): 3,
#  ('arnd', 1.0): 1,
#  ('town', 1.0): 3,
#  ('basic', 1.0): 4,
#  ('piss', 1.0): 2,
#  ('cup', 1.0): 4,
#  ('also', 1.0): 28,
#  ('terribl', 1.0): 2,
#  ('complic', 1.0): 1,
#  ('discuss', 1.0): 2,
#  ('snapchat', 1.0): 31,
#  ('lynettelow', 1.0): 1,
#  ('kikmenow', 1.0): 2,
#  ('snapm', 1.0): 1,
#  ('hot', 1.0): 19,
#  ('amazon', 1.0): 1,
#  ('kikmeguy', 1.0): 2,
#  ('defin', 1.0): 2,
#  ('grow', 1.0): 6,
#  ('sport', 1.0): 4,
#  ('rt', 1.0): 8,
#  ('rakyat', 1.0): 1,
#  ('write', 1.0): 11,
#  ('sinc', 1.0): 11,
#  ('mention', 1.0): 18,
#  ('fli', 1.0): 5,
#  ('fish', 1.0): 4,
#  ('promot', 1.0): 3,
#  ('post', 1.0): 16,
#  ('cyber', 1.0): 1,
#  ('ourdaughtersourprid', 1.0): 3,
#  ('mypapamyprid', 1.0): 2,
#  ('papa', 1.0): 1,
#  ('coach', 1.0): 2,
#  ('posit', 1.0): 3,
#  ('kha', 1.0): 1,
#  ('atleast', 1.0): 2,
#  ('x39', 1.0): 1,
#  ('mango', 1.0): 1,
#  ("lassi'", 1.0): 1,
#  ("monty'", 1.0): 1,
#  ('marvel', 1.0): 1,
#  ('though', 1.0): 16,
#  ('suspect', 1.0): 3,
#  ('meant', 1.0): 2,
#  ('24', 1.0): 3,
#  ('hr', 1.0): 2,
#  ('touch', 1.0): 7,
#  ('kepler', 1.0): 3,
#  ('452b', 1.0): 4,
#  ('chalna', 1.0): 1,
#  ('hai', 1.0): 7,
#  ('thankyou', 1.0): 12,
#  ('hazel', 1.0): 1,
#  ('food', 1.0): 10,
#  ('brooklyn', 1.0): 1,
#  ('pta', 1.0): 2,
#  ('awak', 1.0): 8,
#  ('okayi', 1.0): 2,
#  ('awww', 1.0): 12,
#  ('ha', 1.0): 19,
#  ('doc', 1.0): 1,
#  ('splendid', 1.0): 1,
#  ('spam', 1.0): 1,
#  ('folder', 1.0): 1,
#  ('amount', 1.0): 1,
#  ('nigeria', 1.0): 1,
#  ('claim', 1.0): 1,
#  ('rted', 1.0): 1,
#  ('leg', 1.0): 3,
#  ('hurt', 1.0): 4,
#  ('bad', 1.0): 14,
#  ('mine', 1.0): 11,
#  ('saturday', 1.0): 5,
#  ('thaaank', 1.0): 1,
#  ('puhon', 1.0): 1,
#  ('happinesss', 1.0): 1,
#  ('tnc', 1.0): 1,
#  ('prior', 1.0): 1,
#  ('notif', 1.0): 2,
#  ('probabl', 1.0): 8,
#  ('funni', 1.0): 16,
#  ('2:22', 1.0): 1,
#  ('fat', 1.0): 1,
#  ('co', 1.0): 1,
#  ('ate', 1.0): 4,
#  ('yuna', 1.0): 2,
#  ('tamesid', 1.0): 1,
#  ('´', 1.0): 3,
#  ('googl', 1.0): 5,
#  ('account', 1.0): 17,
#  ('scouser', 1.0): 1,
#  ('everyth', 1.0): 10,
#  ('zoe', 1.0): 1,
#  ('mate', 1.0): 5,
#  ('liter', 1.0): 6,
#  ("they'r", 1.0): 10,
#  ('samee', 1.0): 1,
#  ('edgar', 1.0): 1,
#  ('updat', 1.0): 12,
#  ('log', 1.0): 3,
#  ('bring', 1.0): 12,
#  ('abe', 1.0): 1,
#  ('meet', 1.0): 26,
#  ('x38', 1.0): 1,
#  ('sigh', 1.0): 3,
#  ('dreamili', 1.0): 1,
#  ('pout', 1.0): 1,
#  ('eye', 1.0): 11,
#  ('quacketyquack', 1.0): 6,
#  ('happen', 1.0): 13,
#  ('phil', 1.0): 1,
#  ('em', 1.0): 2,
#  ('del', 1.0): 1,
#  ('rodder', 1.0): 1,
#  ('els', 1.0): 8,
#  ('play', 1.0): 36,
#  ('newest', 1.0): 1,
#  ('gamejam', 1.0): 1,
#  ('irish', 1.0): 2,
#  ('literatur', 1.0): 2,
#  ('inaccess', 1.0): 2,
#  ('flipkartfashionfriday', 1.0): 12,
#  ("kareena'", 1.0): 2,
#  ('fan', 1.0): 21,
#  ('brain', 1.0): 9,
#  ('dot', 1.0): 8,
#  ('braindot', 1.0): 8,
#  ('fair', 1.0): 4,
#  ('rush', 1.0): 1,
#  ('either', 1.0): 10,
#  ('brandi', 1.0): 1,
#  ('18', 1.0): 5,
#  ('carniv', 1.0): 1,
#  ('men', 1.0): 8,
#  ('put', 1.0): 11,
#  ('mask', 1.0): 2,
#  ('xavier', 1.0): 1,
#  ('forneret', 1.0): 1,
#  ('jennif', 1.0): 1,
#  ('site', 1.0): 7,
#  ('free', 1.0): 32,
#  ('5000', 1.0): 3,
#  ('8', 1.0): 11,
#  ('ball', 1.0): 7,
#  ('pool', 1.0): 5,
#  ('coin', 1.0): 5,
#  ('edit', 1.0): 6,
#  ('trish', 1.0): 1,
#  ('♥', 1.0): 13,
#  ('grate', 1.0): 5,
#  ('three', 1.0): 8,
#  ('comment', 1.0): 8,
#  ('wakeup', 1.0): 1,
#  ('besid', 1.0): 2,
#  ('dirti', 1.0): 2,
#  ('sex', 1.0): 4,
#  ('lmaooo', 1.0): 1,
#  ('😤', 1.0): 2,
#  ('loui', 1.0): 4,
#  ("he'", 1.0): 11,
#  ('throw', 1.0): 3,
#  ('caus', 1.0): 11,
#  ('inspir', 1.0): 6,
#  ('ff', 1.0): 40,
#  ('twoof', 1.0): 3,
#  ('gr8', 1.0): 1,
#  ('wkend', 1.0): 3,
#  ('kind', 1.0): 22,
#  ('exhaust', 1.0): 2,
#  ('word', 1.0): 17,
#  ('cheltenham', 1.0): 1,
#  ('area', 1.0): 4,
#  ('kale', 1.0): 1,
#  ('crisp', 1.0): 1,
#  ('ruin', 1.0): 5,
#  ('x37', 1.0): 1,
#  ('open', 1.0): 12,
#  ('worldwid', 1.0): 2,
#  ('outta', 1.0): 1,
#  ('sfvbeta', 1.0): 1,
#  ('vantast', 1.0): 1,
#  ('xcylin', 1.0): 1,
#  ('bundl', 1.0): 1,
#  ('show', 1.0): 19,
#  ('internet', 1.0): 2,
#  ('price', 1.0): 3,
#  ('realisticli', 1.0): 1,
#  ('pay', 1.0): 8,
#  ('net', 1.0): 1,
#  ('educ', 1.0): 1,
#  ('power', 1.0): 6,
#  ('weapon', 1.0): 1,
#  ('nelson', 1.0): 1,
#  ('mandela', 1.0): 1,
#  ('recent', 1.0): 8,
#  ('j', 1.0): 2,
#  ('chenab', 1.0): 1,
#  ('flow', 1.0): 5,
#  ('pakistan', 1.0): 1,
#  ('teenchoic', 1.0): 7,
#  ('choiceinternationalartist', 1.0): 7,
#  ('superjunior', 1.0): 7,
#  ('caught', 1.0): 4,
#  ('first', 1.0): 41,
#  ('salmon', 1.0): 1,
#  ('super-blend', 1.0): 1,
#  ('project', 1.0): 6,
#  ('youthorguk', 1.0): 1,
#  ('awesom', 1.0): 34,
#  ('stream', 1.0): 12,
#  ('artist', 1.0): 2,
#  ('alma', 1.0): 1,
#  ('mater', 1.0): 1,
#  ('highschoolday', 1.0): 1,
#  ('clientvisit', 1.0): 1,
#  ('faith', 1.0): 3,
#  ('christian', 1.0): 1,
#  ('school', 1.0): 9,
#  ('lizaminnelli', 1.0): 1,
#  ('upcom', 1.0): 2,
#  ('uk', 1.0): 4,
#  ('😄', 1.0): 3,
#  ('singl', 1.0): 4,
#  ('hill', 1.0): 4,
#  ('everi', 1.0): 23,
#  ('beat', 1.0): 7,
#  ('wrong', 1.0): 9,
#  ('readi', 1.0): 22,
#  ('natur', 1.0): 1,
#  ('pefumeri', 1.0): 1,
#  ('workshop', 1.0): 2,
#  ('neal', 1.0): 1,
#  ('yard', 1.0): 1,
#  ('covent', 1.0): 1,
#  ('tomorrow', 1.0): 31,
#  ('fback', 1.0): 26,
#  ('indo', 1.0): 1,
#  ...}

# %%
x1=gen_features(stemx1,freq)

# %%
x1
# Out:
# [[1, 3132, 61],
#  [1, 3690, 406],
#  [1, 3119, 116],
#  [1, 2975, 4],
#  [1, 3229, 226],
#  [1, 3053, 120],
#  [1, 3992, 535],
#  [1, 3277, 278],
#  [1, 655, 188],
#  [1, 199, 65],
#  [1, 3127, 55],
#  [1, 3254, 130],
#  [1, 4065, 738],
#  [1, 3192, 205],
#  [1, 3412, 262],
#  [1, 987, 239],
#  [1, 2969, 10],
#  [1, 1192, 248],
#  [1, 3116, 30],
#  [1, 3641, 536],
#  [1, 3606, 344],
#  [1, 3074, 113],
#  [1, 3117, 122],
#  [1, 3622, 447],
#  [1, 3003, 57],
#  [1, 1062, 93],
#  [1, 3342, 406],
#  [1, 2988, 26],
#  [1, 3214, 129],
#  [1, 569, 29],
#  [1, 3001, 124],
#  [1, 3028, 87],
#  [1, 2997, 25],
#  [1, 4297, 525],
#  [1, 639, 80],
#  [1, 4065, 738],
#  [1, 3136, 79],
#  [1, 661, 126],
#  [1, 817, 170],
#  [1, 1015, 561],
#  [1, 851, 177],
#  [1, 791, 169],
#  [1, 3706, 119],
#  [1, 3496, 529],
#  [1, 6462, 338],
#  [1, 1108, 200],
#  [1, 3521, 544],
#  [1, 2995, 42],
#  [1, 3141, 78],
#  [1, 895, 287],
#  [1, 3241, 239],
#  [1, 3132, 61],
#  [1, 3206, 288],
#  [1, 750, 170],
#  [1, 3098, 77],
#  [1, 2978, 10],
#  [1, 3410, 285],
#  [1, 3307, 198],
#  [1, 6425, 490],
#  [1, 524, 0],
#  [1, 2978, 12],
#  [1, 4065, 738],
#  [1, 620, 165],
#  [1, 3259, 134],
#  [1, 3165, 391],
#  [1, 2968, 4],
#  [1, 3014, 7],
#  [1, 3935, 445],
#  [1, 3007, 19],
#  [1, 3127, 55],
#  [1, 3175, 125],
#  [1, 3341, 182],
#  [1, 400, 135],
#  [1, 979, 313],
#  [1, 2964, 4],
#  [1, 4263, 607],
#  [1, 1067, 390],
#  [1, 3606, 344],
#  [1, 3065, 102],
#  [1, 2978, 19],
#  [1, 1033, 93],
#  [1, 4297, 525],
#  [1, 950, 310],
#  [1, 2961, 3],
#  [1, 3158, 176],
#  [1, 1142, 475],
#  [1, 3208, 208],
#  [1, 3622, 447],
#  [1, 3068, 97],
#  [1, 3251, 130],
#  [1, 3618, 564],
#  [1, 3136, 79],
#  [1, 4065, 738],
#  [1, 3241, 377],
#  [1, 3095, 27],
#  [1, 3130, 143],
#  [1, 607, 40],
#  [1, 3318, 400],
#  [1, 3935, 445],
#  [1, 739, 149],
#  [1, 625, 187],
#  [1, 3562, 527],
#  [1, 3014, 50],
#  [1, 3240, 194],
#  [1, 3935, 445],
#  [1, 3132, 61],
#  [1, 528, 2],
#  [1, 3139, 128],
#  [1, 3226, 120],
#  [1, 1102, 111],
#  [1, 3288, 222],
#  [1, 3101, 154],
#  [1, 3032, 10],
#  [1, 3127, 55],
#  [1, 3504, 112],
#  [1, 741, 97],
#  [1, 3345, 486],
#  [1, 3335, 198],
#  [1, 4297, 525],
#  [1, 3240, 381],
#  [1, 4065, 738],
#  [1, 4367, 701],
#  [1, 3111, 49],
#  [1, 2987, 15],
#  [1, 3502, 286],
#  [1, 1100, 394],
#  [1, 2977, 12],
#  [1, 3606, 344],
#  [1, 2963, 16],
#  [1, 2977, 5],
#  [1, 3098, 239],
#  [1, 2979, 12],
#  [1, 127, 18],
#  [1, 3137, 231],
#  [1, 3470, 95],
#  [1, 3136, 79],
#  [1, 3002, 45],
#  [1, 570, 7],
#  [1, 3087, 140],
#  [1, 3173, 112],
#  [1, 2984, 19],
#  [1, 2963, 5],
#  [1, 5989, 55],
#  [1, 554, 0],
#  [1, 593, 60],
#  [1, 3161, 122],
#  [1, 3188, 108],
#  [1, 4065, 738],
#  [1, 3679, 257],
#  [1, 3192, 190],
#  [1, 3028, 50],
#  [1, 3055, 59],
#  [1, 2967, 16],
#  [1, 3776, 430],
#  [1, 3132, 61],
#  [1, 3088, 113],
#  [1, 3234, 326],
#  [1, 573, 246],
#  [1, 4297, 525],
#  [1, 443, 180],
#  [1, 3100, 192],
#  [1, 3151, 292],
#  [1, 4065, 738],
#  [1, 3086, 106],
#  [1, 3127, 55],
#  [1, 391, 257],
#  [1, 554, 96],
#  [1, 817, 157],
#  [1, 3189, 289],
#  [1, 3022, 70],
#  [1, 3130, 76],
#  [1, 3203, 83],
#  [1, 3606, 344],
#  [1, 3199, 198],
#  [1, 3040, 46],
#  [1, 3757, 645],
#  [1, 865, 324],
#  [1, 555, 2],
#  [1, 1084, 103],
#  [1, 4367, 701],
#  [1, 3036, 86],
#  [1, 661, 48],
#  [1, 2993, 53],
#  [1, 4065, 738],
#  [1, 3136, 79],
#  [1, 3935, 445],
#  [1, 3200, 256],
#  [1, 3477, 105],
#  [1, 3644, 115],
#  [1, 811, 229],
#  [1, 3347, 236],
#  [1, 4297, 525],
#  [1, 2987, 25],
#  [1, 583, 65],
#  [1, 838, 244],
#  [1, 3132, 61],
#  [1, 389, 257],
#  [1, 2992, 46],
#  [1, 3792, 575],
#  [1, 1226, 458],
#  [1, 566, 10],
#  [1, 2969, 2],
#  [1, 1142, 475],
#  [1, 3393, 489],
#  [1, 530, 5],
#  [1, 3261, 283],
#  [1, 4065, 738],
#  [1, 3207, 144],
#  [1, 4936, 1674],
#  [1, 3127, 55],
#  [1, 3025, 25],
#  [1, 3172, 110],
#  [1, 660, 81],
#  [1, 3219, 104],
#  [1, 3015, 38],
#  [1, 3169, 206],
#  [1, 3341, 370],
#  [1, 3208, 173],
#  [1, 2989, 41],
#  [1, 3606, 344],
#  [1, 3067, 99],
#  [1, 667, 254],
#  [1, 3183, 132],
#  [1, 3108, 185],
#  [1, 3264, 135],
#  [1, 3027, 47],
#  [1, 901, 167],
#  [1, 3481, 98],
#  [1, 3562, 408],
#  [1, 3006, 43],
#  [1, 957, 315],
#  [1, 4297, 525],
#  [1, 3136, 79],
#  [1, 2979, 21],
#  [1, 3618, 564],
#  [1, 2968, 10],
#  [1, 2963, 2],
#  [1, 3118, 157],
#  [1, 3485, 96],
#  [1, 5993, 66],
#  [1, 1234, 203],
#  [1, 2965, 3],
#  [1, 635, 45],
#  [1, 3008, 50],
#  [1, 564, 10],
#  [1, 3050, 43],
#  [1, 744, 60],
#  [1, 728, 142],
#  [1, 3061, 42],
#  [1, 3123, 193],
#  [1, 600, 26],
#  [1, 2964, 15],
#  [1, 614, 9],
#  [1, 3132, 61],
#  [1, 3764, 397],
#  [1, 4065, 738],
#  [1, 2985, 16],
#  [1, 3389, 244],
#  [1, 2977, 13],
#  [1, 2997, 33],
#  [1, 3018, 51],
#  [1, 3079, 221],
#  [1, 3214, 205],
#  [1, 726, 131],
#  [1, 3007, 59],
#  [1, 3105, 66],
#  [1, 1550, 922],
#  [1, 2978, 12],
#  [1, 694, 55],
#  [1, 3502, 551],
#  [1, 4297, 525],
#  [1, 596, 94],
#  [1, 3127, 55],
#  [1, 814, 284],
#  [1, 4065, 738],
#  [1, 2989, 16],
#  [1, 2999, 20],
#  [1, 3005, 114],
#  [1, 525, 0],
#  [1, 3482, 114],
#  [1, 3204, 218],
#  [1, 3065, 111],
#  [1, 3175, 91],
#  [1, 2981, 92],
#  [1, 734, 202],
#  [1, 2964, 4],
#  [1, 2961, 2],
#  [1, 755, 231],
#  [1, 599, 55],
#  [1, 1585, 26],
#  [1, 3006, 22],
#  [1, 1656, 0],
#  [1, 3017, 11],
#  [1, 2982, 24],
#  [1, 3178, 177],
#  [1, 1358, 780],
#  [1, 3025, 49],
#  [1, 3647, 377],
#  [1, 571, 8],
#  [1, 2973, 10],
#  [1, 3914, 460],
#  [1, 3026, 81],
#  [1, 599, 90],
#  [1, 1125, 97],
#  [1, 4065, 738],
#  [1, 4297, 525],
#  [1, 643, 94],
#  [1, 3463, 164],
#  [1, 569, 3],
#  [1, 30, 47],
#  [1, 3012, 39],
#  [1, 3605, 360],
#  [1, 3273, 180],
#  [1, 3047, 57],
#  [1, 3083, 47],
#  [1, 3138, 147],
#  [1, 3622, 447],
#  [1, 3000, 33],
#  [1, 3099, 83],
#  [1, 3005, 12],
#  [1, 200, 304],
#  [1, 3178, 182],
#  [1, 3031, 43],
#  [1, 4065, 738],
#  [1, 578, 10],
#  [1, 3966, 545],
#  [1, 3316, 164],
#  [1, 3300, 169],
#  [1, 872, 150],
#  [1, 3204, 223],
#  [1, 827, 362],
#  [1, 3438, 268],
#  [1, 3155, 289],
#  [1, 3066, 67],
#  [1, 3499, 487],
#  [1, 1361, 391],
#  [1, 3267, 340],
#  [1, 3846, 432],
#  [1, 3622, 492],
#  [1, 812, 156],
#  [1, 4297, 525],
#  [1, 2974, 14],
#  [1, 710, 230],
#  [1, 3138, 158],
#  [1, 3137, 184],
#  [1, 829, 345],
#  [1, 3521, 161],
#  [1, 3064, 99],
#  [1, 4065, 738],
#  [1, 901, 199],
#  [1, 2981, 17],
#  [1, 660, 109],
#  [1, 3416, 156],
#  [1, 4230, 712],
#  [1, 3272, 451],
#  [1, 5937, 27],
#  [1, 776, 96],
#  [1, 529, 504],
#  [1, 625, 68],
#  [1, 3167, 173],
#  [1, 3186, 85],
#  [1, 3201, 236],
#  [1, 2988, 2],
#  [1, 2961, 2],
#  [1, 552, 0],
#  [1, 3429, 210],
#  [1, 3017, 61],
#  [1, 1107, 134],
#  [1, 2972, 20],
#  [1, 4704, 1204],
#  [1, 551, 38],
#  [1, 3117, 107],
#  [1, 4065, 738],
#  [1, 3475, 830],
#  [1, 3165, 389],
#  [1, 2960, 2],
#  [1, 4367, 701],
#  [1, 3620, 294],
#  [1, 2977, 4],
#  [1, 3036, 76],
#  [1, 3055, 67],
#  [1, 873, 152],
#  [1, 907, 207],
#  [1, 3237, 210],
#  [1, 815, 290],
#  [1, 3579, 119],
#  [1, 3251, 130],
#  [1, 3030, 70],
#  [1, 2980, 7],
#  [1, 702, 188],
#  [1, 2965, 6],
#  [1, 3040, 136],
#  [1, 1102, 97],
#  [1, 1177, 199],
#  [1, 124, 19],
#  [1, 2978, 8],
#  [1, 4297, 525],
#  [1, 2972, 3],
#  [1, 3470, 95],
#  [1, 2961, 2],
#  [1, 2993, 27],
#  [1, 4065, 738],
#  [1, 3167, 152],
#  [1, 646, 87],
#  [1, 3000, 20],
#  [1, 3645, 671],
#  [1, 1101, 130],
#  [1, 2973, 12],
#  [1, 2976, 7],
#  [1, 3717, 302],
#  [1, 1480, 310],
#  [1, 228, 114],
#  [1, 3109, 109],
#  [1, 2148, 482],
#  [1, 3323, 210],
#  [1, 3580, 332],
#  [1, 3202, 263],
#  [1, 533, 5],
#  [1, 711, 304],
#  [1, 3470, 95],
#  [1, 3181, 95],
#  [1, 531, 5],
#  [1, 4065, 738],
#  [1, 3237, 210],
#  [1, 462, 374],
#  [1, 1158, 5],
#  [1, 540, 12],
#  [1, 3167, 190],
#  [1, 3078, 90],
#  [1, 667, 44],
#  [1, 3154, 104],
#  [1, 1072, 726],
#  [1, 2989, 4],
#  [1, 3486, 347],
#  [1, 580, 42],
#  [1, 620, 72],
#  [1, 3622, 447],
#  [1, 4065, 738],
#  [1, 3402, 385],
#  [1, 649, 72],
#  [1, 1258, 596],
#  [1, 3266, 175],
#  [1, 526, 5],
#  [1, 3207, 133],
#  [1, 3021, 67],
#  [1, 525, 1],
#  [1, 2971, 9],
#  [1, 3935, 445],
#  [1, 4023, 391],
#  [1, 584, 39],
#  [1, 583, 38],
#  [1, 3095, 17],
#  [1, 4065, 738],
#  [1, 3450, 428],
#  [1, 3170, 339],
#  [1, 3133, 243],
#  [1, 3470, 95],
#  [1, 4367, 701],
#  [1, 286, 186],
#  [1, 3726, 715],
#  [1, 3085, 56],
#  [1, 3032, 54],
#  [1, 348, 270],
#  [1, 3142, 103],
#  [1, 524, 2],
#  [1, 3470, 95],
#  [1, 3323, 205],
#  [1, 2961, 2],
#  [1, 809, 339],
#  [1, 3033, 54],
#  [1, 757, 224],
#  [1, 3131, 56],
#  [1, 3414, 304],
#  [1, 2999, 47],
#  [1, 2962, 2],
#  [1, 3568, 125],
#  [1, 3153, 134],
#  [1, 815, 128],
#  [1, 6420, 300],
#  [1, 2966, 2],
#  [1, 598, 34],
#  [1, 975, 328],
#  [1, 2977, 6],
#  [1, 549, 24],
#  [1, 2981, 9],
#  [1, 3108, 124],
#  [1, 858, 149],
#  [1, 3027, 9],
#  [1, 3754, 561],
#  [1, 3845, 502],
#  [1, 3589, 154],
#  [1, 3313, 231],
#  [1, 200, 304],
#  [1, 3240, 354],
#  [1, 3413, 207],
#  [1, 3597, 233],
#  [1, 660, 27],
#  [1, 2997, 7],
#  [1, 3220, 376],
#  [1, 660, 64],
#  [1, 526, 2],
#  [1, 576, 4],
#  [1, 3095, 67],
#  [1, 3470, 95],
#  [1, 3889, 437],
#  [1, 1038, 93],
#  [1, 3023, 41],
#  [1, 2972, 45],
#  [1, 696, 332],
#  [1, 3492, 120],
#  [1, 105, 0],
#  [1, 2966, 2],
#  [1, 4065, 738],
#  [1, 795, 304],
#  [1, 3170, 128],
#  [1, 2972, 8],
#  [1, 2985, 3],
#  [1, 657, 159],
#  [1, 220, 285],
#  [1, 3218, 156],
#  [1, 3356, 293],
#  [1, 3096, 198],
#  [1, 645, 107],
#  [1, 2989, 19],
#  [1, 3041, 71],
#  [1, 854, 234],
#  [1, 1094, 471],
#  [1, 3980, 410],
#  [1, 3605, 110],
#  [1, 3370, 726],
#  [1, 1033, 93],
#  [1, 2980, 6],
#  [1, 1319, 298],
#  [1, 4065, 738],
#  [1, 1112, 225],
#  [1, 3069, 225],
#  [1, 1101, 130],
#  [1, 842, 130],
#  [1, 716, 235],
#  [1, 3014, 38],
#  [1, 3195, 42],
#  [1, 3016, 41],
#  [1, 3145, 66],
#  [1, 3639, 194],
#  [1, 555, 0],
#  [1, 3026, 88],
#  [1, 3449, 396],
#  [1, 4248, 594],
#  [1, 3207, 188],
#  [1, 3252, 33],
#  [1, 3294, 182],
#  [1, 937, 221],
#  [1, 3022, 40],
#  [1, 3627, 152],
#  [1, 554, 0],
#  [1, 3890, 563],
#  [1, 557, 5],
#  [1, 3054, 134],
#  [1, 3343, 248],
#  [1, 2986, 6],
#  [1, 710, 154],
#  [1, 1050, 268],
#  [1, 4367, 701],
#  [1, 3014, 7],
#  [1, 1084, 103],
#  [1, 3164, 58],
#  [1, 4065, 738],
#  [1, 586, 20],
#  [1, 3056, 25],
#  [1, 3599, 504],
#  [1, 968, 87],
#  [1, 132, 20],
#  [1, 161, 28],
#  [1, 3223, 76],
#  [1, 3413, 484],
#  [1, 1596, 588],
#  [1, 3036, 29],
#  [1, 2991, 31],
#  [1, 3410, 235],
#  [1, 3402, 341],
#  [1, 3518, 140],
#  [1, 3503, 120],
#  [1, 3400, 389],
#  [1, 3494, 472],
#  [1, 2962, 3],
#  [1, 552, 0],
#  [1, 3226, 156],
#  [1, 4065, 738],
#  [1, 3178, 117],
#  [1, 2983, 26],
#  [1, 3881, 639],
#  [1, 3482, 345],
#  [1, 566, 28],
#  [1, 3102, 120],
#  [1, 3218, 225],
#  [1, 3162, 89],
#  [1, 3202, 222],
#  [1, 622, 52],
#  [1, 4704, 1204],
#  [1, 3053, 55],
#  [1, 3826, 252],
#  [1, 3031, 19],
#  [1, 3627, 593],
#  [1, 3452, 484],
#  [1, 154, 81],
#  [1, 3220, 259],
#  [1, 793, 368],
#  [1, 685, 123],
#  [1, 3470, 95],
#  [1, 588, 22],
#  [1, 586, 82],
#  [1, 2961, 3],
#  [1, 6858, 427],
#  [1, 677, 165],
#  [1, 3935, 445],
#  [1, 2961, 4],
#  [1, 4065, 738],
#  [1, 3202, 244],
#  [1, 3679, 331],
#  [1, 3145, 117],
#  [1, 3633, 388],
#  [1, 675, 80],
#  [1, 3051, 144],
#  [1, 595, 275],
#  [1, 1181, 23],
#  [1, 3001, 41],
#  [1, 3258, 33],
#  [1, 4065, 738],
#  [1, 3331, 369],
#  [1, 2967, 5],
#  [1, 653, 56],
#  [1, 3284, 172],
#  [1, 951, 408],
#  [1, 2219, 8],
#  [1, 2978, 18],
#  [1, 4297, 525],
#  [1, 3165, 294],
#  [1, 769, 196],
#  [1, 526, 1],
#  [1, 602, 476],
#  [1, 2997, 28],
#  [1, 559, 8],
#  [1, 3049, 136],
#  [1, 757, 114],
#  [1, 554, 0],
#  [1, 837, 291],
#  [1, 4065, 738],
#  [1, 2994, 70],
#  [1, 2990, 27],
#  [1, 563, 7],
#  [1, 3138, 191],
#  [1, 1444, 365],
#  [1, 560, 4],
#  [1, 3008, 50],
#  [1, 3629, 641],
#  [1, 1074, 112],
#  [1, 3503, 137],
#  [1, 488, 827],
#  [1, 3488, 394],
#  [1, 3966, 520],
#  [1, 2977, 17],
#  [1, 3245, 93],
#  [1, 2981, 5],
#  [1, 3192, 398],
#  [1, 905, 268],
#  [1, 3080, 171],
#  [1, 3139, 129],
#  [1, 1083, 396],
#  [1, 9033, 266],
#  [1, 3523, 141],
#  [1, 578, 208],
#  [1, 3122, 79],
#  [1, 4065, 738],
#  [1, 3001, 20],
#  [1, 3568, 301],
#  [1, 3007, 31],
#  [1, 3126, 145],
#  [1, 568, 37],
#  [1, 568, 47],
#  [1, 3177, 174],
#  [1, 3054, 63],
#  [1, 3005, 12],
#  [1, 631, 71],
#  [1, 1135, 285],
#  [1, 3560, 220],
#  [1, 552, 0],
#  [1, 3929, 410],
#  [1, 695, 164],
#  [1, 3562, 551],
#  [1, 3049, 100],
#  [1, 729, 85],
#  [1, 3029, 23],
#  [1, 4297, 525],
#  [1, 3425, 454],
#  [1, 6091, 45],
#  [1, 1162, 263],
#  [1, 9459, 146],
#  [1, 3022, 64],
#  [1, 3635, 399],
#  [1, 510, 93],
#  [1, 718, 126],
#  [1, 2995, 8],
#  [1, 4065, 738],
#  [1, 3033, 61],
#  [1, 3026, 55],
#  [1, 9627, 425],
#  [1, 3557, 234],
#  [1, 1449, 293],
#  [1, 3008, 50],
#  [1, 3252, 143],
#  [1, 3015, 90],
#  [1, 560, 5],
#  [1, 3317, 184],
#  [1, 524, 1],
#  [1, 760, 236],
#  [1, 3470, 95],
#  [1, 3810, 590],
#  [1, 3256, 132],
#  [1, 855, 299],
#  [1, 843, 128],
#  [1, 2982, 29],
#  [1, 3100, 110],
#  [1, 856, 139],
#  [1, 577, 5],
#  [1, 3309, 227],
#  [1, 3057, 81],
#  [1, 1239, 479],
#  [1, 5923, 17],
#  [1, 3045, 89],
#  [1, 6238, 336],
#  [1, 3364, 339],
#  [1, 4367, 701],
#  [1, 3935, 445],
#  [1, 3316, 227],
#  [1, 4065, 738],
#  [1, 212, 157],
#  [1, 852, 119],
#  [1, 663, 154],
#  [1, 3237, 125],
#  [1, 3078, 90],
#  [1, 3010, 25],
#  [1, 3095, 17],
#  [1, 7345, 402],
#  [1, 3177, 37],
#  [1, 876, 232],
#  [1, 2983, 15],
#  [1, 2980, 11],
#  [1, 2976, 25],
#  [1, 1322, 523],
#  [1, 650, 163],
#  [1, 934, 205],
#  [1, 3099, 264],
#  [1, 1077, 323],
#  [1, 3436, 113],
#  [1, 1525, 338],
#  [1, 3362, 251],
#  [1, 3058, 83],
#  [1, 3014, 7],
#  [1, 3318, 344],
#  [1, 3262, 134],
#  [1, 2971, 13],
#  [1, 3051, 90],
#  [1, 3236, 213],
#  [1, 3333, 370],
#  [1, 8966, 44],
#  [1, 3802, 231],
#  [1, 4065, 738],
#  [1, 2962, 2],
#  [1, 3128, 116],
#  [1, 3746, 352],
#  [1, 2973, 16],
#  [1, 3482, 509],
#  [1, 3208, 239],
#  [1, 2961, 2],
#  [1, 2985, 26],
#  [1, 3885, 732],
#  [1, 425, 337],
#  [1, 856, 264],
#  [1, 4065, 738],
#  [1, 790, 237],
#  [1, 2978, 3],
#  [1, 206, 125],
#  [1, 3240, 236],
#  [1, 576, 6],
#  [1, 903, 227],
#  [1, 3207, 486],
#  [1, 3226, 286],
#  [1, 541, 9],
#  [1, 3074, 141],
#  [1, 3382, 282],
#  [1, 2964, 8],
#  [1, 1033, 93],
#  [1, 697, 34],
#  [1, 819, 172],
#  [1, 3148, 84],
#  [1, 3036, 36],
#  [1, 4367, 701],
#  [1, 3149, 237],
#  [1, 3534, 189],
#  [1, 2980, 11],
#  [1, 2978, 32],
#  [1, 3033, 95],
#  [1, 3105, 142],
#  [1, 4065, 738],
#  [1, 3450, 174],
#  [1, 585, 37],
#  [1, 3071, 64],
#  [1, 753, 218],
#  [1, 3098, 237],
#  [1, 2982, 26],
#  [1, 2986, 2],
#  [1, 3490, 590],
#  [1, 719, 161],
#  [1, 715, 232],
#  [1, 3091, 212],
#  [1, 3379, 396],
#  [1, 3878, 439],
#  [1, 3479, 110],
#  [1, 3275, 211],
#  [1, 634, 97],
#  [1, 2981, 21],
#  [1, 3506, 125],
#  [1, 3835, 207],
#  [1, 4065, 738],
#  [1, 2975, 4],
#  [1, 4098, 542],
#  [1, 3298, 232],
#  [1, 162, 8],
#  [1, 3002, 29],
#  [1, 3107, 38],
#  [1, 6028, 182],
#  [1, 563, 25],
#  [1, 2966, 9],
#  [1, 3218, 237],
#  [1, 557, 5],
#  [1, 2961, 2],
#  [1, 3097, 92],
#  [1, 76, 97],
#  [1, 3093, 198],
#  [1, 3508, 115],
#  [1, 685, 152],
#  [1, 3225, 108],
#  [1, 3457, 860],
#  [1, 1555, 403],
#  [1, 561, 0],
#  [1, 3471, 95],
#  [1, 3344, 248],
#  [1, 2986, 2],
#  [1, 2980, 11],
#  [1, 3366, 445],
#  [1, 3482, 345],
#  [1, 1499, 644],
#  [1, 3730, 280],
#  [1, 3072, 79],
#  [1, 712, 48],
#  [1, 3364, 229],
#  [1, 3087, 216],
#  [1, 3274, 161],
#  [1, 3208, 368],
#  [1, 3057, 94],
#  [1, 3242, 203],
#  [1, 3232, 309],
#  [1, 2977, 18],
#  [1, 3052, 89],
#  [1, 3054, 87],
#  [1, 3171, 130],
#  [1, 3267, 151],
#  [1, 3166, 42],
#  [1, 3006, 43],
#  [1, 3561, 141],
#  [1, 3276, 329],
#  [1, 3385, 255],
#  [1, 1083, 309],
#  [1, 3030, 58],
#  [1, 3349, 496],
#  [1, 536, 1],
#  [1, 3244, 170],
#  [1, 3308, 329],
#  [1, 3018, 22],
#  [1, 3850, 567],
#  [1, 2966, 8],
#  [1, 3163, 179],
#  [1, 3486, 105],
#  [1, 1366, 323],
#  [1, 2975, 3],
#  [1, 690, 83],
#  [1, 3472, 95],
#  [1, 2986, 2],
#  [1, 1081, 106],
#  [1, 3261, 131],
#  [1, 3260, 245],
#  [1, 3471, 96],
#  [1, 4704, 1204],
#  [1, 5939, 39],
#  [1, 3966, 563],
#  [1, 555, 0],
#  [1, 691, 113],
#  [1, 2985, 18],
#  [1, 3171, 292],
#  [1, 873, 267],
#  [1, 2988, 40],
#  [1, 1199, 425],
#  [1, 793, 289],
#  [1, 3257, 140],
#  [1, 1096, 117],
#  [1, 3041, 79],
#  [1, 3273, 48],
#  [1, 609, 16],
#  [1, 3622, 447],
#  [1, 2993, 35],
#  [1, 774, 302],
#  [1, 3179, 203],
#  [1, 3043, 92],
#  [1, 3162, 161],
#  [1, 3482, 275],
#  [1, 753, 314],
#  [1, 2980, 40],
#  [1, 2972, 4],
#  [1, 4065, 738],
#  [1, 599, 112],
#  [1, 3164, 180],
#  [1, 954, 463],
#  [1, 3177, 237],
#  [1, 3447, 260],
#  [1, 3095, 27],
#  [1, 121, 55],
#  [1, 1157, 303],
#  [1, 2998, 14],
#  [1, 3196, 183],
#  [1, 555, 0],
#  [1, 2986, 2],
#  [1, 555, 0],
#  [1, 2998, 14],
#  [1, 3708, 562],
#  [1, 4065, 738],
#  [1, 3606, 148],
#  [1, 3036, 111],
#  [1, 2971, 7],
#  [1, 2989, 3],
#  [1, 2985, 23],
#  [1, 3350, 378],
#  [1, 787, 129],
#  [1, 1555, 348],
#  [1, 2961, 2],
#  [1, 3486, 347],
#  [1, 3039, 13],
#  [1, 3134, 200],
#  [1, 2998, 14],
#  [1, 3175, 89],
#  [1, 3016, 40],
#  [1, 3090, 222],
#  [1, 3287, 329],
#  [1, 3276, 324],
#  [1, 3609, 186],
#  [1, 3255, 164],
#  [1, 2970, 5],
#  [1, 2973, 20],
#  [1, 2992, 25],
#  [1, 3261, 216],
#  [1, 2986, 2],
#  [1, 530, 9],
#  [1, 3111, 248],
#  [1, 3268, 299],
#  [1, 1416, 339],
#  [1, 3914, 460],
#  [1, 3472, 95],
#  [1, 4297, 525],
#  [1, 4065, 738],
#  [1, 560, 29],
#  [1, 3520, 343],
#  [1, 272, 161],
#  [1, 751, 237],
#  [1, 2964, 9],
#  [1, 639, 40],
#  [1, 3106, 212],
#  [1, 1084, 103],
#  [1, 3153, 91],
#  [1, 3296, 78],
#  [1, 3326, 193],
#  [1, 1520, 400],
#  [1, 840, 152],
#  [1, 3413, 302],
#  [1, 3689, 481],
#  [1, 3163, 66],
#  [1, 580, 41],
#  [1, 523, 0],
#  [1, 3099, 254],
#  [1, 619, 10],
#  [1, 3316, 387],
#  [1, 664, 77],
#  [1, 943, 340],
#  [1, 200, 304],
#  [1, 669, 136],
#  [1, 2984, 11],
#  [1, 3511, 103],
#  [1, 2986, 2],
#  [1, 4065, 738],
#  [1, 742, 36],
#  [1, 1062, 93],
#  [1, 3196, 304],
#  ...]

# %%
cleanx2=clean_tweets(test_x)

# %%
stemx2=tok_stem_tweets(cleanx2)
stemx2
# Out:
# [['bro',
#   'u',
#   'wan',
#   'cut',
#   'hair',
#   'anot',
#   'ur',
#   'hair',
#   'long',
#   'liao',
#   'bo',
#   'sinc',
#   'ord',
#   'liao',
#   'take',
#   'easi',
#   'lor',
#   'treat',
#   'save',
#   'leav',
#   'longer',
#   ':)',
#   'lol',
#   'sibei',
#   'xialan'],
#  ['back', 'thnx', 'god', "i'm", 'happi', ':)'],
#  ['thought',
#   'ear',
#   'malfunct',
#   'thank',
#   'good',
#   'clear',
#   'one',
#   'apolog',
#   ':-)'],
#  ['stuck', 'centr', 'right', 'clown', 'right', 'joker', 'left', ':)'],
#  ['happi', 'friday', ':-)'],
#  ['follow', ':)', 'x'],
#  ['teenchoic',
#   'choiceinternationalartist',
#   'superjunior',
#   'fight',
#   'oppa',
#   ':D'],
#  ['birthday',
#   'today',
#   'birthday',
#   'wish',
#   'hope',
#   "there'",
#   'good',
#   'news',
#   'ben',
#   'soon',
#   ':-)'],
#  ['good',
#   'morn',
#   ':-)',
#   'friday',
#   '\U000fec00',
#   'plan',
#   'day',
#   'current',
#   'play',
#   'shop'],
#  ['happi', 'friday', ':)'],
#  ['3', 'good', 'nigth', ':)', 'estoy', 'escuchando', 'enemi', 'god'],
#  ['actual', 'bye', 'bye', 'inde', 'go', 'take', 'drama', 'elsewher', ':)'],
#  ['ff', 'weekend', ':)', 'smile'],
#  ['work', ':)'],
#  [':)', 'mood', 'bipolar'],
#  ['thank', ':)'],
#  ['hahahahahahahahahahahahahaha', 'die', ':)', 'liter', 'front', 'like'],
#  ['yoohoo', 'shatter', 'record', 'bajrangibhaijaanstorm', 'superhappi', ':D'],
#  ["who'", 'awak', ':-)'],
#  ['happi', 'friday', ':-)'],
#  ['pleasur', 'doll', 'thank', 'wonder', 'energi', 'class', ':)'],
#  ['f', ':)'],
#  ['delight', "m'dear", ':)'],
#  ['hi', 'emma', ':-)', 'ask', 'bellybutton', 'inni', 'outi'],
#  ['followback', 'beauti', 'girl', 'today', ':)'],
#  ['lyka', 'followback', ':)'],
#  ['alrd', 'joy', ':)'],
#  ['ourdaughtersourprid',
#   'dhan',
#   'dhan',
#   'satguru',
#   'tera',
#   'hi',
#   'aasramani',
#   'congratul',
#   'pita',
#   'gkeep',
#   'bless',
#   'alway',
#   ':-)'],
#  ['thank', 'ye', "let'", 'hope', 'work', 'miss', ':-)'],
#  ['keeo',
#   'guess',
#   'what',
#   'behind',
#   'white',
#   'cover',
#   ':)',
#   'special',
#   'happi',
#   'bday',
#   'darl',
#   '…'],
#  ['happi', 'friday', 'everyon', ':)', 'big', 'followfriday'],
#  ['awkward', 'moment', 'name', 'akarshan', 'end', 'stay', 'singl', ':D'],
#  ['know', ':)', 'hot', 'alway'],
#  ['worri',
#   ':)',
#   'know',
#   'much',
#   'stress',
#   'problem',
#   'site',
#   "can't",
#   'wait',
#   'till',
#   'event'],
#  ['say',
#   'sweetpea',
#   'start',
#   'hold',
#   'regular',
#   'gluten',
#   'free',
#   'cake',
#   'pastri',
#   'workshop',
#   ':)'],
#  ['highfiv', 'probabl', 'ahead', 'sinc', 'less', 'artsi', 'verbal', ':D'],
#  ['bae', ':)', '3'],
#  ['kid', 'kaaa', ':p'],
#  ['love',
#   'chat',
#   'cycl',
#   'oxford',
#   'campaign',
#   'way',
#   'home',
#   'yesterday',
#   'cycl',
#   'rout',
#   'pleas',
#   ':)',
#   'cycl',
#   'oxford'],
#  ['wahoo', 'team', ':-)', 'masaantoday'],
#  ['anchor', 'sea', ':)'],
#  ['dat',
#   'rp',
#   'tho',
#   'thank',
#   'much',
#   'guy',
#   'celebr',
#   'one',
#   'month',
#   'partnership',
#   'ty',
#   'raid',
#   ':D'],
#  ['visit',
#   'robbenisland',
#   'cultur',
#   'experi',
#   'tri',
#   'whale',
#   'watch',
#   'aquat',
#   'safari',
#   'either',
#   'great',
#   ':)'],
#  ['least', 'friday', ':D'],
#  ['mayb', 'garru', 'liara', 'rest', 'crew', ':D'],
#  ['thank', 'follow', 'great', 'day', ':)'],
#  ['massag',
#   'appoint',
#   'avail',
#   'tomorrow',
#   'morn',
#   'burnley',
#   'give',
#   'us',
#   'call',
#   'book',
#   ':)',
#   '01282',
#   '453',
#   '110'],
#  ['great', 'hear', 'nice', 'day', 'thank', 'visit', ':)'],
#  ['bore', 'everyth', ':D'],
#  ['drama', 'korea', '49', 'day', ':)'],
#  ['btw',
#   'anyon',
#   'repres',
#   'footbal',
#   'manag',
#   'commun',
#   'youtub',
#   ':)',
#   'fm15',
#   'fmfamili',
#   'vidcon',
#   '2015'],
#  ['mean', 'aamir', 'khan', 'one', ':)'],
#  ['happi', 'friday', ':)'],
#  ['right', 'back', 'excel', 'job', 'difficult', 'medium', ':)'],
#  [':)', 'want', 'ff'],
#  ['tweet', ':p'],
#  ['hey',
#   'come',
#   'see',
#   'us',
#   'summer',
#   'fine',
#   'food',
#   'fair',
#   'sunday',
#   '11am',
#   '4pm',
#   'ride',
#   'school',
#   ':)'],
#  ['pleas', 'follow', 'liam', ':)'],
#  ['love',
#   'write',
#   ':)',
#   'absolut',
#   'ador',
#   'nva',
#   'lucki',
#   'enough',
#   'live',
#   '5',
#   'minuet',
#   'away',
#   'roll',
#   'gamec'],
#  ['ff', 'thank', 'brian', ':)'],
#  ['headrest', 'loos', "that'", 'reason', 'pit', ':-)'],
#  ['hi',
#   "i'v",
#   'spoken',
#   'store',
#   'advis',
#   'paypoint',
#   'card',
#   'top',
#   ':)',
#   'thank',
#   'beth'],
#  ['thank', 'help', ':-)'],
#  ['deepthroat', 'good', 'movi', ':)'],
#  ['hallo', 'twitter', ':D'],
#  ['truli',
#   'later',
#   'move',
#   'know',
#   'queen',
#   'bee',
#   'upward',
#   'bound',
#   'movingonup'],
#  ['thank', 'wish', ':)'],
#  ['aitor',
#   'sn',
#   'would',
#   'mind',
#   'check',
#   'bio',
#   'particip',
#   'ps4',
#   'giveaway',
#   'could',
#   'winner',
#   ':)'],
#  ['hi',
#   'jawad',
#   'today',
#   'thank',
#   'follow',
#   'retweet',
#   'much',
#   'appreci',
#   ':)'],
#  ['thank', ':)'],
#  ['actual', 'need', 'stop', 'tweet', 'drive', ':-)'],
#  ['kind',
#   'feedback',
#   'truli',
#   'made',
#   'day',
#   'perfect',
#   'way',
#   'end',
#   'work',
#   'week',
#   ':)'],
#  ['well',
#   "that'",
#   'presal',
#   'ticket',
#   'bought',
#   'thank',
#   'wonder',
#   'take',
#   'book',
#   'meth',
#   'parent',
#   ':)'],
#  ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow'],
#  ['hope', 'goe', 'well', ':-)'],
#  ['betcha', ':)', 'dumb', 'butt', ':)'],
#  ['kik',
#   'qualki',
#   '808',
#   'kik',
#   'kikmenow',
#   'milf',
#   'like',
#   '4like',
#   'bore',
#   'summer',
#   'sexysaturday',
#   ':)'],
#  ['follow', ':-)'],
#  ['thank', ':)'],
#  ['ye', 'hun', "i'm", 'good', ':)'],
#  ['enjoy', ':)'],
#  ['wow', 'vw', 'bu', 'lot', 'umpfff', 'love', ':)'],
#  ['ca', 'retweet', 'domg', 'nanti', 'difollow', ':D'],
#  ['wish', ':D', ':D', ':D', ':D', ':D', ':D', ':D', 'kid'],
#  ['sure',
#   'would',
#   'good',
#   'thing',
#   '4',
#   'bottom',
#   'dare',
#   '2',
#   'say',
#   '2',
#   'miss',
#   'b',
#   'im',
#   'gonna',
#   'stubborn',
#   'mouth',
#   'soap',
#   'nothavingit',
#   ':p'],
#  ['ye', 'car', ':)'],
#  ['like', 'especi', 'klee', 'one', ':-)'],
#  ['look', 'amaz', 'april', 'love', 'glass', ':D'],
#  ['know', ':)'],
#  ['build', 'hous', ':)'],
#  ['yeah', 'kinda', 'feel', 'like', 'warm', 'butter', ':D'],
#  ['realli', 'week', 'big', 'decis', 'feel', 'rather', 'badass', ':)'],
#  ["i'm",
#   'go',
#   'sleep',
#   'hope',
#   'wake',
#   'follow',
#   'luke',
#   'hem',
#   'someday',
#   ':)',
#   'goodnight',
#   'fam',
#   'ili',
#   '5so',
#   'lot',
#   '💟'],
#  ['congrad', 'better', 'updat', 'page', 'accomplish', ':-)', 'keep'],
#  ['film', 'day', 'invit', 'reason', 'lol', ':)'],
#  [':)'],
#  ['whenev',
#   'sister',
#   'see',
#   'cri',
#   'text',
#   'ask',
#   'im',
#   'okay',
#   'aw',
#   'someon',
#   'care',
#   ':-)'],
#  ['welcom', 'kfcroleplay', 'enjoy', 'let', 'friend', ':)'],
#  ['t-shirt', ':D', 'awesom'],
#  ['belat', 'thank', 'thank', ':D'],
#  ["can't", 'wait', 'see', ':-)'],
#  ['happi', 'happi', 'birthday', 'happi', 'birthday', ':)'],
#  ['take', 'care', ':)'],
#  ['road',
#   'trip',
#   'tregaron',
#   'view',
#   'potenti',
#   'new',
#   'boar',
#   'finger',
#   'cross',
#   'bring',
#   'boy',
#   'home',
#   ':)'],
#  [':)', 'good', 'know', ':)'],
#  ['told',
#   'im',
#   'gorgeou',
#   'extrem',
#   'sweati',
#   'walk',
#   'work',
#   'made',
#   'day',
#   ':)'],
#  ['morn', 'em', ':)'],
#  ['glyon', ':D'],
#  ['💓', '🚮', '👯', 'definit', 'perfect', 'would', 'pictur', 'next', ':)'],
#  ['initi', "tee'", 'order', ':)'],
#  ['confess', ':)', 'nice'],
#  ['welcom', ':)'],
#  ['nice', 'dave', ':D'],
#  ['know',
#   'dumb',
#   'think',
#   'johnni',
#   'rock',
#   'u',
#   'seen',
#   'utub',
#   "video'",
#   'mad',
#   'respect',
#   ':D'],
#  ['sorri', 'loss', 'hope', 'goe', 'well', ':)'],
#  ['combin', 'three', 'add', 'bit', 'asian', 'u', 'got', 'truli', ':)'],
#  ['happi', 'birthday', ':)'],
#  ['got',
#   'call',
#   'end',
#   'pigeon',
#   'home',
#   'safe',
#   ':)',
#   'definit',
#   'worth',
#   'contact'],
#  ['morn',
#   'hospit',
#   'day',
#   'today',
#   'hope',
#   'final',
#   'get',
#   'sign',
#   'long',
#   'year',
#   'pain',
#   'op',
#   'fingerscross',
#   ':)'],
#  ['best', 'photobomb', ':D', 'pic', '—'],
#  ['thank', 'se', ':)'],
#  ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow'],
#  ['finish',
#   'day',
#   '33',
#   'plan',
#   'bibl',
#   '90',
#   'day',
#   'check',
#   '2',
#   'chronicl',
#   '23',
#   'complet',
#   ':)'],
#  ['yo',
#   'gimm',
#   'month',
#   'free',
#   'bill',
#   'sinc',
#   'servic',
#   'pretti',
#   'much',
#   'everi',
#   'day',
#   ':)'],
#  ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via'],
#  ['hi', "i'm", 'definetli', 'exit', "i'm", 'go', 'new', 'york', ':)'],
#  ['saturday', ':)'],
#  ["i'v", 'type', 'wors', 'thing', 'good', ':p'],
#  ['beat',
#   'da',
#   'beat',
#   'sit',
#   'well',
#   'includ',
#   'new',
#   'video',
#   ':-)',
#   'mobilegam',
#   'io',
#   '8',
#   'android'],
#  ["i'm", 'play', 'brain', 'dot', 'braindot'],
#  ['thank', ':)', '💕'],
#  ['soon', ':)'],
#  ['sure', ':)'],
#  ['look',
#   'fun',
#   'kik',
#   'thencerest',
#   '547',
#   'kik',
#   'kiksext',
#   'sex',
#   'followback',
#   'l4l',
#   'indiemus',
#   'kikgirl',
#   ':)'],
#  ['goodnight',
#   'guy',
#   ':-)',
#   'tomorrow',
#   'brand',
#   'new',
#   'day',
#   'fresh',
#   'start',
#   'anoth',
#   'chanc'],
#  ['bom-dia', ':)', 'apod', 'ultraviolet', 'ring', 'm31', '2015', 'jul', '24'],
#  ["i'm", 'play', 'brain', 'dot', 'braindot'],
#  ['thank', 'follow', 'great', 'day', ':)'],
#  ['oooh', 'love', 'hope', 'fantast', 'time', ':)'],
#  ['yawn', 'good', 'morn', 'everyon', 'wag', 'tail', 'everyon', 'today', ':D'],
#  ['congrat', 'launch', ':D'],
#  ['happi', 'wonder', 'birthday', 'love', '💟', 'beauti', 'day', 'world', ':)'],
#  ['ftw', ':)'],
#  ['ah', 'see', 'song', 'prefer', 'take', 'maman', ':)'],
#  ['hi', 'hayley', ':-)', 'ask', 'bellybutton', 'inni', 'outi'],
#  ['gud',
#   'afterznoon',
#   'jumma',
#   'mubarak',
#   'tweeep',
#   ':-)',
#   'rememb',
#   'us',
#   'ur',
#   'prayer'],
#  ['welcom', 'bomb', 'famili', ':)', 'x'],
#  ['abp',
#   'news',
#   'ka',
#   'articl',
#   'read',
#   'kiya',
#   ':D',
#   'bajrangibhaijaanhighestweek',
#   '1'],
#  ['like', 'hurt', 'feel', 'anyth', 'right', ':)'],
#  ['check',
#   'new',
#   'van',
#   'outsid',
#   'olymp',
#   'park',
#   'anniversari',
#   'game',
#   ':)'],
#  ['everi', 'year', 'august', 'get', 'fever', ':p', 'dunno', '😷'],
#  ['yeah',
#   'classi',
#   'look',
#   ':-)',
#   "i'v",
#   'seen',
#   'peopl',
#   'attach',
#   'sort',
#   'life',
#   'save',
#   'equip',
#   'bed',
#   'fix',
#   '0'],
#  ['trend', 'follow', 'bobbl', 'link', ':)'],
#  ['next', 'year', 'sure', 'though', ':)', "there'", '2', 'girl', 'piss'],
#  ['stand', 'cool', ':)'],
#  ['movi', 'key', 'life', 'japanes', 'version', 'interest', 'storylin', ':)'],
#  ['thank', 'anu', ':)'],
#  ['also', 'new', 'layout', 'new', ':)'],
#  ['im', 'tri', 'l', 'mh3', 'english', 'patch', 'psp', ':D'],
#  ['want',
#   'tweet',
#   'someth',
#   'thought',
#   "i'll",
#   'probabl',
#   'lose',
#   'lot',
#   'liam',
#   'girl',
#   'mutual',
#   ':)'],
#  ['1',
#   'day',
#   'go',
#   '1',
#   'day',
#   'left',
#   'sponsor',
#   'us',
#   'matter',
#   'small',
#   'donat',
#   'differ',
#   'make',
#   'huge',
#   ':)'],
#  ['thank', ':)'],
#  ['follow', ':)'],
#  ['hey',
#   'emili',
#   'love',
#   'work',
#   "i'd",
#   'like',
#   'contribut',
#   'huffpost',
#   'busi',
#   "what'",
#   'best',
#   'way',
#   'contact',
#   ':)'],
#  ['asshol', '😂', "that'", 'honest', 'tribut', ':)'],
#  ['h_eartshapedbox',
#   'first',
#   'leg',
#   'magictrikband',
#   'tour',
#   'go',
#   'well',
#   ':D',
#   'music',
#   'band',
#   'rock',
#   'magictrik',
#   'tour',
#   '…'],
#  ['tower', 'ladi', ':)', 'tb', 'eid'],
#  ['whatsapp',
#   'roommat',
#   'want',
#   'anyth',
#   'pari',
#   'french',
#   'man',
#   ':)',
#   'sure',
#   "i'll",
#   'head',
#   'park',
#   'grab',
#   'one'],
#  ['great', 'weekend', 'tami', 'thank', ':)'],
#  ['love', ':-)'],
#  ['want', 'look', 'good', ':)'],
#  ['sure', ':)'],
#  ['excit', 'weekend', ':-)'],
#  ['b3dk', 'far', '7an', 'ank', 'mi', '15', ':)'],
#  ['god',
#   'give',
#   'us',
#   'strength',
#   'purpos',
#   'help',
#   'other',
#   'struggl',
#   ':-)'],
#  ['lol', 'meant', 'lucki', 'eagl', 'thank', 'servic', 'oceana', ':-)'],
#  ['woke',
#   'feel',
#   'incred',
#   'sick',
#   'idk',
#   'caus',
#   'drank',
#   'starbuck',
#   '11',
#   "o'clock",
#   'last',
#   'night',
#   'reaction',
#   'med',
#   ':)'],
#  ["oopsthat'",
#   'call',
#   'fridayfauxpa',
#   ':)',
#   "i'll",
#   'get',
#   'chang',
#   'right',
#   'thank',
#   'g'],
#  ['fulfil', 'fantasi', ':)', '👉', '👈', '💗'],
#  ['call', 'night', 'go', 'sleep', ':)'],
#  ['yeah',
#   "they'r",
#   'give',
#   'subtl',
#   'hint',
#   'also',
#   'tip',
#   '2',
#   'use',
#   'commun',
#   'last',
#   'year',
#   ':-)',
#   'prim',
#   '’',
#   'algorithm',
#   'iii'],
#  ['funni', 'ye', 'soon', 'alway', 'go', 'soon', ':D'],
#  ['thank', ':)', 'get', 'retweet', 'x'],
#  ['smile', 'receiv', 'text', 'dad', 'say', 'suck', ':)'],
#  ['wat', ':)'],
#  ["can't",
#   'wait',
#   'rosa',
#   'love',
#   'xma',
#   ':)',
#   'welcom',
#   'back',
#   'ann',
#   'hope',
#   'u',
#   'good',
#   'one',
#   'back',
#   'time',
#   ':)',
#   'x'],
#  ['morn',
#   'tweep',
#   'new',
#   'post',
#   'today',
#   'pleas',
#   'like',
#   'share',
#   'see',
#   'thank',
#   ':)'],
#  ['yvw', 'great', 'day', 'weekend', ':D'],
#  ['awww', 'here', 'quick', 'workout', 'boost', ':-)'],
#  ['lol',
#   ':D',
#   'know',
#   'idea',
#   ':p',
#   'coz',
#   'unforgett',
#   'sens',
#   'humor',
#   ';)',
#   ':)',
#   ':D',
#   'love',
#   'bro'],
#  ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via'],
#  ["mum'", 'home', 'hahahhaah', 'thank', 'lord', ':)'],
#  ['safe', ':D'],
#  ['girl', ':)'],
#  ['sombrero', 'high', 'okay', "i'm", 'lost', ':)'],
#  ['hellooo', "i'm", 'rose', 'nice', 'meet', ':)'],
#  ['thank',
#   'screenshot',
#   'po',
#   'let',
#   'take',
#   'care',
#   'spammer',
#   ':)',
#   'proceed',
#   'c'],
#  ['perfect', 'thing', 'pick', ':)', 'wsalelov'],
#  ['thank', 'amaz', 'job', ':)'],
#  ['die', 'actual', 'pretti', 'entertain', ':p'],
#  ['congrat', '100k', 'man', "can't", 'wait', 'till', 'hit', 'mileston', ':)'],
#  ['morn',
#   'alljudith',
#   'answer',
#   'district',
#   'council',
#   'relat',
#   'question',
#   'today',
#   ':-)'],
#  ['see', 'tomorrow', ':)'],
#  ['saw',
#   'comment',
#   'midar',
#   'gender',
#   'unknown',
#   'like',
#   ':)',
#   'yeah',
#   'keep',
#   'say'],
#  ['wow', 'realli', 'hate', ':)'],
#  ['watch', 'saw', 'dan', ':)'],
#  ['thank', ':-)', 'ilysm', 'xx'],
#  ['thank', 'trade', ':)'],
#  ['look', 'forward', ':-)', 'ks'],
#  ['lesley', ':)'],
#  ['want',
#   'protect',
#   'relationship',
#   'other',
#   "i'll",
#   'talk',
#   'ppl',
#   'need',
#   'know',
#   'awesom',
#   ':)'],
#  ['oh', 'dang', 'zen', 'look', 'outsid', 'space', 'neat', ':-)'],
#  ['look', 'good', 'outfit', ':)'],
#  ['hiya',
#   "i'm",
#   'afraid',
#   "we'v",
#   'alreadi',
#   'pick',
#   'rider',
#   'year',
#   "we'll",
#   'look',
#   'next',
#   'year',
#   ':)'],
#  ['good', 'morn', 'u', ':)'],
#  ['ha',
#   'ha',
#   'ok',
#   'honey',
#   'go',
#   'ahead',
#   'fyi',
#   'still',
#   'dig',
#   'ya',
#   'enjoy',
#   'vote',
#   'watch',
#   'side',
#   ':)'],
#  ['lucki', ':)'],
#  ['learn',
#   'new',
#   'skill',
#   'take',
#   'time',
#   'perfect',
#   'master',
#   'thank',
#   'favourit',
#   ':)'],
#  ['👱',
#   '🏽',
#   '👽',
#   '🌳',
#   '😂',
#   '😂',
#   '😂',
#   "i'v",
#   'talk',
#   'u',
#   'coupl',
#   'time',
#   'u',
#   'seem',
#   'nice',
#   'funni',
#   ':)'],
#  ['agre', 'suspici', 'mind', ':)'],
#  ['good', 'afternoon', ':)'],
#  ['whoop', 'whoop', 'bring', 'fun', ':)'],
#  ['new',
#   'report',
#   'talk',
#   'burn',
#   'calori',
#   'cold',
#   'work',
#   'harder',
#   'warm',
#   'feel',
#   'better',
#   'weather',
#   ':p'],
#  ['say', 'someth', "i'm", 'give', ':)', "i'm", 'sorri', 'get', ':D'],
#  ['good', 'night', ':)'],
#  ["there'", 'gonna', 'anoth', 'one', 'final', ':)'],
#  ['welcom', 'jessica', 'enjoy', ':)'],
#  ['best',
#   'friend',
#   'carina',
#   'one',
#   'san',
#   'francisco',
#   'let',
#   'know',
#   'want',
#   'get',
#   'touch',
#   ':)'],
#  ['thank',
#   'mommi',
#   'teret',
#   ':)',
#   ':)',
#   'potassium',
#   'rehydr',
#   'drinkitallup',
#   'thirstquench'],
#  ["i'm", 'sure', 'tapir', 'calf', 'one', 'like', 'adventur', 'mealtim', ':)'],
#  ['uhc', 'box', 'larg', 'scale', 'one', 'network', 'server', ':p'],
#  ['ever', 'areal', "we'll", 'lunch', 'dinner', ':)'],
#  ["here'",
#   'one',
#   'extremesport',
#   'fan',
#   'among',
#   'love',
#   'quadbik',
#   'get',
#   'touch',
#   ':)',
#   'bloggersrequir',
#   'bloggersw'],
#  ['thank', 'love', 'cake', ':)', 'bear', 'hug', 'end'],
#  ['masa', 'nowaday', 'brainer', 'type', 'invest', 'list', 'mse', 'fund', ':)'],
#  ['magnific', ':-)'],
#  ['love', 'work', 'tokyo', ':)', 'ceo', '1month'],
#  ['yeah', 'tri', 'look', 'x', ':)'],
#  ['welcom', 'kfcroleplay', 'enjoy', 'let', 'friend', ':)'],
#  [':)',
#   'hehe',
#   'get',
#   'think',
#   'mean',
#   'need',
#   'sleep',
#   'nooowww',
#   'nite',
#   'nite',
#   ':)'],
#  ['hi', '5', 'back', ':)', ':)'],
#  ['ye', 'omg', 'lile', 'tid', 'tmi', ':)'],
#  ['may', 'deploy', 'degre', 'sarcasm', ':)'],
#  ['cute', 'boy', 'jule', ':-)'],
#  ["can't", 'wait', 'week', ':D'],
#  ['thank',
#   'follow',
#   'us',
#   'betti',
#   'miller',
#   'new',
#   'friend',
#   'alway',
#   'welcom',
#   ':)'],
#  ['person', 'small', 'thing', 'u', 'expect', 'person', 'u', 'love', ':)'],
#  ['ye',
#   'hddc',
#   'also',
#   'favourit',
#   ':)',
#   'salman',
#   'khan',
#   'movi',
#   'etern',
#   'case',
#   'watch',
#   'pthht'],
#  ['oh', 'shoot', 'well', 'watch', ':D'],
#  ['far',
#   'lfc',
#   'fan',
#   'make',
#   'expert',
#   'spot',
#   'mental',
#   'weak',
#   'lack',
#   'consist',
#   ':-)'],
#  ['tope', ':)'],
#  ['good', 'night', 'sweet', 'dream', 'xxoo', '♡', '♥', '♡'],
#  ['littl', 'finger', ':D'],
#  ['love', ':)', '13', 'photo', 'explain', 'ukrain', 'russia'],
#  ['friday', ':)'],
#  ['hey', 'fam', 'vote', 'alreadi', ':)', 'gotta', 'win', 'boy', 'teenchoic'],
#  ['hi', 'jane', 'silver-wash', 'fritillari', ':)'],
#  ['pleasur', ':)'],
#  ['great', 'day', 'hunni', ':)'],
#  ['good', 'night', 'moon', ':)', 'pandora'],
#  ['2', 'ap', 'studi', 'hall', 'haha', 'great', ':)'],
#  ['follow', 'everyon', 'back', 'teamfollowback', ':-)'],
#  ['ha',
#   'almost',
#   'gave',
#   'fuck',
#   ':)',
#   'boy',
#   'trash',
#   'wast',
#   'time',
#   "that'",
#   'sure'],
#  ['amaz', 'pic', 'today', ':D'],
#  ['ye', 'alreadi', 'ad', 'pleas', 'check', 'final', 'design', ':)'],
#  ['noth', 'much', 'need', 'grow', ':)'],
#  ['easi', 'clever', 'interest', 'audienc', 'welcom', ':)'],
#  ['great', 'video', ':D'],
#  ['ask', 'end', "i'm", 'friend', ':)'],
#  ["thank'", 'follow', 'keven', ':)'],
#  ['ha',
#   'love',
#   'pic',
#   'clearli',
#   'much',
#   'learn',
#   'popular',
#   'english',
#   'pastim',
#   ':)'],
#  ['ashramcal', 'return', ':p'],
#  ['catch', 'fall', 'fall', 'ontrack', ':)'],
#  ['alway', 'make', 'thing', 'better', ':)', '❤', '️'],
#  ['guess', "they'll", 'show', 'german', 'also', 'subtitl', ':)'],
#  ['pinter', ':-)'],
#  ['goood',
#   'morninggg',
#   'jummah',
#   'mubarak',
#   'everyon',
#   'bless',
#   'amaz',
#   'day',
#   'ahead',
#   ':)'],
#  ['cute', ':-)', '🐶'],
#  ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via'],
#  ['fabul', 'time', 'miss', ':)', 'xx'],
#  ['noth', 'perfect', 'smile', ':)'],
#  ['never', 'show', 'much', ':)'],
#  [':-)', 'cheer', 'pete', 'listen', 'later', '☺', '☺'],
#  ["that'", 'build', 'sunday', ':p'],
#  ['direct', 'attent', 'awesome-o', ':)'],
#  ['get', 'us', 'tune', 'well', 'app', 'multipl', 'option', ':D'],
#  ['engin', ':)'],
#  ['happi', 'friday', ':D'],
#  ['cya', 'week', ':D'],
#  ['happi', 'shop', ':)'],
#  ['fantast',
#   'show',
#   'harrog',
#   'home',
#   'gift',
#   'back',
#   'offic',
#   '2',
#   'day',
#   'jet',
#   'see',
#   'wonder',
#   'supplier',
#   ':)'],
#  ['nice', 'one', ':D'],
#  ['ye', "let'", ':)'],
#  ['7', ':)', ':)', ':)', ':)'],
#  ['australia', 'morn', ':D'],
#  ['req', 'star', ':)', 'fridayloug'],
#  ['knew', 'whole', 'class', 'cri', 'hurt', 'word', ':)'],
#  ['opportun',
#   'anyon',
#   'ask',
#   'question',
#   'babe',
#   'includ',
#   ':)',
#   '4thstreetmus'],
#  ['lunch', ':)'],
#  ["i'll", 'hawaii', 'decemb', "we'll", 'kick', 'back', 'miss', ':)'],
#  ['two', '17', 'year', 'old', 'deepli', 'love', ':-)'],
#  ['aha', "that'", 'alright', '❤', '️', 'love', ':)'],
#  ['hope', 'nate', 'notic', 'edit', 'sinc', 'made', 'icon', ':)'],
#  ['send', 'johneclipsecouk', ':)'],
#  ['hahand', 'thousand', 'lie', ':D'],
#  ["i'd", 'will', 'tri', ':)'],
#  ['read', 'newspap', ':D'],
#  ['afternoon', 'date', '3', ':)'],
#  ["here'",
#   'fan',
#   'made',
#   'art',
#   'u',
#   ':)',
#   'guy',
#   'phone',
#   'lew',
#   'bend',
#   ':D'],
#  ['nah', 'beaut', 'way', ':)'],
#  ['fallout',
#   '4',
#   'get',
#   'see',
#   'glow',
#   'sea',
#   'fallout',
#   '3',
#   'play',
#   'see',
#   ':D'],
#  ["i'm",
#   'friend',
#   'cousin',
#   'karen',
#   'gunderson',
#   'watch',
#   'europa',
#   'report',
#   'thoroughli',
#   'impress',
#   'want',
#   'say',
#   'great',
#   'script',
#   ':-)'],
#  ['dri', 'start', 'wale', 'wait', 'duck', 'overtak', 'motorway', ':-)'],
#  ['good', 'morn', 'fab', 'friday', ':)'],
#  ['hahahaand', 'thusi', 'sneak', 'away', 'log', 'niteflirt', ':D'],
#  ['yep', "we'r", 'trash', 'af', 'im', 'indonesia', 'hbu', ':-)'],
#  ['obvious', 'get', 'better', 'tweet', ':-)'],
#  ['welcom', 'kfcroleplay', 'enjoy', 'let', 'friend', ':)'],
#  ['bowl', 'alway', 'best', 'friend', ':)'],
#  ['hope', "i'll", ':)', 'x'],
#  ['say', 'must', 'chri', 'elli', ':)'],
#  ['ye', 'friendli', 'contest', 'loser', 'buy', 'drink', ':)'],
#  ['thank', 'follow', 'great', 'day', ':)'],
#  ['thank', ':-)'],
#  ['thank', ':D'],
#  ['day', 'practic', 'song', ':)'],
#  ["here'", 'remind', 'need', 'one', ':-)'],
#  ['harri',
#   'niall',
#   '94',
#   'harri',
#   'born',
#   'ik',
#   'stupid',
#   'wanna',
#   'chang',
#   ':D'],
#  ['select', 'other', 'get', ':)'],
#  ['play', 'aln', "he'll", 'score', 'fuck', 'night', ':)'],
#  ['bff', ':)'],
#  ['hi', "here'", 'vid', 'stydia', 'take', 'look', ':)'],
#  ['im', 'send', 'alex', 'like', 'million', 'pictur', ':)'],
#  ['love', ':)'],
#  ['visit', 'blog', 'thank', ':D'],
#  ['happi', 'birthday', 'nawazuddin', 'siddiqu', 'big', 'fan', ':)'],
#  ['ye',
#   'pleas',
#   'would',
#   'brighten',
#   'night',
#   'shift',
#   'nomnomnom',
#   ':D',
#   'chocol',
#   'dukefreebiefriday',
#   'xx'],
#  ['done', 'eonni', ':)'],
#  ['fantast', 'night', ':)'],
#  [':)'],
#  ['boom', 'date', ':D', 'z'],
#  ['follow', 'alreadi', 'thank', ':)'],
#  ['thank', ':)'],
#  ['happi', 'end', 'insyaallah', ':)'],
#  ['that',
#   'way',
#   'see',
#   'west',
#   'ham',
#   'shit',
#   'small',
#   'club',
#   'london',
#   'villa',
#   '3rd',
#   'biggest',
#   'brum',
#   ':)'],
#  ['deni', 'vagina', 'rli', ':D', 'poor', 'thing', ':D'],
#  ['smile', 'sunnah', ':)', 'عن'],
#  ['hi',
#   'see',
#   'u',
#   'like',
#   'fourfivesecond',
#   'think',
#   'u',
#   'might',
#   'like',
#   'deaf',
#   'ear',
#   'plz',
#   'let',
#   'know',
#   'u',
#   'think',
#   ':)'],
#  ['share', 'readi', ':)'],
#  ['oh',
#   'white',
#   'rabbit',
#   'cutest',
#   'thing',
#   "i'v",
#   'ever',
#   'seen',
#   'wait',
#   'ador',
#   ':)'],
#  ['welcom', ':)', 'love', 'weekend', 'izzi'],
#  ['happi', 'birthday', 'mitch', ':-)', 'wish', 'best', 'good', 'day'],
#  ['thank', ':)'],
#  ['done', 'ya', 'minn', ':)', 'cjradacomateada'],
#  ['welcom', 'fun', ':)'],
#  ['recentlywebsit',
#   'upgrad',
#   'might',
#   'see',
#   'new',
#   'pictur',
#   'coolingtow',
#   'soonthank',
#   'showinginterest',
#   ':)'],
#  ['flipkartfashionfriday',
#   'maxi',
#   'dress',
#   'pair',
#   'wid',
#   'wedg',
#   'make',
#   'ur',
#   'life',
#   'bright',
#   'color',
#   ':)'],
#  ['alway', 'motiv', ':-)'],
#  ['nnnnot', 'see', 'upsid', ':-)'],
#  ['haha', 'kyle', "gf'", 'babi', ':)'],
#  ['lol', 'ok', 'watch', 'ya', 'bit', ':p'],
#  ['bluesidemenxix', "i'd", 'love', 'win', 'one', ':)'],
#  ['happi', 'birthday', ':)'],
#  ['hello', ':)', 'ardent', 'follow'],
#  ['goood', 'mooorn', ':)', 'want', 'sleep'],
#  ['ghost',
#   'bae',
#   ':D',
#   'love',
#   'wuppert',
#   'tagsforlikesapp',
#   'instagood',
#   'smile',
#   'follow',
#   'cute',
#   'photooftheday',
#   '…'],
#  ['hahaha', 'okay', 'thank', ':)'],
#  ['lose', ':D'],
#  ['hehe', 'cool', ':)'],
#  ['morn',
#   'u',
#   'today',
#   'u',
#   'got',
#   'plan',
#   'lazi',
#   "i'm",
#   'still',
#   'bed',
#   'toast',
#   'fresh',
#   'coffe',
#   '2',
#   ':)',
#   'great',
#   'fridayfunday'],
#  ['welcom', 'famili', ':)'],
#  ['re-sign', ':)'],
#  ['meet', 'harri', "that'", 'need', 'life', ':-)'],
#  ['stat', 'week', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via'],
#  ['one', 'sleep', 'til', 'wed', ':-)'],
#  ['excit',
#   'chalkhil',
#   'park',
#   'celebr',
#   'tomorrow',
#   'midday',
#   'come',
#   'join',
#   'fun',
#   ':-)'],
#  ['hello', ':)', 'love', 'carter', ':)'],
#  ['good', 'read', ':)'],
#  [':-)'],
#  ['enjoy', 'hope', 'weather', 'hold', 'guy', ':-)'],
#  ['done', ':)'],
#  ['remedi', 'media', 'tell', ':-)'],
#  ['thank', ':)'],
#  ['jumma', 'mubarak', 'bless', ':)'],
#  ["we'r",
#   'look',
#   'forward',
#   'abl',
#   'spend',
#   'time',
#   ':)',
#   'enjoy',
#   'iflix',
#   ':)'],
#  ["tgif'", 'weekendenjoy', ':)'],
#  ['im',
#   'thank',
#   'someon',
#   'like',
#   'life',
#   'inspir',
#   'better',
#   'everyday',
#   'love',
#   'mind',
#   'follow',
#   ':)'],
#  ['becom', 'better', 'atrack', 'better', ':)'],
#  ['first',
#   'third',
#   'look',
#   'promis',
#   'els',
#   'fail',
#   'make',
#   'decis',
#   'go',
#   ':)'],
#  ['crazi', 'girlfriend', 'like', ':-)', '(-:', 'jesu', 'christ'],
#  ['morn',
#   ':)',
#   'gd',
#   'day',
#   'store',
#   "i'm",
#   'badminton',
#   '2',
#   "littl'un",
#   'fabfriday'],
#  ['kid', 'insid', 'want', 'one', ':-)'],
#  ['imran', 'khan', 'hero', ':)', 'realli', 'ikprideofpak'],
#  ['janjua', 'friend', ':)'],
#  ['sorri', 'fuck', 'eric', 'think', 'he', 'funni', ':)'],
#  ['say', 'bday', ':)'],
#  ['hey', ':)', 'pictur', 'think', ':)', 'follow', 'pleas', '💕'],
#  [':)',
#   ':)',
#   ':)',
#   'pimpl',
#   ':)',
#   ':)',
#   ':)',
#   'forehead',
#   ':)',
#   ':)',
#   'size',
#   ':)',
#   ':)',
#   ':)',
#   'volcano',
#   ':)'],
#  ['good', 'luck', 'coupl', 'get', 'marri', 'weekend', ':)'],
#  ['back', ':)', 'na', 'mag', 'miryenda', ':)'],
#  ['wait', 'bro', ':-)'],
#  ['parti',
#   '3d',
#   'printer',
#   ':)',
#   'celebr',
#   'futur',
#   "technology'",
#   'possibl',
#   'touchétoday',
#   '…'],
#  ['u', 'use', 'app', 'listen', 'music', 'ye', 'app', ':-)', '—', 'idownload'],
#  ['get', '25ish', 'snowbal', ':p'],
#  ['cours', ':)'],
#  ['nd',
#   'go',
#   'expir',
#   'next',
#   'year',
#   'dat',
#   'mtn',
#   '6gb',
#   'u',
#   ':D',
#   'realli',
#   'like'],
#  ['happi', 'birthday', 'nice', 'day', ':)', 'loveu'],
#  ['wanna', 'go', 'back', 'time', 'everyth', 'still', 'fine', ':-)'],
#  ['celebr',
#   'life',
#   ':)',
#   'summer',
#   'morefuninthephilippin',
#   'laho',
#   'island',
#   'caramoan',
#   'island'],
#  ['nice', 'quot', ':)', 'ceo', '1month'],
#  ['good', 'stuff', ':)', 'love', 'bit', 'salmon'],
#  ['jumma', 'kareem', ':)', 'remind', 'recit', 'surah', 'kahaf'],
#  ["i'm", 'join', 'right', ':D'],
#  ['sure', ':)'],
#  ['hi',
#   'melani',
#   ':-)',
#   'fact',
#   "they'r",
#   'realli',
#   'use',
#   'case',
#   'normal',
#   'wifi',
#   'could',
#   'issu',
#   'mention'],
#  ['quit',
#   'phenomen',
#   'offer',
#   'bosch',
#   'wash',
#   'machin',
#   "week'",
#   'definit',
#   'last',
#   'long',
#   ':)'],
#  ['one', 'ok', "i'll", 'run', 'photo', 'moment', ':D'],
#  ['thank', 'refollow', ':)'],
#  ['slept',
#   'less',
#   '7',
#   'hour',
#   'last',
#   'night',
#   'prepar',
#   'possibl',
#   'nap',
#   ':p'],
#  ['idk', ':p', 'follow', '😎', '💁', '🏻'],
#  ['feel', 'like', 'relaps', ':-)'],
#  ['girl',
#   'nice',
#   'wallet',
#   'prada',
#   'hai',
#   'rich',
#   'stupid',
#   'mean',
#   'bhai',
#   'ka',
#   'hai',
#   ':p',
#   'punjabiswillgetit'],
#  ['☺', 'morn', 'babe', ':)'],
#  ['lol', 'sorri', 'ultor', 'first', 'hitter', 'soi', 'favor', 'much', ':)'],
#  ['finish',
#   'mass',
#   'effect',
#   '1',
#   'yesterday',
#   'dont',
#   'know',
#   'shoud',
#   'start',
#   'mass',
#   'effect',
#   '2',
#   '100',
#   'game',
#   ':)'],
#  ['bad',
#   'would',
#   'remind',
#   'exercis',
#   '1:12',
#   ':-)',
#   'miss',
#   'need',
#   'come',
#   'back'],
#  ['add',
#   'kik',
#   'ughtm',
#   '545',
#   'kik',
#   'kikmeguy',
#   'kissm',
#   'nude',
#   'likeforfollow',
#   'musicbiz',
#   'sexysasunday',
#   ':)'],
#  ['overwhelm', 'groupmat', 'thank', 'group', 'got', '1', '75', 'recit', ':)'],
#  ['ha', 'mistak', 'thank', 'point', ':)'],
#  ['kyunk',
#   'aitchison',
#   'hai',
#   ':p',
#   'look',
#   'respons',
#   'origin',
#   'tweet',
#   'know',
#   'brother'],
#  ['snapchat',
#   'sexyjudi',
#   '19',
#   'snapchat',
#   'kikmeboy',
#   'tagsforlik',
#   'pussi',
#   'gay',
#   'indiemus',
#   'sexo',
#   ':)'],
#  ["that'", 'true', 'inde', 'curvi', 'rout', ':)'],
#  ['come', 'chill', 'fire', ':)'],
#  ['mont', 'doa', 'header', ':D'],
#  ['haha', 'x', ':D'],
#  ['ted',
#   'speaker',
#   'say',
#   'stress',
#   'good',
#   'bodi',
#   'anoth',
#   'speaker',
#   'introduc',
#   'way',
#   'avoid',
#   'stress',
#   ':)',
#   'ted',
#   'thought',
#   'laboratori',
#   ':)'],
#  ['thing', 'note', 'awesom', ':-)'],
#  ['might', 'lose', 'friend', 'today', 'know', 'idc', ':)'],
#  ['good',
#   'morn',
#   ':D',
#   'lol',
#   'realli',
#   'fuckin',
#   'dark',
#   'gonna',
#   'rain',
#   'hard',
#   'coupl',
#   'minut'],
#  ['far',
#   'lfc',
#   'fan',
#   'make',
#   'expert',
#   'spot',
#   'mental',
#   'weak',
#   'lack',
#   'consist',
#   ':-)'],
#  ['ff', 'amaz', 'singer', 'actress', 'model', ':-)'],
#  ['happi', 'birthday', 'see', 'tonight', ':)'],
#  ["i'm", 'amsterdam', 'guy', 'wooo', ':D'],
#  ['stuff', 'happen', ':)'],
#  ['friend', ':)'],
#  ['neobyt',
#   ':)',
#   'univers',
#   'pictur',
#   'seed',
#   'pirat',
#   'movi',
#   'copi',
#   'file',
#   'takedown',
#   'notic'],
#  ['2',
#   'indirag',
#   'want',
#   'judiciari',
#   'commit',
#   'govt',
#   'polici',
#   'want',
#   'rbi',
#   'commit',
#   'know',
#   'mani',
#   'similar',
#   'view',
#   ':)'],
#  ["thought'", 'kepler', '452b', ':D'],
#  ['progress', 'stone', 'transfer', 'chelsea', ':D'],
#  ['gg', 'bro', ':)', 'fun', 'seri'],
#  ['alway', 'part', 'part', 'defenit', '♬', ':p'],
#  ['cours', 'man', ':)', 'nofx', 'shit'],
#  ['friskyfiday', 'yipee', ':)', 'x'],
#  ['morn',
#   'kim',
#   'sorri',
#   'hear',
#   'shed',
#   'light',
#   'issu',
#   'look',
#   ':)',
#   'helen'],
#  ['great', 'incent', 'get', 'kid', 'eat', 'fruit', 'vege', ':-)'],
#  ['welcom', 'sir', ':)'],
#  ['know',
#   'averag',
#   'take',
#   '6',
#   'second',
#   'read',
#   'god',
#   'dam',
#   'mother',
#   'fuck',
#   'tweet',
#   ':)'],
#  ['thank', 'favourit', 'tweet', 'marin', ':)'],
#  ['get', 'close', "can't", 'wait', 'new', 'season', ':)'],
#  ['gz', ':D', 'name'],
#  ['morn', 'day', ':-)'],
#  ['guess', 'sleep', 'list', 'thing', 'today', ':-)'],
#  ['hai',
#   'rajeevhop',
#   'u',
#   'r',
#   'hvng',
#   'funfil',
#   'fridayit',
#   'ws',
#   'reali',
#   'amaz',
#   'c',
#   'diff',
#   'side',
#   'kabirfel',
#   'luv',
#   'u',
#   ':)',
#   'smile',
#   'pl'],
#  ['prettier', ':)', 'mine', ':)'],
#  ['happi',
#   'birthday',
#   'best',
#   'wish',
#   'dresden',
#   'germani',
#   ':)',
#   'love',
#   '3',
#   '3',
#   '3',
#   '3',
#   'pleas',
#   'share'],
#  ['wanna', 'loser', 'like', ':)', '♥'],
#  ['zayn',
#   'pleas',
#   'follow',
#   'would',
#   'mean',
#   'world',
#   'birthday',
#   ':D',
#   'love',
#   'much',
#   'amaz',
#   '3'],
#  ['congratul', 'friend', 'graduat', 'lose', 'plot', ':D'],
#  ['0',
#   'sleep',
#   'offici',
#   'way',
#   'pari',
#   'cannot',
#   'wait',
#   ':)',
#   'pari',
#   'tdf',
#   '2015',
#   '🇫',
#   '🇷',
#   '🍷',
#   '🍸',
#   '☀',
#   '️',
#   '🇫',
#   '🇷',
#   '🚲',
#   '🇫',
#   '🇷',
#   '🍷',
#   '🍸',
#   '☀',
#   '️',
#   '🚲'],
#  ['put', 'trust', ':)'],
#  ['hey',
#   'good',
#   'suggest',
#   'guy',
#   'make',
#   'minion',
#   'slot',
#   'would',
#   'fun',
#   'cute',
#   ':)'],
#  ['happi', "b'day", ':)'],
#  ['hahand', 'thousand', 'lie', ':D'],
#  ['wow',
#   'look',
#   'good',
#   'isabella',
#   'make',
#   'wanna',
#   'start',
#   'work',
#   'back',
#   ':D'],
#  ['go', 'room', 'bc', '3', ':-)'],
#  ['okeyyy',
#   'vddd',
#   ':)',
#   ');',
#   'excit',
#   "can't",
#   'wait',
#   'love',
#   'selfee',
#   'pic',
#   'insta',
#   ':)',
#   '♥',
#   '♥',
#   'special',
#   'coco',
#   '🙆',
#   '🙌',
#   '😛',
#   '😄',
#   '😄',
#   '😁',
#   '😂',
#   '😂',
#   '🐒',
#   '😁',
#   '😝',
#   '❤',
#   'dishoom'],
#  ['think', 'write', ':)'],
#  ['final', 'went', 'drive', 'tonight', ':-)'],
#  ['thank', 'follow', 'great', 'day', ':)'],
#  ['im', 'go', 'sleep', 'goodnight', ':)'],
#  ['hello', ':)'],
#  ['yup', 'know', 'okay', 'let', 'tri', ':)', 'done', 'hhahhaaa', '—', 'haha'],
#  ["i'm", 'suppos', 'ask', 'buy', 'album', ':)'],
#  ['6', 'day', 'go', ':)'],
#  ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow'],
#  ['least', "there'", 'one', 'cool', 'thing', ':-)'],
#  ['hey', 'guy', "that'", 'new', 'page', ':)'],
#  ['jeez',
#   'tara',
#   'move',
#   'teamcannib',
#   'vs',
#   'teamspacewhalingisthebest',
#   ':p'],
#  ['morn',
#   'gym',
#   'session',
#   'done',
#   'feel',
#   'good',
#   'workout',
#   'earlynow',
#   'enjoy',
#   'rest',
#   'day',
#   ':)',
#   'friyay',
#   'workout',
#   'fitfa',
#   '…'],
#  ['guess', 'never', 'realli', 'identifi', 'pharmaci', ':)', 'iwishiknewbett'],
#  ['yeah',
#   'know',
#   'lack',
#   'thing',
#   'hey',
#   'pleas',
#   'check',
#   'final',
#   'design',
#   'satisfi',
#   'enough',
#   ':)'],
#  ['wow', 'nice', 'combin', ':)'],
#  ['charg', 'speaker', 'final', 'got', 'earlier', 'today', ':)'],
#  [':)', 'masaantoday'],
#  ['later', 'turn', ':D'],
#  ['text', 'wanna', 'meet', "i'll", 'get', ':)'],
#  ['long', ':)'],
#  ['friend', 'never', 'talk', 'ess-aych-eye-te', 'anyon', ':)'],
#  ['ya', ':)', '😊'],
#  ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via'],
#  ['yeah',
#   'left',
#   'one',
#   'supposedli',
#   'hurt',
#   'bc',
#   'right',
#   'heart',
#   'appar',
#   "it'll",
#   'fine',
#   'good',
#   'luck',
#   ':)'],
#  ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow'],
#  ['ahh', 'thank', 'u', ':D'],
#  ['niall', 'follow', 'fan', ':)', "i'm", 'still', 'without', 'follow', '👍'],
#  ['sister', 'best', 'best', 'pre', 'bday', 'celebr', ':)'],
#  ['among', 'time', 'fav', 'tweet', ':D'],
#  ['happi', 'birthday', 'g', 'best', 'life', ':)'],
#  ['need', 'stress', 'time', ':)'],
#  ['immedi', 'plan', 'hope', 'someday', 'futur', ':)'],
#  ['could',
#   'make',
#   "foxy'",
#   'song',
#   'version',
#   'instrument',
#   'form',
#   'sound',
#   'epic',
#   'beat',
#   'alon',
#   ':)'],
#  ['second', 'well', 'done', ':)'],
#  ['think', 'hard', 'bed', ':p'],
#  ['tomorrow', 'goldcoast', ':)'],
#  ['like', 'way', 'said', 'gal', 'lelomustfal', 'beautiful', 'way', ':)'],
#  ['happi', 'save', 'day', ':)', 'hope', 'enjoy', 'meal', 'sam'],
#  ['thank', 'min', ':)'],
#  ['5g', 'liker', ':)', 'fast'],
#  ['like',
#   'morn',
#   'got',
#   'dress',
#   'bought',
#   ':)',
#   "i'm",
#   'total',
#   'love',
#   '♡',
#   'newdress',
#   'happi',
#   '…'],
#  ['ff', 'could', 'anyon', 'resist', 'beauti', 'smile', ':-)', 'quacketyquack'],
#  ['u', 'mean', 'hide', 'fot', ':p'],
#  ['aww', 'thankyou', ':)'],
#  ['ok',
#   'good',
#   'night',
#   'wish',
#   'troy',
#   'ugli',
#   'met',
#   'today',
#   ':)',
#   '):',
#   'ok',
#   'today',
#   'fun',
#   "i'm",
#   'excit',
#   'tmrw'],
#  ['inde', ':-)'],
#  [':)', 'good', 'afternoon', ':D'],
#  ['okay', ':)'],
#  ['make', 'two', 'us', ':D'],
#  ['hurt', 'read', "people'", 'holiday', 'work', ':D'],
#  ['nice',
#   'hear',
#   'want',
#   'switch',
#   'us',
#   ':)',
#   'pro',
#   'kit',
#   'would',
#   'best',
#   'choic',
#   'follow',
#   'link'],
#  ['beautifulwint', 'like', 'summer', 'russia', ':)'],
#  ['thought', '’', 'like', 'mate', ':)'],
#  ["i'm", 'play', 'brain', 'dot', 'braindot'],
#  ['stat', 'week', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via'],
#  ['dm', ':p'],
#  ['also', 'come', 'game', ':)'],
#  ['thank', ':)'],
#  [':)', 'hope', 'enjoy'],
#  ['ok',
#   'first',
#   'time',
#   'chat',
#   'made',
#   'joke',
#   'lol',
#   'believ',
#   'wont',
#   'forget',
#   'u',
#   ':)',
#   'name'],
#  ['mymonsoonstori',
#   'bodi',
#   'shop',
#   'bodi',
#   'mist',
#   'vanilla',
#   'work',
#   'wonder',
#   'skin',
#   ':)'],
#  [':)',
#   'best',
#   'youtub',
#   'keep',
#   'good',
#   'work',
#   'man',
#   'starsquad',
#   'sidemen'],
#  ['yaaayyy', 'best', 'friendaaa', 'shout', 'like', 'minion', ':)'],
#  ['thank',
#   'ad',
#   'us',
#   'list',
#   ':)',
#   'make',
#   'sure',
#   'keep',
#   'touch',
#   'news',
#   'light',
#   'bulb',
#   'made',
#   'corn',
#   'wast'],
#  ['1tbps4',
#   'wow',
#   'prize',
#   'delight',
#   'eye',
#   'pick',
#   'win',
#   'burst',
#   'sing',
#   'ps4',
#   'mine',
#   'feel',
#   'divin',
#   ':)'],
#  ['bath', ':)', 'even', '’', 'wheeli', 'bin', 'nowher', 'put'],
#  ['get', 'readi', 'ubericecream', 'messengerforaday', ':)'],
#  ['yeap', ':)'],
#  ['must', 'watch', ':D', 'bajrangibhaijaanhighestweek', '1'],
#  ['cool', 'congrat', 'kyli', 'u', 'look', 'nice', ':-)'],
#  ['thought',
#   'work',
#   'season',
#   'realli',
#   'busi',
#   'day',
#   'ok',
#   'deal',
#   'weekend',
#   'toilet',
#   'break',
#   ':p'],
#  ['daddi', 'af', ':-)'],
#  ['latest', 'one', ':)'],
#  ['happi', 'make', ':)'],
#  ['far', 'good', 'ikaw', 'musta', 'cheatmat', ':)'],
#  ['elf', 'thank', 'singer', ':)', 'kyuhyun', 'thank', 'elf'],
#  ['20', 'ghanton', 'se', 'light', 'nahi', ':)'],
#  ['one',
#   'last',
#   'long',
#   'lol',
#   'block',
#   'alreadi',
#   'must',
#   'nice',
#   'tweet',
#   'hate',
#   ':)'],
#  ['ur', 'skin', 'think', 'ur', 'still', '16', 'decid', 'break', ':-)', 'cool'],
#  ['easyget',
#   '5:30',
#   'go',
#   'work',
#   'come',
#   'home',
#   'bout',
#   '6',
#   'take',
#   'care',
#   'home',
#   'famili',
#   'therein',
#   "that'",
#   'see',
#   ':-)'],
#  ['thank',
#   'majalah',
#   'juli',
#   'issu',
#   ':)',
#   'love',
#   '👍',
#   '🏼',
#   '👍',
#   '🏼',
#   '👍',
#   '🏼',
#   '😍',
#   '😍',
#   '😍',
#   '🌸',
#   '🌸',
#   '🌸'],
#  ['piti', 'parti', ':-)'],
#  ['tgif',
#   'unless',
#   'one',
#   'student',
#   ':)',
#   'light',
#   'read',
#   'singapor',
#   'hero',
#   'gp',
#   'essay',
#   'alevel'],
#  ['dominiqu',
#   "i'm",
#   'biggest',
#   'fan',
#   'like',
#   'oh',
#   "i'm",
#   'england',
#   'get',
#   'fan',
#   'sign',
#   ':)'],
#  ['good', 'caus', "i'd", 'like', 'upload', ':)'],
#  ['goood', 'mornin', 'earthl', ':D'],
#  ['happi', 'tweet', 'like', 'new', 'build', ':)', 'mm'],
#  ['okay', 'yay', 'ask', 'tomorrow', 'pleas', ':)'],
#  ['alway', ':)', 'posit'],
#  ['lamp', 'shop', ':)'],
#  ['word',
#   'big',
#   'site',
#   'got',
#   'chang',
#   'a-foot',
#   ':)',
#   'websit',
#   'develop',
#   'revamp'],
#  ['vote', 'brainchild', '3', 'time', 'pleas', 'may', 'poem', ':D'],
#  ['confid', 'confin', 'u', 'ur', 'limit', ':)'],
#  ['wish', 'colorado', ':)'],
#  ['happi',
#   'friday',
#   'folk',
#   'order',
#   'goodyear',
#   'tyre',
#   'onlin',
#   'get',
#   'upto',
#   '£',
#   '40',
#   'cashback',
#   'cs',
#   'appli',
#   'yourewelcom',
#   ':)'],
#  ['nightli', 'routin', 'simpin', ':-)'],
#  ['add', 'snapchat', 'yall', ':)', 'give', 'name'],
#  ["i'm", 'look', 'influenc', 'app', ':)', 'interest', "here'", 'invit'],
#  ['sketchbook',
#   'art',
#   'love',
#   '4wild',
#   'draw',
#   'hair',
#   'turn',
#   'pretti',
#   'cool',
#   ':D',
#   'art',
#   'hair',
#   'color',
#   'colorpencil',
#   'cray',
#   '…'],
#  ['tune', 'back', 'hubbi', ':)', 'u', 'play', 'queen', 'pl'],
#  ['fell',
#   'asleep',
#   'like',
#   '6:30',
#   "can't",
#   'fall',
#   'asleep',
#   'two',
#   'hour',
#   ':-)'],
#  ['great', 'night', 'great', 'peopl', ':)'],
#  ['imma', 'use', 'next', 'time', ':)'],
#  ['ob', '11h', 'v', 'kino', ':)'],
#  ['gone',
#   'make',
#   'tho',
#   'posit',
#   'day',
#   ':)',
#   'adult',
#   "can't",
#   'keep',
#   'act',
#   'like',
#   'mom'],
#  ['hi',
#   'see',
#   'u',
#   'like',
#   'fourfivesecond',
#   'think',
#   'u',
#   'might',
#   'like',
#   'deaf',
#   'ear',
#   'plz',
#   'let',
#   'know',
#   'u',
#   'think',
#   ':)'],
#  ['great',
#   'went',
#   'kardamena',
#   'last',
#   'summer',
#   'amaz',
#   'beach',
#   'wonder',
#   'sea',
#   'year',
#   'time',
#   'go',
#   'samo',
#   'greec',
#   ':)',
#   ':)'],
#  ['chicken', 'caesar', 'salad', 'tad', 'bland', 'live', ':)'],
#  ['love', 'afraid', 'respond', 'hate', ':)', 'x', 'x', 'x'],
#  ['first',
#   'leg',
#   'tour',
#   'go',
#   'well',
#   ':D',
#   'music',
#   'band',
#   'rock',
#   'magictrik',
#   'tour'],
#  ['okk',
#   'den',
#   'call',
#   'abp',
#   'n',
#   'spread',
#   'allov',
#   'india',
#   'n',
#   'abroad',
#   'well',
#   ':p'],
#  ['thank', 'much', ':)'],
#  ['pleas',
#   'let',
#   'us',
#   'know',
#   'store',
#   'abl',
#   'visit',
#   'may',
#   'inform',
#   'expect',
#   ':)'],
#  ['tweet', 'much', 'appreci', 'thank', 'dedic', 'member', ':)'],
#  ['freedom', 'hangout', 'whoever', 'want', ':)'],
#  ["i'm", 'like', ':)'],
#  ['hi',
#   ':-)',
#   'look',
#   'tourist',
#   'info',
#   'get',
#   'applic',
#   'zonzofox',
#   'click',
#   'link',
#   'bye',
#   ';-)'],
#  ['leo', 'season', ':-)', '♌', '️'],
#  ['life', 'kutiyapanti', ':D', 'love', 'life', ':D'],
#  ['thank', 'support', ':)', 'ceo', '1month'],
#  ['profession',
#   'hit',
#   'video',
#   'wick',
#   'boomshot',
#   'fuh',
#   'di',
#   'world',
#   'even',
#   'thank',
#   ':)'],
#  ['yeeey',
#   'welcom',
#   'club',
#   'one',
#   'half',
#   'year',
#   'whatsapp',
#   'donot',
#   'regret',
#   ':)'],
#  ['problem', ':)', 'pleasur', '❤', '️'],
#  ['send', 'one', 'pleas', ':)', 'wont', 'expos', 'roast', '3'],
#  ['lemm', 'cover', 'u', 'lipstick', 'n', 'cran', 'vodka', ':-)'],
#  ['road', 'trip', ':D'],
#  ['alway', 'walk', 'past', 'place', 'may', 'go', 'tri', ':D'],
#  ['yeah', "i'v", 'lost', 'call', 'day', ':)'],
#  ['jummah', 'mubarak', 'prayr', ':)'],
#  ['member', 'හ', 'ෙ', 'ල', 'හව', 'ු', 'ල', 'chanc', ':D'],
#  ['miss', 'babi', ':)', 'onemochaonelov'],
#  ['yo', 'southpaw', 'great', 'movi', 'someon', 'better', 'get', 'award', ':D'],
#  ['music', 'human', 'geniu', 'stroma', ':)'],
#  ['🔴', 'live', 'younow', 'jonah', 'jareddd', ':)'],
#  ['messag',
#   'full',
#   'name',
#   'dob',
#   'address',
#   'postcod',
#   'talkmobil',
#   'phone',
#   'number',
#   'thank',
#   ':)'],
#  ['last', 'class', 'morn', 'two', 'week', 'break', ':-)'],
#  ['happi', 'happi', 'birthday', 'emili', ':D'],
#  ['elf',
#   'fight',
#   'huha',
#   ':D',
#   ':)',
#   'teenchoic',
#   'choiceinternationalartist',
#   'superjunior'],
#  ['may', 'find', 'confus', ':)', 'simpl', 'wolf'],
#  ['nice', 'pic', ':)'],
#  ['promot', ':)'],
#  ['yeah', 'bird', 'transform', 'sword', ':D'],
#  ['even', 'real', 'word', ':D'],
#  ['could', 'misread', 'wors', 'thing', ':p'],
#  ['forward', "richardit'", 'follow', ':)'],
#  ['hey', 'like', 'fnaf', 'check', 'youtub', 'channel', ':)', 'via'],
#  ['yup',
#   'happen',
#   'everywher',
#   'peopl',
#   'cant',
#   'debat',
#   'come',
#   'name',
#   'call',
#   ':-)'],
#  ['need',
#   'get',
#   'work',
#   'today',
#   'ibiza',
#   ':)',
#   ':)',
#   ':)',
#   'birthdaymoneyforjesusjuic'],
#  ['anytim', ':)'],
#  ['mistak',
#   'happen',
#   'man',
#   'long',
#   'get',
#   'play',
#   'game',
#   "we'll",
#   'happi',
#   ':)'],
#  ['hey',
#   'wanna',
#   'check',
#   'ytb',
#   'channel',
#   'post',
#   'gameplay',
#   'tutori',
#   ':)',
#   'via'],
#  ['one',
#   'construct',
#   'critic',
#   'welcom',
#   ':)',
#   'ganesha',
#   'textur',
#   'photographi',
#   'art',
#   'hinduism',
#   'hindugod',
#   'elephantgod'],
#  ['ye', 'alway', 'selfish', 'fuck', ':)'],
#  ['hey', 'like', 'fnaf', 'check', 'youtub', 'channel', ':)', 'via'],
#  ['want',
#   'creat',
#   'first',
#   'bboy',
#   'cardgam',
#   'pixelart',
#   'gamedesign',
#   ':D',
#   'think',
#   'indiedev',
#   'pixel_daili',
#   'gamedev'],
#  ['sound', 'still', 'like', 'good', 'idea', ':)'],
#  ['limit',
#   'plateau',
#   'must',
#   'stay',
#   'must',
#   'go',
#   'beyond',
#   ':)',
#   'bruce',
#   'lee'],
#  ['man', 'sing', 'rain', ':)'],
#  ['laguna', ':)', 'see'],
#  [':)',
#   'nhi',
#   'tha',
#   'offic',
#   'work',
#   'bahot',
#   'tha',
#   'baje',
#   'raat',
#   'ko',
#   'liya',
#   'tha',
#   'hath',
#   'tri',
#   'creat',
#   'best',
#   '2',
#   'ghant',
#   'itna',
#   'hi',
#   'bana',
#   'paya'],
#  ["that'", 'true', 'quit', 'whenev', 'want', ':D'],
#  ['thank', ':)', 'weekend', 'tri', 'best', ':)'],
#  ['u',
#   'like',
#   'uta',
#   'read',
#   'manga',
#   ':-)',
#   'love',
#   'even',
#   ':-)',
#   'haha',
#   'yeah'],
#  ['famili', 'hang', ':)', '—', 'feel', 'festiv', 'jamuna', 'futur', 'park'],
#  ['move',
#   'forward',
#   'happi',
#   'spirit',
#   'find',
#   'thing',
#   'alway',
#   'work',
#   '\\:'],
#  ['rememb', 'sent', 'present', 'last', 'christma', 'dub', 'swiftma', ':)'],
#  ['miss', ':-)'],
#  ['super', 'proud', ':)'],
#  ['love', 'pic', 'fab', 'show', ':-)', 'x'],
#  ['morn', ':)'],
#  ['tha', 'case', 'trion', 'interact', 'forum', 'twitch', ':)'],
#  ["that'", 'spirit', ':)', 'wsalelov'],
#  ['sort',
#   'earli',
#   'hour',
#   'thank',
#   'help',
#   'rais',
#   'initi',
#   'issu',
#   'make',
#   'commun',
#   ':)'],
#  ['hii',
#   'follow',
#   'pleas',
#   "i'd",
#   'like',
#   'ask',
#   'one',
#   'thing',
#   'dm',
#   ':)',
#   '💞'],
#  ['happi', 'b-day', ':)'],
#  ["that'", 'disgust', 'glad', 'acc', 'back', ':)', 'hope', 'get', 'deserv'],
#  ['back',
#   '80',
#   'brand',
#   'new',
#   'commodor',
#   '64',
#   'program',
#   'commun',
#   'town',
#   ':)',
#   '12th',
#   'august'],
#  ['okay', ':)'],
#  ['im', 'wear', 'mine', 'dj', 'next', 'fri', ':-)'],
#  ['thank',
#   'take',
#   'time',
#   'tweet',
#   'us',
#   'annabel',
#   "we'll",
#   'pass',
#   'london',
#   'bridg',
#   'team',
#   ':)'],
#  ['alreadi', ':)'],
#  ['everi', 'way', 'like', 'jess', ':)'],
#  ['happi', 'friday', ':)'],
#  ['short', 'routin', 'quest', 'borderland', ':)', 'wanderrook'],
#  ['thank',
#   'made',
#   'day',
#   ':)',
#   "let'",
#   'organis',
#   'meet',
#   'soon',
#   'base',
#   'london'],
#  ["i'm",
#   'person',
#   'workout',
#   'eat',
#   'healthi',
#   'minut',
#   'gain',
#   'weight',
#   ':-)'],
#  ['gm',
#   'meet',
#   'preciou',
#   'soft',
#   'ladi',
#   'real',
#   'friend',
#   'mizz',
#   'preciou',
#   ':)',
#   ';)',
#   'mani',
#   'like'],
#  ['aameen', ':)', 'live', 'pakistanbleedgreen', '✌', '🏻', '️'],
#  ['alreadi', 'follow', 'back', 'oppa', ':)'],
#  ['liam', 'sophia', 'chicago', ':)', '♥'],
#  ['btw', 'honeymoon', ':)'],
#  ['yeah', 'bring', 'boom', "da'esh", 'co-ord', 'fsa', 'estat', ':)'],
#  ['welcom', ':)', "when'", 'next', 'meet'],
#  ['singer',
#   'dusti',
#   'tunisia',
#   '3',
#   'music',
#   'tunisia',
#   '3',
#   'wonder',
#   'nice',
#   'peopl',
#   ':-)',
#   '3'],
#  ['la', "class'", ':p'],
#  ['hahaha', 'go', 'doug', ':-)'],
#  ['forgot', 'ask', 'may', 'post', 'fb', 'happi', 'friday', ':-)'],
#  ['visit', 'blog', 'thank', ':D'],
#  ['everyon', 'fuckin', 'irrit', ':)'],
#  ['also',
#   'mean',
#   'imma',
#   'go',
#   'back',
#   'twitter',
#   'activ',
#   ':D',
#   'know',
#   'everyon',
#   'miss',
#   ';)',
#   'xd'],
#  ['hello',
#   'ladi',
#   'apolog',
#   'delay',
#   'pleas',
#   'dm',
#   'us',
#   'address',
#   'size',
#   'detail',
#   "we'll",
#   'ship',
#   'prize',
#   ':)'],
#  ['free', 'voucher', 'twitter', 'friend', 'use', 'fiverr', ':)'],
#  ['oh',
#   'gina',
#   'busi',
#   ':-)',
#   "can't",
#   'wait',
#   'see',
#   'hear',
#   'xxx',
#   'soproud'],
#  ['happi', 'friday', 'everyon', 'hope', 'fantast', 'week', ':)', 'friday'],
#  ['ye', 'one', 'team', ':)'],
#  ['happi', 'belat', 'birthday', 'sweeti', ':)'],
#  ['morn', 'emma', ':)'],
#  ['thank', 'guy', ':)'],
#  ['would', 'say', ':-)'],
#  ['love', 'make', 'two', 'heart', 'one', ':)'],
#  ['thank',
#   'ad',
#   'us',
#   'list',
#   ':)',
#   'make',
#   'sure',
#   'keep',
#   'touch',
#   'news',
#   'light',
#   'bulb',
#   'made',
#   'corn',
#   'wast'],
#  ['thank', 'mr', 'bee', 'xxx', ':-)'],
#  ['thankyou', ':)'],
#  ['close', 'enought', ':)'],
#  ['good', 'luckanoth', 'potenti', 'favourit', 'water', 'hole', ':-)'],
#  ['bad', 'boy', ':)', 'burger', 'melbourneburg'],
#  ['want', 'ft', 'arianna', ':-)'],
#  ['everyon', 'follow', ':)'],
#  ['hey', 'lesley', 'sorri', 'get', 'shall', 'send', 'post', 'tonight', ':)'],
#  ['thank', 'esai', ':-)'],
#  ['thank', 'text', 'back', ':)', "i'm", 'text', 'tomorrow', ':)'],
#  ['unfollow', 'back', ':)'],
#  ['hope',
#   'enjoy',
#   'stay',
#   'rotterdam',
#   'know',
#   'cheer',
#   'jordi',
#   'clasi',
#   ':)'],
#  ['hi', 'hot', 'girl', 'say', 'hot', 'horni', 'darl', 'xx', ':)', '♥'],
#  ['sure', 'done', ':)'],
#  ['salon', 'bleach', 'hair', 'olaplex', 'damag', 'like', ':)'],
#  ['teamwork', 'right', ':D', 'zitecofficestori'],
#  ['ff', 'happyfriday', 'great', 'friday', ':-)'],
#  ['sure', ':)'],
#  ['다쇼', 'got', '7', 'got', '7', 'fact', ':)'],
#  ['still',
#   'tomorrow',
#   'work',
#   'colleagu',
#   'interest',
#   'bring',
#   'kid',
#   'along',
#   ':)',
#   'point',
#   'eb',
#   'page'],
#  ['tack', '3', ':D'],
#  ["t'would", 'tweetup', 'without', 'book', 'rest', 'assur', 'book', ':)'],
#  ['thank',
#   'much',
#   'know',
#   'greatest',
#   'magic',
#   'detect',
#   'jonathancreek',
#   'back',
#   'tv',
#   'set',
#   'dvr',
#   ':)'],
#  ['get', 'home', '4', 'wake', '9', ':)', ':)'],
#  ['thank', 'take', 'time', 'tweet', 'kat', ':)'],
#  ['lot', 'rarer', 'life', 'twitter', ':)'],
#  ['okkk', 'frend', 'milt', 'h', 'break', 'k', 'bad', ':)'],
#  ['could', 'fun', 'sexi', 'girl', 'two', 'sexi', 'girl', ':)', '👉', '👈', '😘'],
#  ['thank', 'mario', 'wonder', 'friday', ':)'],
#  ['fun', 'daniel', 'hope', 'goe', 'well', ':-)'],
#  ['thank', 'hope', 'got', 'good', 'book', 'keep', 'compani', ':-)'],
#  ['yeah',
#   "i'v",
#   'watch',
#   'cours',
#   'rewatch',
#   'ad',
#   'free',
#   'faster',
#   'hope',
#   ':)',
#   'thank',
#   'look',
#   'forward'],
#  ['price',
#   'around',
#   '1600',
#   "i'm",
#   'gonna',
#   'forward',
#   'info',
#   'email',
#   'decid',
#   'interest',
#   ':)'],
#  ['got', 'bed', 'yet', ':-)'],
#  ['awww',
#   'sige',
#   'next',
#   'time',
#   'u',
#   'know',
#   'na',
#   'punta',
#   'kayo',
#   'dun',
#   'imma',
#   'make',
#   'sure',
#   'na',
#   "we'll",
#   'go',
#   'din',
#   ':-)'],
#  ['sure', 'thing', ':)', 'x'],
#  ['friday', ':D'],
#  ['cours', 'would', 'like', ':)', 'x'],
#  ['nooo', 'didnt', 'even', 'know', 'that', 'actual', 'type', 'googl', ':)'],
#  ['found', 'prompt', ':-)'],
#  ['chillin', 'w', 'salmon', ':)'],
#  ['see', 'beauti', 'believ', 'exist', 'first', ':)'],
#  ['hi',
#   'j',
#   'upgrad',
#   't-mobil',
#   'orang',
#   'ee',
#   'us',
#   'dm',
#   'mobil',
#   'number',
#   "i'll",
#   'ask',
#   'sale',
#   'call',
#   ':)'],
#  ['congratul',
#   'realli',
#   'look',
#   'forward',
#   'book',
#   'good',
#   'sunday',
#   'morn',
#   'view',
#   "that'",
#   'awesom',
#   'teapot',
#   'btw',
#   ':-)',
#   'x'],
#  ['three',
#   'refresh',
#   'cocktail',
#   'even',
#   '«',
#   'hotter',
#   '»',
#   'summer',
#   'one',
#   'suit',
#   ':)',
#   'cocktail'],
#  ['love', ':)', '3'],
#  ['wip',
#   'let',
#   'get',
#   'thing',
#   'tweak',
#   "i'll",
#   'link',
#   ':)',
#   'max',
#   'kal',
#   'tak'],
#  ['fab', 'giveaway', ':)'],
#  ['case', 'facebook', 'wall', ':p'],
#  ['stat', 'week', 'arriv', '3', 'new', 'follow', 'unfollow', ':)', 'via'],
#  ['home', 'alon', ':D'],
#  ['wish', 'happi', 'birthday', 'awesom', 'fun', 'fill', 'day', ':D'],
#  ['let', 'know', 'hear', 'anyth', ':)', 'xx'],
#  ['wayward', 'pine', 'later', ':)'],
#  ['yeah', 'better', 'use', 'offici', 'account', ':)', 'like', '❤', '️'],
# ...
#  ['ourdaughtersourprid', 'mani', 'mani', 'congratul', 'papa', 'ji', ':)'],
#  ['thank', 'becca', ':)'],
#  ['love', 'new', 'song', 'delta', 'rock', ':)'],
#  ['saw', 'thought', 'might', 'need', 'upgrad', 'girl', 'get', 'bigger', ':)'],
#  ['first',
#   'love',
#   'wanna',
#   'fuck',
#   'late',
#   'night',
#   'think',
#   'got',
#   'nut',
#   ':-)',
#   'v',
#   'look'],
#  ['enjoy', 'cute', 'babi', 'panda', ':)'],
#  ['done', 'yun', ':)'],
#  ['watch', 'joe', 'dirt', '2', ':)'],
#  ['ohh', 'happyfriday', 'thank', 'love', 'team', ':)'],
#  ['alway', 'posit', ':)', 'postiv', 'selfi'],
#  ['good',
#   'morn',
#   'sharon',
#   'realli',
#   'hope',
#   'better',
#   'today',
#   'medicin',
#   'work',
#   'thank',
#   ':)',
#   'ttyl',
#   'x'],
#  ['oh',
#   'fab',
#   'gav',
#   'love',
#   'love',
#   'ladi',
#   'linda',
#   'talk',
#   'time',
#   'great',
#   'actress',
#   ':D',
#   'x'],
#  ['follback', ':D'],
#  ['answer',
#   'super',
#   'sonic',
#   'fast',
#   ':)',
#   'would',
#   'love',
#   'win',
#   'first',
#   'time',
#   ';)',
#   'gohf'],
#  ['3hr', ':)', 'tym', 'prepar'],
#  ['dieback', 'music', 'pack', 'total', 'worth', 'awesom', ':)', 'dota', '2'],
#  ['morn', ':)'],
#  ['think',
#   'might',
#   'endit',
#   'london',
#   'photo',
#   'vid',
#   'minecon',
#   'london',
#   'video',
#   ':)',
#   'look',
#   'rememb',
#   'great',
#   'time'],
#  ['ok', 'sere', '2', 'play', 'yah', 'min', 'haha', ':)'],
#  ['joerin', 'scene', ':)', 'power', 'tandem'],
#  [':D', "can't", 'sleep', 'need', 'tri', 'lay', 'bed', 'bore'],
#  ['stat', 'day', 'arriv', '6', 'new', 'follow', 'unfollow', ':)', 'via'],
#  ['b', 'call', 'friend', 'need', ':)'],
#  ['hello', 'ligao', 'citi', 'albay', ':-)'],
#  ['goodnight', 'love', 'luke', 'heart', ':-)', 'love', '💜'],
#  ['happi', 'birthday', 'enjoy', 'vacat', ':)'],
#  ['congratul', 'sat', '3rd', 'honorari', 'degre', 'everyon', 'alac', ':)'],
#  ['hey',
#   'raspberri',
#   'island',
#   'skelo_ghost',
#   ':)',
#   'want',
#   'get',
#   'iph',
#   '0ne',
#   '6',
#   'free',
#   'kindli',
#   'check',
#   'bi0',
#   'thx'],
#  ['thank', 'u', ':)'],
#  ['thank', 'great', ':)', '❤', '️', '😘'],
#  ['deserv', 'madadagdagan', 'pa', 'yan', ':-)', 'congrat', ':-)', 'bmc', '3'],
#  ['save',
#   'money',
#   'use',
#   'good',
#   'way',
#   'money',
#   'better',
#   'life',
#   'fun',
#   ':)',
#   'nice',
#   'day',
#   '11'],
#  ['u',
#   'find',
#   'ur',
#   'friend',
#   'ditch',
#   'u',
#   'caus',
#   'lot',
#   'thing',
#   ':)',
#   'wtf',
#   'done',
#   'im',
#   'actual',
#   'nice',
#   'person'],
#  ['order', 'dress', ':)', ':)'],
#  ['like', 'eye', ':D'],
#  ['dear',
#   'person',
#   'pleas',
#   'studi',
#   'embarrass',
#   'urself',
#   'entropi',
#   'work',
#   '100',
#   'w',
#   'evolut',
#   ':)'],
#  ['ye', 'stay', 'touch', ':)', 'instagram'],
#  ['look',
#   'forward',
#   'alway',
#   'love',
#   'giggl',
#   'loop',
#   'two',
#   'great',
#   'act',
#   ':)'],
#  ['cheer', 'mention', 'even', 'wrong', 'section', ':)'],
#  ['ty', 'dear', "eva'm", 'total', 'agre', ':-)', 'smile', 'u'],
#  ['spain', 'morn', ':)', 'good', 'morn', 'ian'],
#  ['anoth', 'note', 'found', 'camden', 'town', ':D', 'work'],
#  ['even', 'talk', 'great', ':)'],
#  ['ohhh', 'wait', '28', ':)', 'luv', 'uhh'],
#  ['thank',
#   'favorit',
#   ':)',
#   'make',
#   'sure',
#   'keep',
#   'touch',
#   'news',
#   'light',
#   'bulb',
#   'made',
#   'corn',
#   'wast'],
#  ['scoup', '17', 'like', 'jren', 'nuest', ':D'],
#  ['oh', 'love', 'lovelayyy', 'thank', 'ok', 'kidney', 'want', 'anyway', ':p'],
#  ['neuer', 'post', 'onlin', ':)', 'fix', 'spray'],
#  ['check',
#   'us',
#   ':)',
#   'untangl',
#   'never',
#   'easier',
#   'dtangl',
#   'patent',
#   'innov'],
#  ['class', 'today', 'train', 'friend', ':)'],
#  ['okay', 'let', 'get', 'bat', ':)'],
#  ['one', 'fall', 'love', 'choic', '’', 'chanc', ':)', '♡'],
#  ['would', 'email', 'donnaestrydomgovza', ':-)', 'ta'],
#  ["that'",
#   'great',
#   'hear',
#   "we'll",
#   'sure',
#   'pass',
#   'thank',
#   'staff',
#   ':)',
#   'nic'],
#  ['seen', 'uni', 'talent', ':)'],
#  ['uff', 'itna', 'miss', 'karhi', 'thi', 'ap', ':p'],
#  ['aww', 'love', 'kind', 'men', ':)'],
#  ['mca', 'money', 'tell', 'stori', ':)'],
#  ['save', 'live', ':-)'],
#  ['hey',
#   'juaquin',
#   'v3nzor99',
#   ':)',
#   'want',
#   'get',
#   'iph',
#   '0ne',
#   '6',
#   'free',
#   'kindli',
#   'check',
#   'bi0',
#   'thx'],
#  ['break', 'shell', ':-)'],
#  ['truth', ':D'],
#  ['fantast', 'thank', ':)'],
#  ['heyi', ':)', 'u', 'rt', 'link', 'tag', 'michael', 'pleas', 'thank'],
#  ['hashtag', 'say', ':)'],
#  ['still', 'green', 'tea', 'blend', 'flavor', ':)'],
#  ["i'm", 'excit', "what'", 'come', ':)', 'realli', 'deserv'],
#  ['today', 'improv', 'tomorrow', ':-)', ':)'],
#  ['sometim', ':-)'],
#  ["i'm",
#   'sorri',
#   'ran',
#   'friend',
#   'rough',
#   'day',
#   "i'll",
#   'tri',
#   'stream',
#   'saturday',
#   ':)'],
#  ['get', 'well', 'soon', ':)', 'xx'],
#  ['bed', 'best', 'coupl', 'ever', ':)'],
#  ['favorit', 'appl', 'sauc', ':)'],
#  ['nice', 'holiday', 'honey', ':-)', 'kiss'],
#  ['follow', 'back', 'pleass', ':)'],
#  ['sir', ':)'],
#  ['thank', 'beatriz', ':)'],
#  ['rt', 'bailona', 'group', 'chat', 'approv', 'fanbas', ':)'],
#  ['parti', 'cancel', ':p', 'bajrangibhaijaanhighestweek', '1'],
#  ['thank', 'follow', ':-)', 'hope', 'great', 'week'],
#  ['puff',
#   'pastri',
#   'egg',
#   'tart',
#   'hot',
#   'fresh',
#   'oven',
#   ':)',
#   'wan',
#   'chai',
#   'mtr'],
#  ['thank',
#   'follow',
#   'us',
#   ':)',
#   'like',
#   'cool',
#   'new',
#   'product',
#   'check',
#   'campaign'],
#  ['make', 'alyssa', 'rub', 'tummi', ':)'],
#  ['almost', 'done', 'master', 'sword', ':D', 'princess', 'zelda'],
#  ['ive', 'email', 'regard', 'cours', 'queri', ':)'],
#  ['happi', 'birthday', '🎂', 'jiva', 'ever', ':)', '🍹', '🍸', '🍻'],
#  ['awesom', 'news', 'mate', 'well', 'happi', ':)'],
#  ['jumma', 'mubbarak', ':)', '❤', '❤'],
#  ['gorgeou',
#   'deborah',
#   'good',
#   'tast',
#   ':)',
#   'use',
#   'coupon',
#   'code',
#   'colourdeb',
#   'red',
#   'purpl',
#   'blue',
#   'thank'],
#  ['im',
#   'sure',
#   'wasnt',
#   'anyth',
#   "we'r",
#   'alreadi',
#   'use',
#   ':)',
#   'glad',
#   'ur',
#   'home'],
#  ['wooo', 'happi', 'friday', 'friend', ':)', 'ff'],
#  ['plan',
#   'send',
#   'email',
#   "chippy'",
#   'vessel',
#   'monday',
#   'ps',
#   'happi',
#   'anniversari',
#   'haha',
#   ':)'],
#  ['comput', 'sex', 'count', ':)', 'funni', 'vintag'],
#  ['use',
#   "i'll",
#   'pick',
#   'next',
#   'time',
#   "i'm",
#   ':)',
#   'yeah',
#   "i'll",
#   'cook',
#   'nice',
#   'big',
#   'kitchen',
#   '😍',
#   '😊'],
#  ['love', 'great', 'collag', ':)'],
#  ['✫',
#   '✧',
#   '˚',
#   '✧',
#   '·',
#   '✵',
#   '⊹',
#   'alway',
#   'put',
#   'smile',
#   'face',
#   'follow',
#   ':)',
#   'nice',
#   'day',
#   'x'],
#  ['look',
#   'fun',
#   'snapchat',
#   'gooffeanotter',
#   'snapchat',
#   'kiksex',
#   'snapm',
#   'lesbian',
#   'instagram',
#   'mpoint',
#   'mugshot',
#   ':)'],
#  ["can't",
#   'sleep',
#   'much',
#   'want',
#   'love',
#   'bug',
#   'made',
#   '33',
#   'token',
#   'never',
#   'mind',
#   ':)'],
#  ['gamer', 'follow', 'train', 'retweet', 'activ', 'follow', ':)', '110'],
#  ['look', 'forward', 'hear', 'thought', ':)', 'maritimen'],
#  ['stat', 'day', 'arriv', '2', 'new', 'follow', 'unfollow', ':)', 'via'],
#  ["there'",
#   'stun',
#   'show',
#   'garden',
#   'rh',
#   'tatton',
#   'park',
#   'show',
#   'wonder',
#   'design',
#   'construct',
#   'plant',
#   ':)'],
#  ['behav', 'els', 'u', 'jump_julia', 'malema', ':D'],
#  ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow'],
#  ['great', 'friday', 'fren', ':-)'],
#  ['nuf',
#   'teas',
#   'alreadi',
#   'show',
#   'us',
#   'alien',
#   'everyday',
#   'seem',
#   'get',
#   'closer',
#   'see',
#   'alien',
#   'cousin',
#   ':-)'],
#  ['new', 'monitor', 'good', ':D'],
#  ['good', 'morn', 'kimmi', ':)'],
#  ["channel'",
#   'show',
#   'planetbollywoodnew',
#   'full',
#   'epi',
#   'avail',
#   'onlin',
#   ':)'],
#  ['evolut', ':D'],
#  ['fback', ':)'],
#  ['love', 'airport', ':-)', ':-)'],
#  ['love', ':)', 'want', 'corn', 'chip', ':)'],
#  ['thank', ':)', 'tricki', 'bt', 'v', 'import', 'subject'],
#  ['hah', ':D', 'say', 'sorri'],
#  ['be-shak', ':p'],
#  [':)'],
#  ['happi',
#   'birthday',
#   'miss',
#   'chenoweth',
#   'hope',
#   'great',
#   'one',
#   'oodl',
#   'cake',
#   ':)'],
#  ['happi', 'birthday', 'gorgeou', 'hope', "i'll", 'see', 'fair', ':)'],
#  ['im',
#   'go',
#   'bed',
#   'love',
#   'hailey',
#   'milk',
#   'craźi',
#   'sęxxxÿ',
#   'cøôl',
#   'runway',
#   'look',
#   ':)'],
#  ['feel', 'someon', 'share', 'review', 'work', 'hard', ':D'],
#  ['gooodnight',
#   'love',
#   'boy',
#   'iv',
#   'ri',
#   'zoe',
#   'kati',
#   'jayci',
#   'jen',
#   ':)'],
#  ['well',
#   'bud',
#   'guess',
#   "i'm",
#   'go',
#   'bed',
#   'goodnight',
#   'guy',
#   'see',
#   'morn',
#   'whatev',
#   'woke',
#   ':)'],
#  ['thank', 'follow', 'great', 'day', ':)'],
#  ['thank', ':)'],
#  ['bad', 'thing', 'think', 'weird', 'face', 'rad', ':-)', 'thank', 'though'],
#  ['make',
#   'aliv',
#   'make',
#   'suffer',
#   'make',
#   'feel',
#   'song',
#   'alway',
#   'sing',
#   'karaok',
#   ':-)'],
#  ['realli', 'cuti', ':D'],
#  ['ltsw', 'gooo', ':-)'],
#  ['thank',
#   'favorit',
#   ':)',
#   'make',
#   'sure',
#   'keep',
#   'touch',
#   'news',
#   'light',
#   'bulb',
#   'made',
#   'corn',
#   'wast'],
#  ['threw', 'phone', 'wall', ':)'],
#  ['giant', 'balloon', 'want', 'one', ':)'],
#  ['face', 'time', ':)'],
#  ["what'", 'hashtag', 'weekend', 'guy', ':)'],
#  ['one',
#   'look',
#   'like',
#   'need',
#   'much',
#   'care',
#   'studi',
#   "i'll",
#   'favourit',
#   'later',
#   ':-)'],
#  ['welcom', 'hun', ':)', 'thank', 'follow'],
#  ['12pm', ':)'],
#  ['thank', 'much', 'mom', 'get', 'ticket', ':)'],
#  ['thank', 'manila_bro', 'follow', "let'", 'connect', 'soon', ':)'],
#  ['lol',
#   'sometim',
#   'tweet',
#   'account',
#   'lol',
#   'day',
#   'home',
#   'dont',
#   'lot',
#   'say',
#   ':D'],
#  ['✫',
#   '✧',
#   '˚',
#   '✧',
#   '·',
#   '✵',
#   '⊹',
#   'alway',
#   'put',
#   'smile',
#   'face',
#   'follow',
#   ':)',
#   'nice',
#   'day',
#   'x'],
#  ['hope',
#   'one',
#   'day',
#   "he'll",
#   'fall',
#   'love',
#   'strong',
#   'woman',
#   'let',
#   'see',
#   'thing',
#   'refus',
#   'see',
#   ':)'],
#  ['lol', ':)'],
#  ["that'", 'great', 'idea', 'love', 'fellow', 'veggi', ':-)'],
#  ['c', '75', 'made', 'collagen', 'an', '2win', 'hopetowin', ':)'],
#  ['awww', 'thank', 'hey', 'million', ':)', 'enjoy', 'weekend', 'hey'],
#  ['guess',
#   'need',
#   'build',
#   'content',
#   'around',
#   'imag',
#   'inventori',
#   'littl',
#   'bit',
#   ':)'],
#  ['gamer', 'follow', 'train', 'retweet', 'activ', 'follow', ':)', '1'],
#  ['snap', ':)'],
#  ['bring',
#   'togeth',
#   'friend',
#   'famili',
#   'loveforfood',
#   'foodforthought',
#   'thoughtfortheday',
#   ':)'],
#  ['carp', 'diem', 'mr', 'nath', ':)'],
#  ['yep',
#   "i'd",
#   'without',
#   'ning',
#   'recommend',
#   'book',
#   'thought',
#   'wow',
#   ':)',
#   'think',
#   'gener',
#   'posit',
#   'lead'],
#  ['ty', 'appreci', 'recent', 'retweet', 'great', 'friday', ':)'],
#  ['11:11',
#   'meet',
#   'michael',
#   'hug',
#   'tight',
#   'talk',
#   'tell',
#   "he'",
#   'import',
#   'love',
#   'much',
#   'make',
#   'smile',
#   ':D'],
#  ['long',
#   'feel',
#   'comfort',
#   'im',
#   'gonna',
#   'wear',
#   'want',
#   'mother',
#   'hahathat',
#   'sound',
#   'nicebut',
#   ':-)'],
#  ['congratul', 'daughter', ':D'],
#  ['goodnight', 'love', 'everyon', 'hate', 'stupid', ':)'],
#  ['thank',
#   'fill',
#   'although',
#   'opinion',
#   'still',
#   'stand',
#   'agre',
#   'disagre',
#   'harm',
#   'done',
#   ':)'],
#  ['see', 'saturday', ':p', "i'll", 'see', 'stormi', ':D'],
#  ['time', '2', 'parti', ':D'],
#  ['upgrad',
#   'an',
#   'sync',
#   'plu',
#   'done',
#   'singl',
#   'remot',
#   'devic',
#   'get',
#   'folk',
#   ':)'],
#  ['haha', 'know', 'mess', ':D'],
#  ['want', 'say', 'huge', 'thank', 'ff', 'thank', 'support', ':)'],
#  ['found',
#   'song',
#   'mention',
#   'nylon',
#   'gvb',
#   'cd',
#   'take',
#   'mountaintitl',
#   'unto',
#   'other',
#   'theworldwouldchang',
#   ':)'],
#  ['relat',
#   'would',
#   'make',
#   'new',
#   'categori',
#   'blog',
#   'everyth',
#   'one',
#   'place',
#   ':)'],
#  ['yah', 'know', "i'm", 'good', 'fake', 'mah', 'emot', ':)'],
#  ['go',
#   'nice',
#   'mother',
#   'daughter',
#   'day',
#   'today',
#   ':)',
#   'even',
#   'though',
#   'rain',
#   'morn',
#   'great',
#   'day',
#   'folk',
#   'xx'],
#  ['idk', 'cant', 'wait', 'tonight', 'panel', 'peopl', ':)'],
#  [':)', 'reason', 'dream'],
#  ["i'am", 'elf', 'hbu', ':)'],
#  ['follow', 'back', 'pleass', ':)'],
#  ['ps', 'took', '80-1', 'hope', 'count', ':-)'],
#  ['✫',
#   '✧',
#   '˚',
#   '✧',
#   '·',
#   '✵',
#   '⊹',
#   'alway',
#   'put',
#   'smile',
#   'face',
#   'follow',
#   ':)',
#   'nice',
#   'day',
#   'x'],
#  ['yeah', 'neenkin', 'congrat', 'success', 'masterpiec', ':)', '🎉'],
#  ['goodmorn', 'smile', 'debit', 'order', ':)', 'soon'],
#  ['thank', 'work', 'beagl', 'amaz', 'incred', ':)'],
#  ['rt', 'bailona', 'group', 'chat', 'approv', 'fanbas', ':)'],
#  ['rememb',
#   'someon',
#   ':)',
#   '♫',
#   'see',
#   'feat',
#   'charli',
#   'puth',
#   'wiz',
#   'khalifa',
#   '—'],
#  ['cours', ':)'],
#  ['hi', 'dylan', 'tyler', ':)', '♡', '♡', '♡'],
#  ['favorit', 'tea', ':)'],
#  ["i'v",
#   'done',
#   'today',
#   'watch',
#   'law',
#   'order',
#   'svu',
#   'love',
#   'sick',
#   ':-)'],
#  ['pleasur', ':D', 'enjoy', 'day'],
#  ['fine', 'day', ':)'],
#  ['morn',
#   'wear',
#   'get',
#   'darker',
#   'end',
#   'world',
#   'day',
#   'today',
#   'instead',
#   'septemb',
#   ':-)'],
#  ['lmao', 'love', 'berni', ':D'],
#  ['lol', 'morn', ':)', 'wet', 'hey', 'friday', ':)'],
#  ['aint',
#   'never',
#   'upload',
#   'lol',
#   'also',
#   'found',
#   'anoth',
#   'vid',
#   'u',
#   'danc',
#   'henri',
#   'trap',
#   'keep',
#   'go',
#   'fit',
#   'journey',
#   'tommi',
#   ':)'],
#  ['ye',
#   'think',
#   'b',
#   'stupid',
#   'discuss',
#   'abt',
#   'wild',
#   'card',
#   'entri',
#   'jst',
#   'wait',
#   "vivian'",
#   'perform',
#   ':)'],
#  ['new',
#   'blog',
#   'import',
#   'life',
#   'lesson',
#   'learnt',
#   'watch',
#   'movi',
#   ':)',
#   'someth',
#   'everyon',
#   'need',
#   'rememb',
#   'xx'],
#  ["i'm", 'best', 'perfect', 'promis', 'love', 'whole', 'heart', ':)'],
#  ['u', 'transparentglass', ':-)'],
#  ['thank',
#   'share',
#   'bitcoin',
#   'news',
#   'stream',
#   'great',
#   'monday',
#   ':)',
#   'insight',
#   'h'],
#  ['ye', ':D'],
#  ['thank',
#   'retweet',
#   ':)',
#   'make',
#   'sure',
#   'keep',
#   'touch',
#   'news',
#   'light',
#   'bulb',
#   'made',
#   'corn',
#   'wast'],
#  ['rang',
#   'sick',
#   'yesterday',
#   'told',
#   "i'd",
#   'back',
#   'today',
#   "i'm",
#   'better',
#   'morn',
#   'anyway',
#   'day',
#   'sunday',
#   ':)'],
#  ['ping', "i'm", 'watch', 'tl', 'like', 'hawk', ':D'],
#  ['make', 'use', 'masquerad', 'mask', 'lol', 'zorroreturm', ':-)'],
#  ['hope', 'help', ':-)'],
#  ['congrat', 'ryan', 'jami', 'delight', ':)', 'xx'],
#  ['✫',
#   '✧',
#   '˚',
#   '✧',
#   '·',
#   '✵',
#   '⊹',
#   'alway',
#   'put',
#   'smile',
#   'face',
#   'follow',
#   ':)',
#   'nice',
#   'day',
#   'x'],
#  ['thank', 'mention', 'happi', 'friday', ':)'],
#  ['ye', 'pk', 'hay', ':p'],
#  ['hi',
#   'jacquelin',
#   "we'r",
#   'sorri',
#   'hear',
#   'pleas',
#   'dm',
#   'us',
#   'contact',
#   'detail',
#   'give',
#   'call',
#   ':)'],
#  ['passion',
#   'beer',
#   'ultim',
#   'made',
#   'way',
#   'becom',
#   'full-fledg',
#   'busi',
#   ':)',
#   'entrepreneur',
#   'startup'],
#  ['thank', 'guy', ':)', 'fun', ':)', 'anoth', '1', ';)'],
#  ['hi',
#   "i'm",
#   'see',
#   'workplac',
#   'one',
#   'venu',
#   'list',
#   "i'm",
#   'sure',
#   'fix',
#   'thank',
#   ':)'],
#  ['oh',
#   'wow',
#   'thank',
#   ':)',
#   'skin',
#   'go',
#   'perfect',
#   'time',
#   'head',
#   'lago',
#   'travel'],
#  ['wow',
#   'luxord',
#   'look',
#   'realli',
#   'amaz',
#   'new',
#   'kingdom',
#   'heart',
#   '3',
#   'promo',
#   'art',
#   ':)'],
#  ['new', 'potato', 'garden', 'hundr', 'dig', ':)'],
#  ['love', ':D'],
#  ['thank', 'love', 'weekend', 'everyon', ':-)'],
#  ['well', 'total', 'blew', 'mind', 'morn'],
#  ['cours', "i'v", 'cite', 'academ', 'paper', 'feel', "i'v", 'arriv', ':-)'],
#  ['life', 'smile', ':)'],
#  ['thank', 'info', ':)'],
#  ['sure',
#   'watch',
#   'pokiri',
#   '1nenokkadin',
#   'tym',
#   'fav',
#   ':-)',
#   'bajrangibhaijaanhighestweek',
#   '1'],
#  ['yang', 'retweet', ':)', ':D'],
#  ["who'", 'still', 'awak', ':)'],
#  ['heritag', 'sword', 'made', 'wood', ':D'],
#  ['right', 'thx', 'andrew', 'great', 'day', ':)'],
#  ['true', ':)'],
#  ['beleaf', 'u', ':-)'],
#  ['cool', 'video', 'love', ':)', 'thank', 'u'],
#  ['season',
#   '11',
#   'set',
#   '♡',
#   'nice',
#   'friday',
#   'spnfamili',
#   ':)',
#   'spn',
#   '11',
#   'alwayskeepfight',
#   'jaredpadalecki',
#   'jensenackl'],
#  ['cool', ':D'],
#  ['exactli', ':D'],
#  ['peasant', 'seat', 'watch', 'peasant', 'teami', 'mind', ':p', 'ahahha'],
#  ['chri',
#   "that'",
#   'great',
#   'hear',
#   ':)',
#   'due',
#   'time',
#   'remind',
#   'inde',
#   'plan',
#   'avail',
#   'distant',
#   'futur'],
#  ['thank', 'shout-out', ':)', 'great', 'aboard'],
#  ['hey', ':)', 'long', 'time', 'talk'],
#  ['matt', 'would', 'say', 'welcom', 'adulthood', ':)'],
#  ['could', 'say', 'egg', 'face', ':-)'],
#  ...]

# %%
x2=gen_features(stemx2,freq)
x2
# Out:
# [[1, 3369, 401],
#  [1, 3411, 391],
#  [1, 1376, 327],
#  [1, 3052, 114],
#  [1, 802, 27],
#  [1, 3393, 283],
#  [1, 551, 19],
#  [1, 1136, 425],
#  [1, 1156, 294],
#  [1, 3210, 29],
#  [1, 3308, 146],
#  [1, 3140, 252],
#  [1, 3108, 36],
#  [1, 3049, 104],
#  [1, 2966, 4],
#  [1, 3470, 95],
#  [1, 3163, 216],
#  [1, 528, 3],
#  [1, 567, 14],
#  [1, 802, 27],
#  [1, 3507, 115],
#  [1, 2960, 6],
#  [1, 2964, 3],
#  [1, 738, 52],
#  [1, 3133, 121],
#  [1, 2964, 8],
#  [1, 2963, 4],
#  [1, 773, 78],
#  [1, 1354, 563],
#  [1, 3187, 71],
#  [1, 3303, 64],
#  [1, 580, 84],
#  [1, 3155, 170],
#  [1, 3314, 444],
#  [1, 3105, 117],
#  [1, 549, 44],
#  [1, 3109, 58],
#  [1, 117, 16],
#  [1, 3410, 440],
#  [1, 576, 13],
#  [1, 2962, 3],
#  [1, 1275, 423],
#  [1, 3201, 155],
#  [1, 628, 22],
#  [1, 550, 36],
#  [1, 4172, 471],
#  [1, 3245, 171],
#  [1, 3908, 278],
#  [1, 539, 29],
#  [1, 3148, 118],
#  [1, 3031, 53],
#  [1, 3074, 160],
#  [1, 3210, 29],
#  [1, 3176, 149],
#  [1, 3071, 189],
#  [1, 155, 28],
#  [1, 3344, 306],
#  [1, 3428, 455],
#  [1, 3348, 243],
#  [1, 3512, 99],
#  [1, 613, 49],
#  [1, 3697, 201],
#  [1, 1101, 137],
#  [1, 3164, 101],
#  [1, 549, 20],
#  [1, 155, 139],
#  [1, 3499, 157],
#  [1, 3121, 136],
#  [1, 4235, 578],
#  [1, 3470, 95],
#  [1, 701, 179],
#  [1, 3438, 372],
#  [1, 3668, 270],
#  [1, 3622, 447],
#  [1, 730, 141],
#  [1, 5920, 4],
#  [1, 3198, 329],
#  [1, 935, 246],
#  [1, 3470, 95],
#  [1, 3345, 386],
#  [1, 3016, 9],
#  [1, 3346, 155],
#  [1, 560, 5],
#  [1, 3703, 78],
#  [1, 679, 735],
#  [1, 3021, 51],
#  [1, 832, 300],
#  [1, 969, 220],
#  [1, 3088, 113],
#  [1, 2969, 15],
#  [1, 788, 358],
#  [1, 3163, 304],
#  [1, 3877, 902],
#  [1, 663, 74],
#  [1, 3224, 152],
#  [1, 2960, 2],
#  [1, 828, 401],
#  [1, 3182, 77],
#  [1, 559, 5],
#  [1, 1546, 187],
#  [1, 748, 288],
#  [1, 3543, 88],
#  [1, 3001, 51],
#  [1, 3150, 143],
#  [1, 6236, 197],
#  [1, 3338, 365],
#  [1, 3027, 26],
#  [1, 523, 0],
#  [1, 3114, 105],
#  [1, 2974, 17],
#  [1, 3032, 19],
#  [1, 3014, 7],
#  [1, 598, 17],
#  [1, 921, 350],
#  [1, 3149, 263],
#  [1, 3263, 280],
#  [1, 3172, 36],
#  [1, 3111, 218],
#  [1, 3682, 629],
#  [1, 614, 47],
#  [1, 3472, 96],
#  [1, 3622, 447],
#  [1, 3459, 313],
#  [1, 3325, 330],
#  [1, 3935, 445],
#  [1, 3628, 777],
#  [1, 2965, 12],
#  [1, 368, 196],
#  [1, 802, 132],
#  [1, 200, 304],
#  [1, 3480, 100],
#  [1, 2998, 42],
#  [1, 2997, 28],
#  [1, 3169, 246],
#  [1, 1030, 300],
#  [1, 2979, 23],
#  [1, 200, 304],
#  [1, 4172, 471],
#  [1, 3471, 345],
#  [1, 959, 228],
#  [1, 542, 3],
#  [1, 3744, 313],
#  [1, 2960, 4],
#  [1, 3128, 185],
#  [1, 739, 50],
#  [1, 694, 69],
#  [1, 3081, 54],
#  [1, 642, 56],
#  [1, 3238, 401],
#  [1, 3141, 103],
#  [1, 333, 241],
#  [1, 828, 303],
#  [1, 3359, 262],
#  [1, 3164, 206],
#  [1, 2995, 12],
#  [1, 3038, 62],
#  [1, 3470, 95],
#  [1, 3214, 106],
#  [1, 601, 172],
#  [1, 3332, 349],
#  [1, 3781, 628],
#  [1, 3470, 95],
#  [1, 3343, 248],
#  [1, 3714, 530],
#  [1, 3023, 61],
#  [1, 815, 300],
#  [1, 2967, 7],
#  [1, 3291, 435],
#  [1, 3665, 131],
#  [1, 843, 128],
#  [1, 3329, 344],
#  [1, 2997, 28],
#  [1, 639, 25],
#  [1, 2982, 29],
#  [1, 753, 133],
#  [1, 1122, 138],
#  [1, 3113, 298],
#  [1, 3803, 402],
#  [1, 2980, 7],
#  [1, 3200, 308],
#  [1, 854, 269],
#  [1, 842, 350],
#  [1, 3723, 317],
#  [1, 3080, 102],
#  [1, 2961, 5],
#  [1, 7370, 1113],
#  [1, 4173, 755],
#  [1, 903, 151],
#  [1, 572, 24],
#  [1, 4647, 283],
#  [1, 3935, 445],
#  [1, 3493, 148],
#  [1, 526, 5],
#  [1, 2994, 19],
#  [1, 3136, 318],
#  [1, 3200, 305],
#  [1, 3592, 187],
#  [1, 3045, 59],
#  [1, 3545, 115],
#  [1, 142, 49],
#  [1, 3103, 221],
#  [1, 731, 124],
#  [1, 3102, 132],
#  [1, 3298, 314],
#  [1, 3048, 156],
#  [1, 3011, 75],
#  [1, 1095, 111],
#  [1, 3472, 98],
#  [1, 683, 82],
#  [1, 2961, 2],
#  [1, 3379, 478],
#  [1, 711, 169],
#  [1, 3260, 166],
#  [1, 3364, 508],
#  [1, 3413, 254],
#  [1, 3315, 410],
#  [1, 2967, 14],
#  [1, 3750, 313],
#  [1, 3655, 601],
#  [1, 2986, 10],
#  [1, 3155, 86],
#  [1, 3025, 30],
#  [1, 429, 396],
#  [1, 4048, 918],
#  [1, 3203, 117],
#  [1, 3112, 228],
#  [1, 3070, 14],
#  [1, 3584, 682],
#  [1, 6431, 100],
#  [1, 3417, 588],
#  [1, 201, 131],
#  [1, 3000, 45],
#  [1, 3559, 453],
#  [1, 3791, 289],
#  [1, 2976, 8],
#  [1, 553, 0],
#  [1, 3357, 233],
#  [1, 3184, 207],
#  [1, 3182, 77],
#  [1, 6265, 445],
#  [1, 6228, 140],
#  [1, 3028, 87],
#  [1, 2977, 18],
#  [1, 586, 47],
#  [1, 680, 231],
#  [1, 4206, 505],
#  [1, 3732, 507],
#  [1, 3115, 146],
#  [1, 668, 186],
#  [1, 664, 133],
#  [1, 2960, 2],
#  [1, 313, 173],
#  [1, 555, 23],
#  [1, 3274, 143],
#  [1, 3051, 11],
#  [1, 3082, 115],
#  [1, 3115, 31],
#  [1, 2970, 2],
#  [1, 3280, 133],
#  [1, 3205, 117],
#  [1, 3182, 79],
#  [1, 1122, 361],
#  [1, 3210, 277],
#  [1, 676, 111],
#  [1, 3205, 339],
#  [1, 3113, 224],
#  [1, 3038, 18],
#  [1, 687, 35],
#  [1, 3178, 351],
#  [1, 3343, 248],
#  [1, 3372, 274],
#  [1, 106, 6],
#  [1, 2979, 35],
#  [1, 3198, 242],
#  [1, 3020, 52],
#  [1, 552, 0],
#  [1, 3243, 152],
#  [1, 573, 37],
#  [1, 3935, 445],
#  [1, 3115, 380],
#  [1, 3037, 31],
#  [1, 3082, 179],
#  [1, 601, 32],
#  [1, 162, 52],
#  [1, 2965, 3],
#  [1, 866, 282],
#  [1, 2961, 2],
#  [1, 773, 27],
#  [1, 595, 47],
#  [1, 3131, 28],
#  [1, 3522, 447],
#  [1, 685, 135],
#  [1, 3036, 42],
#  [1, 11844, 21],
#  [1, 592, 25],
#  [1, 2968, 5],
#  [1, 3001, 110],
#  [1, 3034, 61],
#  [1, 2963, 10],
#  [1, 3204, 384],
#  [1, 905, 190],
#  [1, 3338, 205],
#  [1, 3136, 167],
#  [1, 2977, 9],
#  [1, 525, 5],
#  [1, 3008, 70],
#  [1, 551, 15],
#  [1, 3122, 59],
#  [1, 3833, 263],
#  [1, 2994, 36],
#  [1, 1118, 496],
#  [1, 1019, 599],
#  [1, 671, 74],
#  [1, 3312, 117],
#  [1, 540, 26],
#  [1, 632, 144],
#  [1, 810, 242],
#  [1, 3182, 77],
#  [1, 3098, 97],
#  [1, 3194, 163],
#  [1, 3019, 66],
#  [1, 3042, 61],
#  [1, 4172, 471],
#  [1, 1062, 93],
#  [1, 1033, 93],
#  [1, 3163, 143],
#  [1, 727, 205],
#  [1, 573, 129],
#  [1, 3135, 190],
#  [1, 3074, 125],
#  [1, 2963, 4],
#  [1, 3281, 144],
#  [1, 3215, 312],
#  [1, 3251, 130],
#  [1, 1084, 103],
#  [1, 3218, 70],
#  [1, 828, 357],
#  [1, 3001, 21],
#  [1, 3024, 35],
#  [1, 2960, 2],
#  [1, 534, 9],
#  [1, 3872, 382],
#  [1, 3470, 95],
#  [1, 3131, 56],
#  [1, 3138, 198],
#  [1, 1097, 74],
#  [1, 3009, 11],
#  [1, 4547, 1224],
#  [1, 3023, 19],
#  [1, 3161, 269],
#  [1, 3366, 156],
#  [1, 1214, 309],
#  [1, 3470, 95],
#  [1, 3020, 31],
#  [1, 3059, 27],
#  [1, 3213, 174],
#  [1, 3121, 146],
#  [1, 600, 49],
#  [1, 664, 104],
#  [1, 3022, 64],
#  [1, 245, 134],
#  [1, 3367, 281],
#  [1, 3172, 36],
#  [1, 3391, 256],
#  [1, 3067, 257],
#  [1, 1307, 446],
#  [1, 3511, 135],
#  [1, 525, 7],
#  [1, 2996, 6],
#  [1, 3966, 936],
#  [1, 3028, 16],
#  [1, 2960, 2],
#  [1, 726, 189],
#  [1, 3822, 377],
#  [1, 683, 198],
#  [1, 744, 136],
#  [1, 6259, 140],
#  [1, 3176, 99],
#  [1, 552, 0],
#  [1, 777, 174],
#  [1, 3000, 20],
#  [1, 577, 22],
#  [1, 3470, 95],
#  [1, 2970, 3],
#  [1, 6240, 260],
#  [1, 2960, 2],
#  [1, 4496, 864],
#  [1, 3048, 68],
#  [1, 3323, 388],
#  [1, 749, 188],
#  [1, 3404, 439],
#  [1, 734, 326],
#  [1, 3034, 110],
#  [1, 3002, 32],
#  [1, 3064, 237],
#  [1, 3011, 52],
#  [1, 6512, 559],
#  [1, 35523, 34],
#  [1, 3408, 295],
#  [1, 6066, 123],
#  [1, 624, 38],
#  [1, 3020, 40],
#  [1, 915, 284],
#  [1, 270, 182],
#  [1, 2970, 9],
#  [1, 1170, 688],
#  [1, 3428, 168],
#  [1, 990, 602],
#  [1, 3016, 48],
#  [1, 3052, 24],
#  [1, 3467, 232],
#  [1, 2964, 4],
#  [1, 721, 304],
#  [1, 2997, 28],
#  [1, 882, 261],
#  [1, 3066, 105],
#  [1, 751, 212],
#  [1, 3470, 95],
#  [1, 244, 138],
#  [1, 488, 267],
#  [1, 770, 310],
#  [1, 253, 104],
#  [1, 3034, 43],
#  [1, 3133, 286],
#  [1, 3310, 298],
#  [1, 920, 604],
#  [1, 3016, 147],
#  [1, 3596, 208],
#  [1, 3502, 114],
#  [1, 415, 240],
#  [1, 3050, 167],
#  [1, 3035, 65],
#  [1, 3029, 82],
#  [1, 523, 2],
#  [1, 617, 59],
#  [1, 6245, 243],
#  [1, 638, 49],
#  [1, 3244, 246],
#  [1, 946, 363],
#  [1, 664, 133],
#  [1, 641, 22],
#  [1, 3298, 159],
#  [1, 711, 307],
#  [1, 2984, 53],
#  [1, 3002, 32],
#  [1, 3002, 52],
#  [1, 3311, 551],
#  [1, 530, 0],
#  [1, 526, 5],
#  [1, 3027, 29],
#  [1, 179, 68],
#  [1, 2997, 58],
#  [1, 3010, 37],
#  [1, 3188, 262],
#  [1, 873, 238],
#  [1, 3024, 12],
#  [1, 3259, 268],
#  [1, 3535, 131],
#  [1, 3340, 434],
#  [1, 535, 13],
#  [1, 802, 138],
#  [1, 744, 215],
#  [1, 3496, 374],
#  [1, 5932, 14],
#  [1, 4241, 655],
#  [1, 3183, 279],
#  [1, 1702, 889],
#  [1, 577, 42],
#  [1, 3149, 190],
#  [1, 2978, 13],
#  [1, 3464, 352],
#  [1, 3119, 20],
#  [1, 525, 5],
#  [1, 1208, 564],
#  [1, 831, 276],
#  [1, 6436, 429],
#  [1, 3025, 74],
#  [1, 609, 91],
#  [1, 4172, 471],
#  [1, 3177, 361],
#  [1, 3008, 10],
#  [1, 3333, 297],
#  [1, 3145, 311],
#  [1, 3285, 307],
#  [1, 3622, 447],
#  [1, 739, 192],
#  [1, 3231, 156],
#  [1, 116, 15],
#  [1, 3575, 421],
#  [1, 3065, 161],
#  [1, 3402, 487],
#  [1, 3044, 23],
#  [1, 3136, 221],
#  [1, 2960, 2],
#  [1, 549, 23],
#  [1, 3259, 332],
#  [1, 2987, 35],
#  [1, 3077, 128],
#  [1, 2988, 22],
#  [1, 3935, 445],
#  [1, 3377, 409],
#  [1, 3622, 447],
#  [1, 1237, 247],
#  [1, 3932, 901],
#  [1, 3074, 45],
#  [1, 689, 154],
#  [1, 3264, 86],
#  [1, 3127, 221],
#  [1, 3102, 110],
#  [1, 3107, 201],
#  [1, 3072, 70],
#  [1, 175, 104],
#  [1, 2991, 28],
#  [1, 3230, 273],
#  [1, 3478, 243],
#  [1, 3477, 100],
#  [1, 2962, 8],
#  [1, 3913, 745],
#  [1, 722, 88],
#  [1, 325, 189],
#  [1, 2980, 22],
#  [1, 3694, 703],
#  [1, 558, 0],
#  [1, 3678, 86],
#  [1, 2991, 31],
#  [1, 703, 141],
#  [1, 656, 166],
#  [1, 3749, 602],
#  [1, 3158, 194],
#  [1, 3189, 233],
#  [1, 200, 304],
#  [1, 3822, 377],
#  [1, 138, 20],
#  [1, 3074, 116],
#  [1, 3470, 95],
#  [1, 3126, 99],
#  [1, 3463, 419],
#  [1, 3120, 144],
#  [1, 3366, 262],
#  [1, 3205, 198],
#  [1, 3813, 340],
#  [1, 3058, 203],
#  [1, 3021, 86],
#  [1, 3148, 206],
#  [1, 2961, 2],
#  [1, 632, 88],
#  [1, 977, 249],
#  [1, 580, 434],
#  [1, 559, 12],
#  [1, 3054, 123],
#  [1, 3188, 110],
#  [1, 3162, 100],
#  [1, 3983, 190],
#  [1, 2975, 18],
#  [1, 3328, 385],
#  [1, 745, 222],
#  [1, 1100, 679],
#  [1, 3782, 249],
#  [1, 562, 12],
#  [1, 3100, 152],
#  [1, 3691, 1010],
#  [1, 3361, 286],
#  [1, 526, 1],
#  [1, 3477, 273],
#  [1, 3142, 288],
#  [1, 3011, 52],
#  [1, 2972, 10],
#  [1, 3094, 156],
#  [1, 871, 400],
#  [1, 3194, 172],
#  [1, 2989, 64],
#  [1, 3415, 250],
#  [1, 554, 0],
#  [1, 3065, 127],
#  [1, 3288, 358],
#  [1, 937, 215],
#  [1, 3351, 313],
#  [1, 829, 423],
#  [1, 3325, 121],
#  [1, 3130, 191],
#  [1, 2966, 9],
#  [1, 3514, 621],
#  [1, 4547, 1224],
#  [1, 6443, 480],
#  [1, 2986, 40],
#  [1, 3411, 283],
#  [1, 784, 284],
#  [1, 230, 107],
#  [1, 3542, 211],
#  [1, 3398, 443],
#  [1, 3636, 247],
#  [1, 3031, 188],
#  [1, 3285, 443],
#  [1, 1031, 304],
#  [1, 570, 20],
#  [1, 1409, 186],
#  [1, 3511, 119],
#  [1, 3572, 190],
#  [1, 3152, 178],
#  [1, 3020, 36],
#  [1, 3297, 390],
#  [1, 773, 168],
#  [1, 537, 12],
#  [1, 780, 322],
#  [1, 3226, 254],
#  [1, 2962, 2],
#  [1, 540, 20],
#  [1, 2994, 277],
#  [1, 915, 288],
#  [1, 2978, 17],
#  [1, 2983, 35],
#  [1, 3543, 162],
#  [1, 749, 148],
#  [1, 895, 52],
#  [1, 3507, 19],
#  [1, 3003, 70],
#  [1, 3052, 32],
#  [1, 2963, 5],
#  [1, 556, 37],
#  [1, 584, 81],
#  [1, 178, 101],
#  [1, 3363, 253],
#  [1, 3330, 236],
#  [1, 729, 257],
#  [1, 9288, 461],
#  [1, 2965, 3],
#  [1, 3414, 377],
#  [1, 3171, 136],
#  [1, 3110, 133],
#  [1, 3084, 136],
#  [1, 3330, 236],
#  [1, 696, 271],
#  [1, 3415, 392],
#  [1, 3137, 233],
#  [1, 2996, 67],
#  [1, 3071, 107],
#  [1, 3341, 259],
#  [1, 674, 256],
#  [1, 6573, 192],
#  [1, 1909, 581],
#  [1, 3048, 177],
#  [1, 396, 274],
#  [1, 3023, 78],
#  [1, 569, 238],
#  [1, 2983, 14],
#  [1, 941, 196],
#  [1, 3025, 25],
#  [1, 2973, 10],
#  [1, 3018, 50],
#  [1, 3654, 280],
#  [1, 3822, 850],
#  [1, 3119, 20],
#  [1, 3473, 432],
#  [1, 3260, 162],
#  [1, 2991, 31],
#  [1, 648, 160],
#  [1, 3797, 363],
#  [1, 2979, 43],
#  [1, 3203, 225],
#  [1, 3210, 29],
#  [1, 2968, 11],
#  [1, 3784, 307],
#  [1, 724, 307],
#  [1, 3287, 285],
#  [1, 2998, 52],
#  [1, 3506, 389],
#  [1, 2978, 23],
#  [1, 2968, 5],
#  [1, 3003, 46],
#  [1, 3077, 62],
#  [1, 1141, 241],
#  [1, 111, 8],
#  [1, 687, 191],
#  [1, 864, 89],
#  [1, 1084, 103],
#  [1, 3005, 21],
#  [1, 1074, 734],
#  [1, 3264, 306],
#  [1, 3092, 97],
#  [1, 844, 421],
#  [1, 3537, 193],
#  [1, 3131, 171],
#  [1, 3178, 39],
#  [1, 3025, 27],
#  [1, 3518, 140],
#  [1, 665, 101],
#  [1, 3432, 373],
#  [1, 3813, 340],
#  [1, 1077, 109],
#  [1, 2972, 4],
#  [1, 2972, 18],
#  [1, 760, 98],
#  [1, 2991, 67],
#  [1, 626, 183],
#  [1, 3388, 266],
#  [1, 3249, 357],
#  [1, 1062, 93],
#  [1, 6763, 507],
#  [1, 3152, 107],
#  [1, 3290, 234],
#  [1, 3275, 149],
#  [1, 3037, 46],
#  [1, 3153, 203],
#  [1, 561, 39],
#  [1, 820, 28],
#  [1, 2997, 28],
#  [1, 3086, 209],
#  [1, 3179, 278],
#  [1, 669, 49],
#  [1, 3006, 71],
#  [1, 3827, 432],
#  [1, 6141, 273],
#  [1, 3651, 287],
#  [1, 3101, 69],
#  [1, 2988, 71],
#  [1, 3146, 155],
#  [1, 3587, 113],
#  [1, 776, 162],
#  [1, 1487, 404],
#  [1, 3850, 445],
#  [1, 3202, 358],
#  [1, 628, 128],
#  [1, 1287, 779],
#  [1, 3095, 106],
#  [1, 614, 9],
#  [1, 3276, 278],
#  [1, 3146, 229],
#  [1, 563, 11],
#  [1, 2974, 18],
#  [1, 3165, 151],
#  [1, 3390, 186],
#  [1, 1182, 409],
#  [1, 3110, 193],
#  [1, 3396, 179],
#  [1, 3335, 310],
#  [1, 2975, 6],
#  [1, 114, 11],
#  [1, 3906, 407],
#  [1, 543, 64],
#  [1, 1031, 237],
#  [1, 3233, 204],
#  [1, 2972, 13],
#  [1, 3306, 327],
#  [1, 529, 3],
#  [1, 664, 133],
#  [1, 725, 150],
#  [1, 3484, 347],
#  [1, 1459, 514],
#  [1, 3131, 58],
#  [1, 3208, 111],
#  [1, 3054, 120],
#  [1, 3284, 305],
#  [1, 3384, 160],
#  [1, 168, 188],
#  [1, 3264, 69],
#  [1, 277, 137],
#  [1, 3122, 137],
#  [1, 3205, 569],
#  [1, 707, 282],
#  [1, 3153, 96],
#  [1, 3039, 72],
#  [1, 2983, 29],
#  [1, 3168, 213],
#  [1, 608, 5],
#  [1, 733, 156],
#  [1, 3068, 200],
#  [1, 3355, 221],
#  [1, 3030, 51],
#  [1, 3470, 95],
#  [1, 3385, 201],
#  [1, 3283, 342],
#  [1, 1218, 566],
#  [1, 3059, 84],
#  [1, 3000, 21],
#  [1, 3032, 95],
#  [1, 3790, 244],
#  [1, 3020, 57],
#  [1, 4169, 652],
#  [1, 1484, 553],
#  [1, 541, 1],
#  [1, 3522, 373],
#  [1, 2961, 4],
#  [1, 3071, 71],
#  [1, 3025, 25],
#  [1, 3450, 354],
#  [1, 3117, 131],
#  [1, 2967, 8],
#  [1, 702, 389],
#  [1, 3891, 436],
#  [1, 3094, 144],
#  [1, 626, 19],
#  [1, 1168, 290],
#  [1, 3233, 45],
#  [1, 3015, 27],
#  [1, 3369, 430],
#  [1, 3670, 242],
#  [1, 3646, 147],
#  [1, 1274, 64],
#  [1, 3609, 407],
#  [1, 3775, 647],
#  [1, 5939, 23],
#  [1, 720, 191],
#  [1, 3180, 363],
#  [1, 3047, 68],
#  [1, 3585, 291],
#  [1, 3032, 90],
#  [1, 836, 183],
#  [1, 3280, 134],
#  [1, 646, 142],
#  [1, 3157, 108],
#  [1, 3022, 42],
#  [1, 3707, 301],
#  [1, 711, 182],
#  [1, 1062, 519],
#  [1, 2986, 31],
#  [1, 3128, 101],
#  [1, 3101, 136],
#  [1, 3228, 247],
#  [1, 3385, 308],
#  [1, 645, 65],
#  [1, 3738, 225],
#  [1, 2970, 21],
#  [1, 121, 242],
#  [1, 3289, 157],
#  [1, 2998, 53],
#  [1, 581, 38],
#  [1, 3366, 428],
#  [1, 557, 5],
#  [1, 526, 3],
#  [1, 3479, 95],
#  [1, 3780, 465],
#  [1, 3006, 50],
#  [1, 3005, 120],
#  [1, 3276, 462],
#  [1, 3636, 114],
#  [1, 563, 14],
#  [1, 3466, 654],
#  [1, 3261, 286],
#  [1, 3040, 55],
#  [1, 2975, 8],
#  [1, 637, 37],
#  [1, 3484, 347],
#  [1, 2970, 7],
#  [1, 3470, 95],
#  [1, 2987, 16],
#  [1, 176, 40],
#  [1, 1761, 491],
#  [1, 2985, 17],
#  [1, 4327, 627],
#  [1, 3029, 97],
#  [1, 573, 24],
#  [1, 2994, 30],
#  [1, 3195, 66],
#  [1, 3238, 92],
#  [1, 3003, 32],
#  [1, 3719, 223],
#  [1, 3224, 316],
#  [1, 3292, 63],
#  [1, 3233, 84],
#  [1, 2989, 23],
#  [1, 3568, 614],
#  [1, 3386, 145],
#  [1, 3768, 515],
#  [1, 3185, 243],
#  [1, 3545, 718],
#  [1, 3773, 515],
#  [1, 3135, 138],
#  [1, 3914, 460],
#  [1, 3060, 80],
#  [1, 732, 151],
#  [1, 3622, 447],
#  [1, 777, 24],
#  [1, 974, 410],
#  [1, 823, 125],
#  [1, 3213, 107],
#  [1, 3008, 56],
#  [1, 523, 0],
#  [1, 2986, 2],
#  [1, 1397, 135],
#  [1, 6284, 315],
#  [1, 3485, 108],
#  [1, 578, 164],
#  [1, 104, 0],
#  [1, 2960, 2],
#  [1, 3530, 505],
#  [1, 3480, 275],
#  [1, 3534, 506],
#  [1, 731, 310],
#  [1, 3266, 143],
#  [1, 3552, 699],
#  [1, 4172, 471],
#  [1, 3470, 95],
#  [1, 1204, 323],
#  [1, 861, 481],
#  [1, 594, 106],
#  [1, 553, 1],
#  [1, 3707, 301],
#  [1, 2978, 30],
#  [1, 3124, 307],
#  [1, 3066, 144],
#  [1, 3086, 82],
#  [1, 1186, 644],
#  [1, 3909, 349],
#  [1, 2961, 2],
#  [1, 3725, 412],
#  [1, 3925, 385],
#  [1, 1033, 387],
#  [1, 3768, 515],
#  [1, 3993, 760],
#  [1, 3006, 31],
#  [1, 1053, 196],
#  [1, 3004, 29],
#  [1, 3717, 182],
#  [1, 3099, 150],
#  [1, 3834, 534],
#  [1, 2963, 4],
#  [1, 3034, 55],
#  [1, 2962, 9],
#  [1, 3099, 156],
#  [1, 3262, 36],
#  [1, 1115, 473],
#  [1, 765, 520],
#  [1, 532, 2],
#  [1, 3327, 201],
#  [1, 3572, 231],
#  [1, 928, 254],
#  [1, 672, 170],
#  [1, 3183, 215],
#  [1, 695, 139],
#  [1, 4168, 448],
#  [1, 3042, 87],
#  [1, 3362, 334],
#  [1, 3420, 469],
#  [1, 3917, 703],
#  [1, 3084, 171],
#  [1, 2987, 22],
#  [1, 2961, 3],
#  [1, 3484, 347],
#  [1, 674, 106],
#  [1, 3768, 515],
#  [1, 3014, 44],
#  [1, 3063, 65],
#  [1, 3605, 209],
#  [1, 2987, 16],
#  [1, 3131, 176],
#  [1, 2970, 9],
#  [1, 3152, 57],
#  [1, 2974, 12],
#  [1, 1045, 401],
#  [1, 774, 122],
#  [1, 3152, 123],
#  [1, 1107, 465],
#  [1, 816, 138],
#  [1, 6182, 95],
#  [1, 3487, 493],
#  [1, 3147, 172],
#  [1, 3363, 301],
#  [1, 3470, 444],
#  [1, 752, 147],
#  [1, 3683, 170],
#  [1, 579, 38],
#  [1, 3734, 303],
#  [1, 3663, 695],
#  [1, 882, 506],
#  [1, 701, 150],
#  [1, 701, 134],
#  [1, 3016, 21],
#  [1, 3768, 515],
#  [1, 3738, 128],
#  [1, 160, 45],
#  [1, 3465, 515],
#  [1, 3059, 80],
#  [1, 6622, 199],
#  [1, 4157, 903],
#  [1, 3801, 512],
#  [1, 3461, 320],
#  [1, 3077, 49],
#  [1, 814, 128],
#  [1, 1459, 260],
#  [1, 148, 83],
#  [1, 702, 278],
#  [1, 3043, 40],
#  [1, 3481, 96],
#  [1, 696, 102],
#  [1, 3521, 7],
#  [1, 3012, 120],
#  [1, 561, 21],
#  [1, 3330, 172],
#  [1, 2979, 21],
#  [1, 752, 147],
#  [1, 4020, 394],
#  [1, 3154, 60],
#  [1, 552, 4],
#  [1, 528, 5],
#  [1, 150, 66],
#  [1, 3315, 260],
#  [1, 3606, 110],
#  [1, 3183, 220],
#  [1, 3132, 109],
#  [1, 625, 119],
#  ...]

# %%
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()

# %%
clf.fit(x1,train_y)
# Out:
# E:\programs\anaconda\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# E:\programs\anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
clf.score(x1,train_y)
# Out:
# 0.994375

# %%
clf.score(x2,test_y)
# Out:
# 0.995
